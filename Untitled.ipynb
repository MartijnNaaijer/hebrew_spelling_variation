# %%
from tf.app import use

A = use('etcbc/dss', hoist=globals())
A.load(['g_nme'])
# Out:
# C:\Users\geitb\anaconda3\envs\hebrew_spelling\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/app</span>
# <b title="local commit">data:</b> <span title="#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/tf/1.9</span>
# <b title="local commit">data:</b> <span title="#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/parallels/tf/1.9</span>
# ...

# %%
for scr in F.otype.s('scroll'):
    if T.scrollName(scr) == '1Q8':
        words = L.d(scr, 'word')
        for w in words:
            if F.lex_etcbc.v(w) == 'JD<[':
                print(w, F.chapter.v(w), F.verse.v(w), F.g_cons.v(w), F.vs.v(w), F.vs_etcbc.v(w))
# Out:
# 1919203 12 4 HWDJ<W hifil hif
# 1919217 12 5 MWD<T hofal hof
# 1919807 19 12 JD<W qal qal
# 1919940 19 21 NWD< nifal nif
# 1919945 19 21 JD<W qal qal
# 1921657 38 19 JWD< hifil hif
# 1922267 41 20 JD<W qal qal
# 1922309 41 22 ND<H qal qal
# 1922322 41 23 ND<H qal qal
# 1922525 43 10 TD<W qal qal
# 1922900 45 3 TD< qal qal
# 1922925 45 4 JD<TNJ qal qal
# 1922939 45 5 JD<TNJ qal qal
# 1922942 45 6 JD<W qal qal
# 1923389 47 8 >D< qal qal
# 1923442 47 11 TD<J qal qal
# 1923458 47 11 TD<J qal qal
# 1923494 47 13 MWDJ<M hifil hif
# 1923942 50 7 >D< qal qal
# 1924157 51 7 JWD<J qal qal
# 1924423 53 3 JD< qal qal
# 1924771 55 5 TD< qal qal
# 1924777 55 5 JD<WK qal qal
# 1925149 56 10 JD<W qal qal
# 1925169 56 11 JD<W qal qal
# 1925175 56 11 JD<W qal qal
# 1925383 58 3 TD< qal qal
# 1925768 59 8 JD<W qal qal
# 1926087 60 16 JD<T qal qal
# 1926748 63 16 JD<NW qal qal
# 1926812 64 1 HWDJ< hifil hif
# 1927445 66 14 NWD<H nifal nif

# %%
 
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
 
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
 
prompt = "the best chessplayer"
inputs = tokenizer(prompt, return_tensors="pt")
input_ids = inputs.input_ids
 
print(f"Prompt: '{prompt}'", end="")
 
for _ in range(20):
    outputs = model(input_ids)
    logits = outputs.logits
 
    next_token_logits = logits[:, -1, :]
    next_token_id = next_token_logits.argmax(dim=-1).unsqueeze(-1)
 
    input_ids = torch.cat([input_ids, next_token_id], dim=-1)
 
    new_token = tokenizer.decode(next_token_id[0])
    print(new_token, end="", flush=True)
 
print("\n")
# Out:
# Prompt: 'the best chessplayer' in the world, and he's a great player. He's a great player. He's a

# %%
from tf.app import use

A = use('etcbc/syriac', hoist=globals())
# Out:
# C:\Users\geitb\anaconda3\envs\hebrew_spelling\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# **Locating corpus resources ...**
# The requested app is not available offline
# 	~/text-fabric-data/github/etcbc/syriac/app not found
# Status: latest release online <b>v0.2.1</b> versus <b>None</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">app:</b> <span title="unknown release or commit">~/text-fabric-data/github/etcbc/syriac/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/etcbc/syriac/tf/0.2 not found
# Status: latest release online <b>v0.2.1</b> versus <b>None</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">data:</b> <span title="unknown release or commit">~/text-fabric-data/github/etcbc/syriac/tf/0.2</span>
# ...

# %%
import pandas as pd
from tf.app import use

A = use('etcbc/bhsa', hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local commit">data:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gaba4367b49750089e4e4122415a77cac43bd97bc offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gf45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/parallels/tf/2021</span>
# ...

# %%
dat = pd.read_csv('C:/Users/geitb/Kopenhagen/KopenhagenResearch/scripts_research/hebrew_spelling_variation/data/niph_hiph_pe_yod.csv', sep='\t')

# %%
signs = set()
counter = 0
for idf in list(dat.tf_id):
    if idf > 500000:
        continue
    vs = F.vs.v(idf)
    vt = F.vt.v(idf)
    #print(idf)
    text = T.text(idf)
    start = text[:3]
    print(start)
    for sign in start:
        signs.add(sign)

    counter += 1
    if counter > 3:
        break
    
signs
# Out:
# תֹּ
# תֹּ
# תֹּ
# תֵּ
# {'ֵ', 'ֹ', 'ּ', 'ת'}

# %%
allowed = { 'ֵ', 'ֹ'}

for idf in list(dat.tf_id):
    if idf > 500000:
        continue
    vs = F.vs.v(idf)
    vt = F.vt.v(idf)
    lex = F.lex.v(idf)
    #print(idf)
    text = T.text(idf)
    start = text[:3]
    if not any([(sign in allowed) for sign in start]):
        print(text, lex, vs, vt)
# Out:
# הַיְצֵ֣א  JY>[ hif impv
# יַּצֵּ֗ג  JYG[ hif wayq
# אַצִּֽיגָה־ JYG[ hif impf
# מוּצֵ֗את  JY>[ hof ptcp
# הוּרַ֣ד  JRD[ hof perf
# הֻלֶּ֣דֶת  JLD[ hof infc
# הִצַּגְתִּ֣יו  JYG[ hif perf
# יַּצִּגֵ֖ם  JYG[ hif wayq
# תְּנִיקֵֽהוּ׃  JNQ[ hif wayq
# יֻצָּ֑ג  JYG[ hof impf
# תּ֥וּקַד  JQD[ hof impf
# תּֽוּקַד־ JQD[ hof impf
# תּוּקַ֥ד  JQD[ hof impf
# יוּצַ֥ק  JYQ[ hof impf
# הוּרַ֖ד  JRD[ hof perf
# הַצֵּ֣ג  JYG[ hif infa
# יַּצִּקֻ֖ם  JYQ[ hif wayq
# תַּצִּ֤יתוּ  JYT[ hif impf
# יַּצִּ֥יתוּ  JYT[ hif wayq
# מַצִּ֛יג  JYG[ hif ptca
# תַּצִּ֤יג  JYG[ hif impf
# יַּצֵּ֨ג  JYG[ hif wayq
# יַּצִּ֧יתוּ  JYT[ hif wayq
# יַּצִּ֥יגוּ  JYG[ hif wayq
# יַּצִּ֤גוּ  JYG[ hif wayq
# הַצִּית֣וּהָ  JYT[ hif impv
# יַּצִּ֜תוּ  JYT[ hif wayq
# הִצִּ֧יתוּ  JYT[ hif perf
# יַּצִּ֨קוּ֙  JYQ[ hif wayq
# מּוּקָעִֽים׃  JQ<[ hof ptcp
# מֻצַ֣ק  JYQ[ hof ptcp
# מוּצָ֑ק  JYQ[ hof ptcp
# מוּצָֽק׃  JYQ[ hof ptcp
# נִצְּתָ֣ה  JYT[ nif perf
# נִצְּתָ֧ה  JYT[ nif perf
# הֽוּשַׁבְתֶּ֥ם  JCB[ hof perf
# ...

# %%
for idf in list(dat.tf_id):
    if idf > 500000:
        continue
    vs = F.vs.v(idf)
    vt = F.vt.v(idf)
    lex = F.lex.v(idf)
    if lex == 'JSD[':
        print(T.sectionFromNode(idf))
# Out:
# ('Isaiah', 28, 16)
# ('Ezra', 3, 11)
# ('2_Chronicles', 3, 3)

# %%
section = ('Exodus', 19, 24)
node = T.nodeFromSection(section)
T.text(node)
# Out:
# 'ויאמר אליו יהוה ך רד ועלית אתה ואהרן עמך והכהנים והעם אל יחרסו לעלות אל יהוה פן יפרץ בם '

# %%
words = L.d(node, 'word')
for w in words:
    print(w, F.lex.v(w), F.g_cons.v(w))
# Out:
# 446021 W W
# 446022 >MR[ J>MR
# 446023 >L >LJW
# 446024 JHWH/ JHWH
# 446025 K K
# 446026 JRD[ RD
# 446027 W W
# 446028 <LH[ <LJT
# 446029 >TH >TH
# 446030 W W
# 446031 >HRN/ >HRN
# 446032 <M <MK
# 446033 W W
# 446034 H H
# 446035 KHN/ KHNJM
# 446036 W W
# 446037 H H
# 446038 <M/ <M
# 446039 >L= >L
# 446040 XRS[ JXRSW
# 446041 L L
# 446042 <LH[ <LWT
# 446043 >L >L
# 446044 JHWH/ JHWH
# 446045 PN PN
# 446046 PRY[ JPRY
# 446047 B BM
