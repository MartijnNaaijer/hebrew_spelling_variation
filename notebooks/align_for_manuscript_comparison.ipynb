# %%
import os, collections

from Bio import pairwise2
from Bio.Seq import Seq
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from data import AllBooks, Book
from utils import most_frequent

#import bible_datasets

from align_config import dss_version, sp_version
from align_functions import make_alignments, collect_matching_words

from tf.app import use

MT = use('etcbc/bhsa')
Fmt, Tmt, Lmt = MT.api.F, MT.api.T, MT.api.L

SP = use('dt-ucph/sp', version=sp_version)
Fsp, Tsp, Lsp = SP.api.F, SP.api.T, SP.api.L

DSS = use('etcbc/dss', version=dss_version)
Fdss, Tdss, Ldss = DSS.api.F, DSS.api.T, DSS.api.L
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv1.8.1=#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local release">data:</b> <span title="rv1.8.1=#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#gaba4367b49750089e4e4122415a77cac43bd97bc offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#gf45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/parallels/tf/2021</span>
# <b title="local release">data:</b> <span title="rv1.8.1=#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/ner</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.3.3</a>, <a target="_blank" href="https://github.com/etcbc/bhsa/blob/master/app" title="etcbc/bhsa app">etcbc/bhsa/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://etcbc.github.io/bhsa/" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">etcbc - bhsa 2021</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="etcbc - bhsa feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>39</td>
#     <td>10938.21</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>929</td>
#     <td>459.19</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>lex</th>
#     <td>9230</td>
#     <td>46.22</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>23213</td>
#     <td>18.38</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>half_verse</th>
#     <td>45179</td>
#     <td>9.44</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>63717</td>
#     <td>6.70</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence_atom</th>
#     <td>64514</td>
#     <td>6.61</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>88131</td>
#     <td>4.84</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause_atom</th>
#     <td>90704</td>
#     <td>4.70</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>253203</td>
#     <td>1.68</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase_atom</th>
#     <td>267532</td>
#     <td>1.59</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>113850</td>
#     <td>1.42</td>
#     <td>38</td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>426590</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>Parallel Passages</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://nbviewer.jupyter.org/github/etcbc/parallels/blob/master/programs/parallels.ipynb" title="~/text-fabric-data/github/etcbc/parallels/tf/2021/crossref.tf">crossref</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 🆗 links between similar passages</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in Latin (Genesis; Numeri; Reges1; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book@ll" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book@am.tf">book@ll</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in amharic (ኣማርኛ)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ chapter number (1; 2; 3; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/code" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/code.tf">code</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ identifier of a clause atom relationship (0; 74; 367; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/det" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/det.tf">det</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ determinedness of phrase(atom) (det; und; NA.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/domain" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ text type of clause (? (Unknown); N (narrative); D (discursive); Q (Quotation).)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/freq_lex" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/freq_lex.tf">freq_lex</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ frequency of lexemes</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/function" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/function.tf">function</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ syntactic function of phrase (Cmpl; Objc; Pred; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word consonantal-transliterated (B R>CJT BR> >LHJM ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_cons_utf8.tf">g_cons_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word consonantal-Hebrew (ב ראשׁית ברא אלהים)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_lex.tf">g_lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme pointed-transliterated (B.:- R;>CIJT B.@R@> >:ELOH ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_lex_utf8.tf">g_lex_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme pointed-Hebrew (בְּ רֵאשִׁית בָּרָא אֱלֹה)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_word.tf">g_word</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word pointed-transliterated (B.:- R;>CI73JT B.@R@74> >:ELOHI92JM)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_word_utf8.tf">g_word_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word pointed-Hebrew (בְּ רֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/gloss" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> 🆗 english translation of lexeme (beginning create god(s))</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/gn" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/gn.tf">gn</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ grammatical gender (m; f; NA; unknown.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.gith
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv3.4=#g0c9b2fff6448228af93ed6c466ba95e6c0bb3547 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/app</span>
# <b title="local release">data:</b> <span title="rv3.4=#g0c9b2fff6448228af93ed6c466ba95e6c0bb3547 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.3.3</a>, <a target="_blank" href="https://github.com/dt-ucph/sp/blob/master/app" title="dt-ucph/sp app">dt-ucph/sp/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://etcbc.github.io/bhsa/" title="provenance of The Samaritan Pentateuch">dt-ucph - sp 3.4.1</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="dt-ucph - sp feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>5</td>
#     <td>79878.40</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>187</td>
#     <td>2135.79</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>5841</td>
#     <td>68.38</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>114891</td>
#     <td>3.48</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th><i>sign</i></th>
#     <td>399392</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>The Samaritan Pentateuch</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> book title</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> word consonantal-transliterated</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons_raw" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_cons_raw.tf">g_cons_raw</a>
# </div>
# <div class="fmono">str</div>
#
# <span> word consonantal-transliterated (without disambiguation of Shin (C) and Sin (F))</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons_utf8" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_cons_utf8.tf">g_cons_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> word in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_lex.tf">g_lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized lexeme</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex_utf8" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_lex_utf8.tf">g_lex_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized lexeme in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_nme" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_nme.tf">g_nme</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized nominal ending consonantal</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_nme_utf8" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_nme_utf8.tf">g_nme_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized nominal ending consonantal in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_pfm" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_pfm.tf">g_pfm</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal preformative consonantal</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_pfm_utf8" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_pfm_utf8.tf">g_pfm_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal preformative consonantal in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_prs" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_prs.tf">g_prs</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized pronominal suffix consonantal</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_prs_utf8" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_prs_utf8.tf">g_prs_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized pronominal suffix consonantal in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_uvf" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_uvf.tf">g_uvf</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized univalent final</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_uvf_utf8" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_uvf_utf8.tf">g_uvf_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized univalent final in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_vbe" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_vbe.tf">g_vbe</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal ending consonantal</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_vbe_utf8" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_vbe_utf8.tf">g_vbe_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal ending consonantal in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_vbs" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_vbs.tf">g_vbs</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal stem consonantal</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_vbs_utf8" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/g_vbs_utf8.tf">g_vbs_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal stem consonantal in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/gn" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/gn.tf">gn</a>
# </div>
# <div class="fmono">str</div>
#
# <span> gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/language" title="~/text-fabric-data/github/dt-ucph/sp/tf/3.4.1/language.tf">language</a>
# </div>
# <div class="fmono">str</div>
#
# <span> language</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv1.9=#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/app</span>
# <b title="local release">data:</b> <span title="rv1.9=#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/tf/1.9</span>
# <b title="local release">data:</b> <span title="rv1.9=#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/parallels/tf/1.9</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.3.3</a>, <a target="_blank" href="https://github.com/etcbc/dss/blob/master/app" title="etcbc/dss app">etcbc/dss/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/about.md" title="provenance of Dead Sea Scrolls">etcbc - dss 1.9</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="etcbc - dss feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>scroll</th>
#     <td>1001</td>
#     <td>1428.81</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>lex</th>
#     <td>10450</td>
#     <td>129.14</td>
#     <td>94</td>
# </tr>
#
# <tr>
#     <th>fragment</th>
#     <td>11182</td>
#     <td>127.91</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>line</th>
#     <td>52895</td>
#     <td>27.04</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>125</td>
#     <td>12.85</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>cluster</th>
#     <td>101099</td>
#     <td>6.68</td>
#     <td>47</td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>315</td>
#     <td>5.10</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>500995</td>
#     <td>2.81</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th><i>sign</i></th>
#     <td>1430241</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b><github>etcbc/dss/parallels/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://github.com/etcbc/dss/tree/master/parallels/tf" title="~/text-fabric-data/github/etcbc/dss/parallels/tf/1.9/sim.tf">sim</a>
# </div>
# <div class="fmono">int</div>
#
# <span> similarity between lines, as a percentage of the common material wrt the combined material</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>Dead Sea Scrolls</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> space behind the word, if any</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/alt.tf">alt</a>
# </div>
# <div class="fmono">int</div>
#
# <span> alternative reading</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/biblical.tf">biblical</a>
# </div>
# <div class="fmono">int</div>
#
# <span> whether we are in biblical material or not</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> acronym of the book in which the word occurs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/book_etcbc.tf">book_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/chapter.tf">chapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> label of the chapter in which the word occurs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/cl.tf">cl</a>
# </div>
# <div class="fmono">str</div>
#
# <span> class (morphology tag)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/cl2.tf">cl2</a>
# </div>
# <div class="fmono">str</div>
#
# <span> class (for part 2) (morphology tag)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/cor.tf">cor</a>
# </div>
# <div class="fmono">int</div>
#
# <span> correction made by an ancient or modern editor</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/fragment.tf">fragment</a>
# </div>
# <div class="fmono">str</div>
#
# <span> label of a fragment of a scroll</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/full.tf">full</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (Unicode) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/fulle.tf">fulle</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (ETCBC transliteration) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/fullo.tf">fullo</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (original source) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/g_nme_etcbc.tf">g_nme_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/g_prs_etcbc.tf">g_prs_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/glex.tf">glex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> representation (Unicode) of a lexeme leaving out non-letters</span>
#
# </div>
#
# <div class="frow">
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>

# %%
DATA_FOLDER = '../data'
MATRES_FILE = ['nouns_adjectives.csv', 'ptca_qal.csv', 'ptcp_qal.csv', 'niph_hiph_pe_yod.csv', 'infa_qal.csv',
               'infc_qal_triliteral.csv', 'infc_qal_lamed_he.csv', 'hiphil_triliteral_with_hireq.csv']

# %%
PENTATEUCH_BOOKS = ['Genesis', 'Exodus', 'Leviticus', 'Numbers', 'Deuteronomy']
ALL_BOOK_NAMES = [Tmt.sectionFromNode(bo)[0] for bo in Fmt.otype.s('book')]

# %%
QSP_SCROLLS = {'1Qisaa', '1QisaaI', '1QisaaII', '2Q3', '4Q13', '4Q20', '2Q7', '4Q27', '1Q4', '2Q12', '4Q37', '4Q38', '4Q38a', '4Q40', '4Q53',
               '4Q57', '2Q13', '4Q78', '4Q80', '4Q82', '4Q128', '4Q129', '4Q134', '4Q135', '4Q136',
                '4Q137', '4Q138', '4Q139', '4Q140', '4Q141', '4Q142', '4Q143', '4Q144', '4Q158', '4Q364',
                '4Q365', '4Q96', '4Q111', '4Q109', '11Q5', '11Q6', '11Q7', '11Q8'}

# %% [markdown]
# # Prepare MT and SP texts

# %% [markdown]
# Produce dictionary mt_sp_matches which has mt words nodes as keys and matching word numbers from SP as values.

# %%
# prepare mt and sp books
MANUSCRIPTS = ['MT', 'SP']
all_books = AllBooks()
for book_name in ALL_BOOK_NAMES:
    book = Book('MT', book_name, Fmt, Tmt, Lmt)
    all_books.data[('MT', book_name)] = book
    
    if book_name in PENTATEUCH_BOOKS:
        book = Book('SP', book_name, Fsp, Tsp, Lsp)
        all_books.data[('SP', book_name)] = book

# %% [markdown]
# # Match words

# %%
all_data = []

for file_name in MATRES_FILE:
    file_path = DATA_FOLDER + '/' + file_name
    feature_name = file_name.split('.')[0]
    data_one_feature = pd.read_csv(file_path, sep='\t')
    data_one_feature['feature'] = feature_name
    all_data.append(data_one_feature)
    
dat = pd.concat(all_data)
dat.shape
# Out:
# (62333, 39)

# %%
dat.head()
# Out:
#    tf_id scroll     book  chapter  verse     lex g_cons   stem pattern
# 0      2     MT  Genesis        1      1  R>CJT/  R>CJT  R>CJT   CMCMC  \
# 1      2     MT  Genesis        1      1  R>CJT/  R>CJT  R>CJT   CMCMC
# 2      4     MT  Genesis        1      1  >LHJM/  >LHJM    >LH     CCC
# 3     20     MT  Genesis        1      2    XCK/    XCK    XCK     CCC
# 4     23     MT  Genesis        1      2   THWM/   THWM   THWM    CCMC
#
#   pattern_g_cons  ... has_nme rec_signs_stem cor_signs_stem   type
# 0          CMCMC  ...       0          nnnnn          nnnnn  first  \
# 1          CMCMC  ...       0          nnnnn          nnnnn   last
# 2          CCCMC  ...       1            nnn            nnn   last
# 3            CCC  ...       0            nnn            nnn  first
# 4           CCMC  ...       0           nnnn           nnnn   last
#
#   vowel_letter has_vowel_letter neigh_vowel_letter           feature
# 0            >                1                0.0  nouns_adjectives  \
# 1            J                1                0.0  nouns_adjectives
# 2          NaN                0                0.0  nouns_adjectives
# 3          NaN                0                0.0  nouns_adjectives
# 4            W                1                0.0  nouns_adjectives
#
#   has_hireq mt_match
# 0       NaN      NaN
# 1       NaN      NaN
# 2       NaN      NaN
# 3       NaN      NaN
# 4       NaN      NaN
#
# [5 rows x 39 columns]

# %%
dat.tail()
# Out:
#         tf_id scroll       book  chapter  verse   lex  g_cons  stem pattern
# 3136  2104434  Mas1b  Leviticus       11      7  PRS[   MPRJS  PRJS     NaN  \
# 3137  2106782  Mas1e     Psalms       81     15  KN<[   >KNJ<  KNJ<     NaN
# 3138  2106808  Mas1e     Psalms       81     17  FB<[  >FBJ<K  FBJ<     NaN
# 3139  2106840  Mas1e     Psalms       82      3  YDQ[  HYDJQW  YDJQ     NaN
# 3140  2106849  Mas1e     Psalms       82      4  NYL[   HYJLW   YJL     NaN
#
#      pattern_g_cons  ... has_nme rec_signs_stem cor_signs_stem  type
# 3136            NaN  ...       0           nnnn           nnnn  last  \
# 3137            NaN  ...       0           nnnn           nnnn  last
# 3138            NaN  ...       0           nnnn           nnnn  last
# 3139            NaN  ...       0           nnnn           nnnn  last
# 3140            NaN  ...       0            nnn            nnn  last
#
#      vowel_letter has_vowel_letter neigh_vowel_letter
# 3136            J                1                NaN  \
# 3137            J                1                NaN
# 3138            J                1                NaN
# 3139            J                1                NaN
# 3140            J                1                NaN
#
#                            feature has_hireq mt_match
# 3136  hiphil_triliteral_with_hireq         1    57952
# 3137  hiphil_triliteral_with_hireq         1   324738
# 3138  hiphil_triliteral_with_hireq         1   324762
# 3139  hiphil_triliteral_with_hireq         1   324791
# 3140  hiphil_triliteral_with_hireq         1   324799
#
# [5 rows x 39 columns]

# %%
dat.dtypes
# Out:
# tf_id                   int64
# scroll                 object
# book                   object
# chapter                 int64
# verse                   int64
# lex                    object
# g_cons                 object
# stem                   object
# pattern                object
# pattern_g_cons         object
# vs                     object
# vt                     object
# nu                     object
# gn                     object
# ps                     object
# sp                     object
# prs                    object
# nme                    object
# hloc                   object
# prefix                 object
# rec_signs              object
# cor_signs              object
# heb_g_cons             object
# other_vowel_ending     object
# line                   object
# column                 object
# has_prs                 int64
# has_prefix              int64
# has_hloc                int64
# has_nme                 int64
# rec_signs_stem         object
# cor_signs_stem         object
# type                   object
# vowel_letter           object
# has_vowel_letter        int64
# neigh_vowel_letter    float64
# feature                object
# has_hireq              object
# mt_match               object
# dtype: object

# %%
# Remove hiphil without hireq

dat = dat[(dat.feature != 'hiphil_triliteral_with_hireq') | (dat.feature == 'hiphil_triliteral_with_hireq') & (dat.has_hireq == '1')] # & dat.has_hireq == 1)]

# %%
dat['book2'] = pd.Series(dat.book.str.replace('1_', '').str.replace('2_', ''))

# %%
#dat = pd.read_csv(MATRES_FILE, sep='\t')

# dat_dss means non-MT, SP is included
dat_dss = dat[~dat.scroll.isin(['MT'])]
scroll_book_combinations = list(set(zip(dat_dss.scroll, dat_dss.book)))
dat_dss.shape
# Out:
# (19026, 40)

# %%
for manuscript, book_name in scroll_book_combinations:
    if manuscript == 'MT':
        continue
    elif manuscript == 'SP':
        book = Book(manuscript, book_name, Fsp, Tsp, Lsp)
        all_books.data[(manuscript, book_name)] = book
    else:
        book = Book(manuscript, book_name, Fdss, Tdss, Ldss)
        all_books.data[(manuscript, book_name)] = book

# %%
def make_matching_word_dict(book_name, all_books):

    all_match_dicts = {}

    matching_book = book_name
    matching_manuscripts = [scr for scr, bo in all_books.data.keys() if bo == matching_book]

    for man1 in matching_manuscripts:
        for man2 in matching_manuscripts:
            if man1 != man2:
            
                man1_verse_texts = all_books.data[(man1, matching_book)].verse_text_dict
                man2_verse_texts = all_books.data[(man2, matching_book)].verse_text_dict

                alignments_dict = make_alignments(man1_verse_texts, man2_verse_texts)
    
                man1_word2char = all_books.data[(man1, matching_book)].word2char
                man2_word2char = all_books.data[(man2, matching_book)].word2char
 
                matching_words_dict = collect_matching_words(alignments_dict, man1_word2char, man2_word2char)

                matches = {}
                for man1_word, man2_list in matching_words_dict.items():
                    man2_word = most_frequent(man2_list)
                    matches[man1_word] = man2_word
                all_match_dicts[((man1, matching_book), (man2, matching_book))] = matches
                
    return all_match_dicts, matching_manuscripts

# %%
def read_dataset(file):

    return pd.read_csv(file, sep='\t')

# %%
class MaterData:
    def __init__(self, man1, man2, section, lex, mater_val1, mater_val2, tf_id1, tf_id2, g_cons1, g_cons2):
        self.man1 = man1
        self.man2 = man2
        self.section = section
        self.lex = lex
        self.mater_val1 = mater_val1
        self.mater_val2 = mater_val2
        self.tf_id1 = tf_id1
        self.tf_id2 = tf_id2
        self.g_cons1 = g_cons1
        self.g_cons2 = g_cons2

# %%
def collect_matching_cases(matching_manuscripts, matching_book, dat):

    all_mater_datasets = {}

    for man in matching_manuscripts:
        mater_data = dat[(dat.book == matching_book) & (dat.scroll == man)]
        all_mater_datasets[(man, matching_book)] = mater_data
        
    return all_mater_datasets

# %%
def collect_mater_data(matching_manuscripts, all_match_dicts, all_mater_datasets, matching_book):

    manuscript_mater_match = collections.defaultdict(list)
    manuscripts = set()

    for idx, man in enumerate(matching_manuscripts):
        for idx2, man2 in enumerate(matching_manuscripts):
            if idx < idx2:
            
                matching_ids = all_match_dicts[((man, matching_book), (man2, matching_book))]
                man_data = all_mater_datasets[(man, matching_book)]
                man2_data = all_mater_datasets[(man2, matching_book)]
                for _, row in man_data.iterrows():
                
                    tf_id = row.tf_id
                    lex, typ, has_vl = row.lex, row.type, row.has_vowel_letter
                    g_cons1 = row.g_cons
                    section = (row.book, row.chapter, row.verse)
                    if man == 'SP':
                        tf_id = tf_id - 100000

                    matching_tf_id = matching_ids.get(tf_id, None)
                
                    if not matching_tf_id:
                        continue
                    
                    if man2 == 'SP':
                        matching_tf_id = matching_tf_id + 100000
                
                    man2_row = man2_data[(man2_data.tf_id == matching_tf_id) & (man2_data.lex == lex) & (man2_data.type == typ)]
                    
                    if not man2_row.shape[0]:
                        continue
                    has_vl2 = man2_row.has_vowel_letter.iloc[0]
                    g_cons2 = man2_row.g_cons.iloc[0]
                 
                    mater_data = MaterData(man, man2, section, lex, has_vl, has_vl2, tf_id, matching_tf_id, g_cons1, g_cons2)
                
                    manuscript_mater_match[man].append(mater_data)
                    manuscripts.add(man)
                    manuscripts.add(man2)
                    
    return manuscript_mater_match, manuscripts

# %%
def register_similarities_with_mt(manuscripts, mt_ids, manuscript_mater_match):

    mater_value_dict = {0: -1,
                    1: 1}

    mater_match_array = np.zeros((len(manuscripts), len(mt_ids)))

    for dat_object in manuscript_mater_match['MT']:
        
        other_man = dat_object.man2
        mt_tfid = dat_object.tf_id1
        other_man_tfid = dat_object.tf_id2
    
        mt_mater = dat_object.mater_val1
        other_man_mater = dat_object.mater_val2
    
        mt_idx = man2idx['MT']
        other_man_idx = man2idx[other_man]
    
        mt_mater_value = mater_value_dict[mt_mater]
        other_man_mater_value = mater_value_dict[other_man_mater]
    
        mt_tf_id = mt_tf2idx[mt_tfid]
    
        mater_match_array[mt_idx, mt_tf_id] = mt_mater_value
        mater_match_array[other_man_idx, mt_tf_id] = other_man_mater_value
        
    return mater_match_array

# %%
def get_parallels(manuscript_mater_match, hif_match_dict):
    for scroll in manuscript_mater_match.keys():
        for dat_object in manuscript_mater_match[scroll]:
            man1 = dat_object.man1
            man2 = dat_object.man2
            
            hif_match_dict[(dat_object.tf_id2, man2)][man1] = dat_object.tf_id1
            hif_match_dict[(dat_object.tf_id1, man1)][man2] = dat_object.tf_id2
        
    return hif_match_dict

# %%
def count_parallel_cases(mater_match_array):

    mater_arr = np.zeros((2, mater_match_array.shape[1]))

    for col_idx in range(mater_match_array.shape[1]):
        col = mater_match_array[:, col_idx]
        col_counts = collections.Counter(col)
        with_vowel_count = col_counts.get(1, 0)
        without_vowel_count = col_counts.get(-1, 0)
        mater_arr[0, col_idx] = with_vowel_count
        mater_arr[1, col_idx] = without_vowel_count
        
    return mater_arr

# %%
hif_match_dict = collections.defaultdict(lambda: collections.defaultdict(int))

for book in {'Isaiah'}: #ALL_BOOK_NAMES:
    print(book)
    all_match_dicts, matching_manuscripts = make_matching_word_dict(book, all_books)
    all_mater_datasets = collect_matching_cases(matching_manuscripts, book, dat)
    manuscript_mater_match, manuscripts = collect_mater_data(matching_manuscripts, all_match_dicts, all_mater_datasets, book)
    
    hif_match_dict = get_parallels(manuscript_mater_match, hif_match_dict)
    print(len(hif_match_dict))
# Out:
# Isaiah
# 6647

# %%
all_scrolls = set(dat_dss.scroll) 
non_qsp_scrolls = all_scrolls.difference(QSP_SCROLLS)
non_qsp_data = dat_dss[dat_dss.scroll.isin(non_qsp_scrolls)]

# %%
set(dat_dss.scroll)
# Out:
# {'11Q1',
#  '11Q2',
#  '11Q4',
#  '11Q5',
#  '11Q6',
#  '11Q7',
#  '11Q8',
#  '1Q1',
#  '1Q10',
#  '1Q11',
#  '1Q12',
#  '1Q13',
#  '1Q2',
#  '1Q3',
#  '1Q4',
#  '1Q5',
#  '1Q6',
#  '1Q7',
#  '1Q71',
#  '1Q8',
#  '1Q9',
#  '1Qisaa',
#  '2Q11',
#  '2Q13',
#  '2Q14',
#  '2Q15',
#  '2Q16',
#  '2Q17',
#  '2Q2',
#  '2Q3',
#  '2Q5',
#  '2Q7',
#  '2Q9',
#  '34Se1',
#  '34Se2',
#  '3Q2',
#  '3Q3',
#  '4Q1',
#  '4Q10',
#  '4Q100',
#  '4Q101',
#  '4Q102',
#  '4Q103',
#  '4Q104',
#  '4Q105',
#  '4Q106',
#  '4Q107',
#  '4Q108',
#  '4Q109',
#  '4Q11',
#  '4Q110',
#  '4Q111',
#  '4Q112',
#  '4Q113',
#  '4Q114',
#  '4Q128',
#  '4Q129',
#  '4Q13',
#  '4Q130',
#  '4Q131',
#  '4Q133',
#  '4Q134',
#  '4Q135',
#  '4Q136',
#  '4Q137',
#  '4Q138',
#  '4Q139',
#  '4Q14',
#  '4Q140',
#  '4Q141',
#  '4Q142',
#  '4Q143',
#  '4Q145',
#  '4Q146',
#  '4Q149',
#  '4Q15',
#  '4Q150',
#  '4Q151',
#  '4Q152',
#  '4Q153',
#  '4Q154',
#  '4Q155',
#  '4Q16',
#  '4Q17',
#  '4Q18',
#  '4Q2',
#  '4Q20',
#  '4Q21',
#  '4Q22',
#  '4Q23',
#  '4Q24',
#  '4Q25',
#  '4Q26',
#  '4Q26a',
#  '4Q26b',
#  '4Q26c',
#  '4Q27',
#  '4Q28',
#  '4Q29',
#  '4Q3',
#  '4Q30',
#  '4Q31',
#  '4Q32',
#  '4Q33',
#  '4Q34',
#  '4Q35',
#  '4Q36',
#  '4Q37',
#  '4Q38',
#  '4Q38a',
#  '4Q38b',
#  '4Q38c',
#  '4Q39',
#  '4Q4',
#  '4Q40',
#  '4Q41',
#  '4Q42',
#  '4Q43',
#  '4Q44',
#  '4Q45',
#  '4Q46',
#  '4Q47',
#  '4Q48',
#  '4Q49',
#  '4Q5',
#  '4Q50',
#  '4Q51',
#  '4Q52',
#  '4Q53',
#  '4Q54',
#  '4Q55',
#  '4Q56',
#  '4Q57',
#  '4Q58',
#  '4Q59',
#  '4Q6',
#  '4Q60',
#  '4Q61',
#  '4Q62',
#  '4Q62a',
#  '4Q63',
#  '4Q64',
#  '4Q65',
#  '4Q66',
#  '4Q67',
#  '4Q68',
#  '4Q7',
#  '4Q70',
#  '4Q71',
#  '4Q72',
#  '4Q72a',
#  '4Q72b',
#  '4Q73',
#  '4Q74',
#  '4Q76',
#  '4Q77',
#  '4Q78',
#  '4Q79',
#  '4Q80',
#  '4Q81',
#  '4Q82',
#  '4Q83',
#  '4Q84',
#  '4Q85',
#  '4Q86',
#  '4Q87',
#  '4Q88',
#  '4Q89',
#  '4Q8d',
#  '4Q9',
#  '4Q90',
#  '4Q91',
#  '4Q92',
#  '4Q93',
#  '4Q94',
#  '4Q95',
#  '4Q96',
#  '4Q97',
#  '4Q98',
#  '4Q98a',
#  '4Q98b',
#  '4Q98d',
#  '4Q98f',
#  '4Q98g',
#  '4Q99',
#  '5/6hev1a',
#  '5/6hev1b',
#  '5Q1',
#  '5Q2',
#  '5Q4',
#  '5Q5',
#  '5Q6',
#  '6Q1',
#  '6Q2',
#  '6Q4',
#  '6Q5',
#  '6Q6',
#  '6Q7',
#  '8Q1',
#  '8Q2',
#  '8Q3',
#  '8Q4',
#  'Arugleviticus',
#  'Mas1a',
#  'Mas1b',
#  'Mas1c',
#  'Mas1d',
#  'Mas1e',
#  'Mas1f',
#  'Mur1',
#  'Mur2',
#  'Mur3',
#  'Mur4',
#  'Mur88',
#  'Murx',
#  'SP',
#  'Sdeir1',
#  'Xhev/se2',
#  'Xhev/se5',
#  'Xjoshua',
#  'Xjudges',
#  'Xq1',
#  'Xq2',
#  'Xq3'}

# %%
## Calculate how individual features vary in pairs of manuscripts.

# %%
n = 0
isa_dict = collections.defaultdict(lambda: collections.defaultdict(lambda: collections.defaultdict(int)))
id_combinations = set()


for index, row in dat_dss.iterrows():
    tf_id = row.tf_id, 
    scroll = row.scroll, 
    has_vl = row.has_vowel_letter
    book, ch, ve = row.book, row.chapter, row.verse
    g_cons = row.g_cons
    lex = row.lex
    prefix = row.prefix
    feature = row.feature
    typ = row.type
    feature = feature + '_' + typ
    
    if book != 'Isaiah':
        continue

    if (tf_id[0], scroll[0]) in hif_match_dict:

        matching_man_dict = hif_match_dict[(tf_id[0], scroll[0])]
        
        if scroll[0] == '1Qisaa' and 'MT' not in matching_man_dict:
            print(book, ch, ve, lex, g_cons)
        
        for man, corr_id in matching_man_dict.items():

            corr_row = dat[dat.tf_id == corr_id]
            n += 1
        
            mt_full = corr_row.has_vowel_letter.iloc[0]
            corr_scroll = corr_row.scroll.iloc[0]
            corr_vl = corr_row.has_vowel_letter.iloc[0]
            #print(scroll, corr_scroll, has_vl, corr_vl, g_cons, corr_row.g_cons.iloc[0], prefix, book, ch, ve)
            
            if not tuple(sorted([tf_id[0], corr_id])) in id_combinations:
                isa_dict[(scroll[0], man)][feature][(has_vl, corr_vl)] += 1
            id_combinations.add(tuple(sorted([tf_id[0], corr_id])))
            
    elif scroll[0] == '1Qisaa':
        print('NOT IN MATCH_DICT', book, ch, ve, lex)
            
    
print(n)
# Out:
# NOT IN MATCH_DICT Isaiah 1 15 <WN/
# NOT IN MATCH_DICT Isaiah 3 24 BCT/
# NOT IN MATCH_DICT Isaiah 5 12 P<LH/
# NOT IN MATCH_DICT Isaiah 5 12 P<LH/
# NOT IN MATCH_DICT Isaiah 5 27 J<P/
# NOT IN MATCH_DICT Isaiah 5 28 YWR/
# NOT IN MATCH_DICT Isaiah 8 3 NBJ>/
# NOT IN MATCH_DICT Isaiah 9 6 MRBH/
# NOT IN MATCH_DICT Isaiah 13 22 <WD/
# NOT IN MATCH_DICT Isaiah 14 23 QPWZ/
# NOT IN MATCH_DICT Isaiah 16 4 MY/
# NOT IN MATCH_DICT Isaiah 16 14 KBWD/
# NOT IN MATCH_DICT Isaiah 19 13 NFJ>/
# NOT IN MATCH_DICT Isaiah 20 4 GWLH/
# NOT IN MATCH_DICT Isaiah 21 1 RXWQ/
# NOT IN MATCH_DICT Isaiah 21 8 R>H/
# NOT IN MATCH_DICT Isaiah 21 16 CLC/
# NOT IN MATCH_DICT Isaiah 22 5 QDC/
# NOT IN MATCH_DICT Isaiah 23 9 KL/
# NOT IN MATCH_DICT Isaiah 23 11 M<WZ/
# NOT IN MATCH_DICT Isaiah 27 2 XMR===/
# NOT IN MATCH_DICT Isaiah 28 1 G>WN/
# NOT IN MATCH_DICT Isaiah 28 12 J<P/
# NOT IN MATCH_DICT Isaiah 28 22 MWSRH/
# NOT IN MATCH_DICT Isaiah 29 3 MYWDH/
# NOT IN MATCH_DICT Isaiah 29 5 ZD/
# NOT IN MATCH_DICT Isaiah 29 7 MYWRH/
# NOT IN MATCH_DICT Isaiah 29 16 XMR==/
# NOT IN MATCH_DICT Isaiah 30 5 B>C/
# NOT IN MATCH_DICT Isaiah 34 15 QPD/
# NOT IN MATCH_DICT Isaiah 34 15 QPD/
# NOT IN MATCH_DICT Isaiah 36 2 M>D/
# NOT IN MATCH_DICT Isaiah 36 12 >DWN/
# NOT IN MATCH_DICT Isaiah 37 20 >LHJM/
# NOT IN MATCH_DICT Isaiah 37 27 QDJM/
# NOT IN MATCH_DICT Isaiah 37 33 SLLH/
# NOT IN MATCH_DICT Isaiah 38 9 XLJ/
# NOT IN MATCH_DICT Isaiah 38 10 PQDH/
# NOT IN MATCH_DICT Isaiah 38 10 MR/
# NOT IN MATCH_DICT Isaiah 38 17 M>D/
# NOT IN MATCH_DICT Isaiah 38 20 >LWH/
# NOT IN MATCH_DICT Isaiah 39 2 KL/
# NOT IN MATCH_DICT Isaiah 40 8 >LHJM/
# NOT IN MATCH_DICT Isaiah 40 10 XZQ=/
# NOT IN MATCH_DICT Isaiah 41 11 KL/
# NOT IN MATCH_DICT Isaiah 41 22 >XRWN/
# NOT IN MATCH_DICT Isaiah 42 5 >LHJM/
# NOT IN MATCH_DICT Isaiah 42 11 HR/
# NOT IN MATCH_DICT Isaiah 42 24 MCSH/
# NOT IN MATCH_DICT Isaiah 43 3 KPR/
# NOT IN MATCH_DICT Isaiah 43 19 NTJBH/
# NOT IN MATCH_DICT Isaiah 43 25 <WD/
# Isaiah 45 2 HR/ HRRJM
# NOT IN MATCH_DICT Isaiah 45 7 VWB/
# NOT IN MATCH_DICT Isaiah 45 16 YWR/
# NOT IN MATCH_DICT Isaiah 46 1 MCM</
# NOT IN MATCH_DICT Isaiah 47 5 GBWRH/
# NOT IN MATCH_DICT Isaiah 47 7 GBWRH/
# NOT IN MATCH_DICT Isaiah 47 7 <WD/
# NOT IN MATCH_DICT Isaiah 47 7 >XRWN/
# NOT IN MATCH_DICT Isaiah 47 8 <WD/
# NOT IN MATCH_DICT Isaiah 49 9 KL/
# NOT IN MATCH_DICT Isaiah 49 14 >LHJM/
# NOT IN MATCH_DICT Isaiah 49 24 <RJY/
# NOT IN MATCH_DICT Isaiah 49 25 MLQWX/
# NOT IN MATCH_DICT Isaiah 50 5 >LHJM/
# Isaiah 50 10 NGH/ NWGH
# NOT IN MATCH_DICT Isaiah 51 3 NS/
# NOT IN MATCH_DICT Isaiah 51 9 RXB==/
# NOT IN MATCH_DICT Isaiah 52 9 RNH/
# NOT IN MATCH_DICT Isaiah 52 12 >LHJM/
# NOT IN MATCH_DICT Isaiah 52 12 KL/
# NOT IN MATCH_DICT Isaiah 53 9 BMH/
# NOT IN MATCH_DICT Isaiah 54 9 <WD/
# NOT IN MATCH_DICT Isaiah 57 4 JLWD/
# NOT IN MATCH_DICT Isaiah 57 18 TNXWMJM/
# Isaiah 58 14 BMH/ BWMTJ
# NOT IN MATCH_DICT Isaiah 59 3 <WLH/
# NOT IN MATCH_DICT Isaiah 59 19 YWR/
# Isaiah 60 14 KL/ KWL
# Isaiah 60 19 NGH/ NWGH
# Isaiah 61 1 PQX_QWX/ PQXQWX
# NOT IN MATCH_DICT Isaiah 61 10 KHN/
# NOT IN MATCH_DICT Isaiah 61 11 >LHJM/
# NOT IN MATCH_DICT Isaiah 62 1 NGH/
# Isaiah 62 8 <WD/ <WD
# NOT IN MATCH_DICT Isaiah 62 9 >LHJM/
# NOT IN MATCH_DICT Isaiah 66 17 CQWY/
# NOT IN MATCH_DICT Isaiah 66 20 KL/
# NOT IN MATCH_DICT Isaiah 3 16 VPP[
# NOT IN MATCH_DICT Isaiah 6 3 QR>[
# NOT IN MATCH_DICT Isaiah 13 1 XZH[
# NOT IN MATCH_DICT Isaiah 14 2 RDH[
# NOT IN MATCH_DICT Isaiah 14 31 MDD[
# NOT IN MATCH_DICT Isaiah 18 2 BZ>[
# NOT IN MATCH_DICT Isaiah 18 7 BZ>[
# NOT IN MATCH_DICT Isaiah 21 4 T<H[
# NOT IN MATCH_DICT Isaiah 21 5 YPH=[
# NOT IN MATCH_DICT Isaiah 21 7 RKB[
# NOT IN MATCH_DICT Isaiah 21 9 RKB[
# NOT IN MATCH_DICT Isaiah 27 1 BRX[
# NOT IN MATCH_DICT Isaiah 27 7 HRG[
# NOT IN MATCH_DICT Isaiah 29 12 JD<[
# NOT IN MATCH_DICT Isaiah 32 6 XCB[
# NOT IN MATCH_DICT Isaiah 33 24 CKN[
# NOT IN MATCH_DICT Isaiah 34 4 NBL[
# NOT IN MATCH_DICT Isaiah 36 11 JCB[
# NOT IN MATCH_DICT Isaiah 41 2 NDP[
# NOT IN MATCH_DICT Isaiah 43 3 G>L[
# NOT IN MATCH_DICT Isaiah 43 28 GDP[
# NOT IN MATCH_DICT Isaiah 44 2 <ZR[
# NOT IN MATCH_DICT Isaiah 44 11 XBR[
# NOT IN MATCH_DICT Isaiah 44 12 CTH[
# NOT IN MATCH_DICT Isaiah 44 12 J<P[
# NOT IN MATCH_DICT Isaiah 45 8 >MR[
# NOT IN MATCH_DICT Isaiah 45 9 XRC=[
# NOT IN MATCH_DICT Isaiah 45 9 >MR[
# NOT IN MATCH_DICT Isaiah 45 16 XRC=[
# NOT IN MATCH_DICT Isaiah 46 3 <MS[
# NOT IN MATCH_DICT Isaiah 46 3 NF>[
# NOT IN MATCH_DICT Isaiah 47 9 XBR[
# NOT IN MATCH_DICT Isaiah 47 12 XBR[
# NOT IN MATCH_DICT Isaiah 47 13 XBR[
# Isaiah 48 14 >HB[ >WHBJ
# NOT IN MATCH_DICT Isaiah 49 17 BNH[
# NOT IN MATCH_DICT Isaiah 49 25 CBH[
# NOT IN MATCH_DICT Isaiah 51 9 MXY[
# NOT IN MATCH_DICT Isaiah 53 3 JD<[
# NOT IN MATCH_DICT Isaiah 54 13 BNH[
# NOT IN MATCH_DICT Isaiah 56 6 CMR[
# NOT IN MATCH_DICT Isaiah 56 10 YPH[
# NOT IN MATCH_DICT Isaiah 57 1 >BD[
# NOT IN MATCH_DICT Isaiah 57 12 QBY[
# NOT IN MATCH_DICT Isaiah 57 13 QBY[
# NOT IN MATCH_DICT Isaiah 62 4 CMM[
# NOT IN MATCH_DICT Isaiah 63 5 TMK[
# NOT IN MATCH_DICT Isaiah 64 9 CMM[
# NOT IN MATCH_DICT Isaiah 66 2 XRD[
# NOT IN MATCH_DICT Isaiah 3 16 NVH[
# NOT IN MATCH_DICT Isaiah 5 17 KBC[
# NOT IN MATCH_DICT Isaiah 10 4 >SR[
# NOT IN MATCH_DICT Isaiah 22 3 >SR[
# NOT IN MATCH_DICT Isaiah 37 26 NYR[
# NOT IN MATCH_DICT Isaiah 42 7 >SR[
# Isaiah 49 7 BZH[ BZWJ
# NOT IN MATCH_DICT Isaiah 51 11 PZR[
# NOT IN MATCH_DICT Isaiah 54 11 S<R[
# NOT IN MATCH_DICT Isaiah 66 19 MCK[
# NOT IN MATCH_DICT Isaiah 8 11 JSR[
# NOT IN MATCH_DICT Isaiah 15 2 JLL[
# NOT IN MATCH_DICT Isaiah 16 7 JLL[
# NOT IN MATCH_DICT Isaiah 16 7 JLL[
# NOT IN MATCH_DICT Isaiah 33 2 JC<[
# NOT IN MATCH_DICT Isaiah 37 33 JRH[
# NOT IN MATCH_DICT Isaiah 38 20 JDH[
# Isaiah 38 20 JC<[ HWCJ<NJ
# NOT IN MATCH_DICT Isaiah 41 2 JRD[
# NOT IN MATCH_DICT Isaiah 42 13 JD<[
# NOT IN MATCH_DICT Isaiah 45 22 JC<[
# NOT IN MATCH_DICT Isaiah 49 23 JNQ[
# NOT IN MATCH_DICT Isaiah 51 5 JXL[
# NOT IN MATCH_DICT Isaiah 52 5 JLL[
# NOT IN MATCH_DICT Isaiah 65 14 JLL[
# NOT IN MATCH_DICT Isaiah 24 19 PRR=[
# NOT IN MATCH_DICT Isaiah 37 30 NV<[
# NOT IN MATCH_DICT Isaiah 57 2 HLK[
# NOT IN MATCH_DICT Isaiah 22 10 BYR=[
# NOT IN MATCH_DICT Isaiah 44 19 >MR[
# NOT IN MATCH_DICT Isaiah 47 14 XMM[
# NOT IN MATCH_DICT Isaiah 55 10 >KL[
# NOT IN MATCH_DICT Isaiah 62 5 B<L[
# NOT IN MATCH_DICT Isaiah 66 16 CPV[
# NOT IN MATCH_DICT Isaiah 33 1 KLH[
# NOT IN MATCH_DICT Isaiah 56 6 HJH[
# 5998

# %%
hif_match_dict
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {(2020224, '4Q57'): defaultdict(int,
#                          {'MT': 215261, '1Qisaa': 1898158}),
#              (215261, 'MT'): defaultdict(int,
#                          {'4Q57': 2020224, '1Qisaa': 1898158}),
#              (2020248, '4Q57'): defaultdict(int,
#                          {'MT': 215285, '1Qisaa': 1898182}),
#              (215285, 'MT'): defaultdict(int,
#                          {'4Q57': 2020248, '1Qisaa': 1898182}),
#              (2020269, '4Q57'): defaultdict(int,
#                          {'MT': 215304, '1Qisaa': 1898203}),
#              (215304, 'MT'): defaultdict(int,
#                          {'4Q57': 2020269, '1Qisaa': 1898203}),
#              (2020288, '4Q57'): defaultdict(int,
#                          {'MT': 215322, '1Qisaa': 1898222}),
#              (215322, 'MT'): defaultdict(int,
#                          {'4Q57': 2020288, '1Qisaa': 1898222}),
#              (2020318, '4Q57'): defaultdict(int,
#                          {'MT': 215350, '1Qisaa': 1898252}),
#              (215350, 'MT'): defaultdict(int,
#                          {'4Q57': 2020318, '1Qisaa': 1898252}),
#              (2020322, '4Q57'): defaultdict(int,
#                          {'MT': 215353, '1Qisaa': 1898256, '4Q56': 2016774}),
#              (215353, 'MT'): defaultdict(int,
#                          {'4Q57': 2020322,
#                           '1Qisaa': 1898256,
#                           '4Q56': 2016774}),
#              (2020559, '4Q57'): defaultdict(int,
#                          {'MT': 216183, '1Qisaa': 1899137}),
#              (216183, 'MT'): defaultdict(int,
#                          {'4Q57': 2020559, '1Qisaa': 1899137}),
#              (2020572, '4Q57'): defaultdict(int,
#                          {'MT': 216195, '1Qisaa': 1899149}),
#              (216195, 'MT'): defaultdict(int,
#                          {'4Q57': 2020572, '1Qisaa': 1899149}),
#              (2020588, '4Q57'): defaultdict(int,
#                          {'MT': 216211, '1Qisaa': 1899166}),
#              (216211, 'MT'): defaultdict(int,
#                          {'4Q57': 2020588, '1Qisaa': 1899166}),
#              (2020593, '4Q57'): defaultdict(int,
#                          {'MT': 216216, '1Qisaa': 1899171}),
#              (216216, 'MT'): defaultdict(int,
#                          {'4Q57': 2020593, '1Qisaa': 1899171}),
#              (2020606, '4Q57'): defaultdict(int,
#                          {'MT': 216228, '1Qisaa': 1899183}),
#              (216228, 'MT'): defaultdict(int,
#                          {'4Q57': 2020606, '1Qisaa': 1899183}),
#              (2020641, '4Q57'): defaultdict(int,
#                          {'MT': 216263, '1Qisaa': 1899216}),
#              (216263, 'MT'): defaultdict(int,
#                          {'4Q57': 2020641, '1Qisaa': 1899216}),
#              (2020965, '4Q57'): defaultdict(int,
#                          {'MT': 219208, '1Qisaa': 1902302}),
#              (219208, 'MT'): defaultdict(int,
#                          {'4Q57': 2020965, '1Qisaa': 1902302}),
#              (2020988, '4Q57'): defaultdict(int,
#                          {'MT': 219350, '1Qisaa': 1902451, '4Q55': 2015757}),
#              (219350, 'MT'): defaultdict(int,
#                          {'4Q57': 2020988,
#                           '1Qisaa': 1902451,
#                           '4Q55': 2015757}),
#              (2021082, '4Q57'): defaultdict(int,
#                          {'MT': 219586, '1Qisaa': 1902701}),
#              (219586, 'MT'): defaultdict(int,
#                          {'4Q57': 2021082, '1Qisaa': 1902701}),
#              (2021166, '4Q57'): defaultdict(int,
#                          {'MT': 219665, '1Qisaa': 1902768}),
#              (219665, 'MT'): defaultdict(int,
#                          {'4Q57': 2021166, '1Qisaa': 1902768}),
#              (2021190, '4Q57'): defaultdict(int,
#                          {'MT': 219689, '1Qisaa': 1902791}),
#              (219689, 'MT'): defaultdict(int,
#                          {'4Q57': 2021190, '1Qisaa': 1902791}),
#              (2021211, '4Q57'): defaultdict(int,
#                          {'MT': 219710, '1Qisaa': 1902812}),
#              (219710, 'MT'): defaultdict(int,
#                          {'4Q57': 2021211, '1Qisaa': 1902812}),
#              (2021215, '4Q57'): defaultdict(int,
#                          {'MT': 219715, '1Qisaa': 1902816}),
#              (219715, 'MT'): defaultdict(int,
#                          {'4Q57': 2021215, '1Qisaa': 1902816}),
#              (2021259, '4Q57'): defaultdict(int,
#                          {'MT': 219764, '1Qisaa': 1902860}),
#              (219764, 'MT'): defaultdict(int,
#                          {'4Q57': 2021259, '1Qisaa': 1902860}),
#              (2021274, '4Q57'): defaultdict(int,
#                          {'MT': 219778, '1Qisaa': 1902875}),
#              (219778, 'MT'): defaultdict(int,
#                          {'4Q57': 2021274, '1Qisaa': 1902875}),
#              (2021300, '4Q57'): defaultdict(int,
#                          {'MT': 219801, '1Qisaa': 1902899}),
#              (219801, 'MT'): defaultdict(int,
#                          {'4Q57': 2021300, '1Qisaa': 1902899}),
#              (2021305, '4Q57'): defaultdict(int,
#                          {'MT': 219805, '1Qisaa': 1902903}),
#              (219805, 'MT'): defaultdict(int,
#                          {'4Q57': 2021305, '1Qisaa': 1902903}),
#              (2021311, '4Q57'): defaultdict(int,
#                          {'MT': 219810, '1Qisaa': 1902909}),
#              (219810, 'MT'): defaultdict(int,
#                          {'4Q57': 2021311, '1Qisaa': 1902909}),
#              (2021317, '4Q57'): defaultdict(int,
#                          {'MT': 219816, '1Qisaa': 1902915}),
#              (219816, 'MT'): defaultdict(int,
#                          {'4Q57': 2021317, '1Qisaa': 1902915}),
#              (2021333, '4Q57'): defaultdict(int,
#                          {'MT': 219831, '1Qisaa': 1902932}),
#              (219831, 'MT'): defaultdict(int,
#                          {'4Q57': 2021333, '1Qisaa': 1902932}),
#              (2021343, '4Q57'): defaultdict(int,
#                          {'MT': 219841, '1Qisaa': 1902942}),
#              (219841, 'MT'): defaultdict(int,
#                          {'4Q57': 2021343, '1Qisaa': 1902942}),
#              (2021345, '4Q57'): defaultdict(int,
#                          {'MT': 219843, '1Qisaa': 1902944}),
#              (219843, 'MT'): defaultdict(int,
#                          {'4Q57': 2021345, '1Qisaa': 1902944}),
#              (2021374, '4Q57'): defaultdict(int,
#                          {'MT': 219870, '1Qisaa': 1902972}),
#              (219870, 'MT'): defaultdict(int,
#                          {'4Q57': 2021374, '1Qisaa': 1902972}),
#              (2021377, '4Q57'): defaultdict(int,
#                          {'MT': 219873, '1Qisaa': 1902975}),
#              (219873, 'MT'): defaultdict(int,
#                          {'4Q57': 2021377, '1Qisaa': 1902975}),
#              (2021380, '4Q57'): defaultdict(int,
#                          {'MT': 219876, '1Qisaa': 1902978}),
#              (219876, 'MT'): defaultdict(int,
#                          {'4Q57': 2021380, '1Qisaa': 1902978}),
#              (2021384, '4Q57'): defaultdict(int,
#                          {'MT': 219879, '1Qisaa': 1902982}),
#              (219879, 'MT'): defaultdict(int,
#                          {'4Q57': 2021384, '1Qisaa': 1902982}),
#              (2021388, '4Q57'): defaultdict(int,
#                          {'MT': 219882, '1Qisaa': 1902985}),
#              (219882, 'MT'): defaultdict(int,
#                          {'4Q57': 2021388, '1Qisaa': 1902985}),
#              (2021612, '4Q57'): defaultdict(int,
#                          {'MT': 220291, '1Qisaa': 1903403}),
#              (220291, 'MT'): defaultdict(int,
#                          {'4Q57': 2021612, '1Qisaa': 1903403}),
#              (2021623, '4Q57'): defaultdict(int,
#                          {'MT': 220302, '1Qisaa': 1903414}),
#              (220302, 'MT'): defaultdict(int,
#                          {'4Q57': 2021623, '1Qisaa': 1903414}),
#              (2021625, '4Q57'): defaultdict(int,
#                          {'MT': 220304, '1Qisaa': 1903416}),
#              (220304, 'MT'): defaultdict(int,
#                          {'4Q57': 2021625, '1Qisaa': 1903416}),
#              (2021632, '4Q57'): defaultdict(int,
#                          {'MT': 220310, '1Qisaa': 1903423}),
#              (220310, 'MT'): defaultdict(int,
#                          {'4Q57': 2021632, '1Qisaa': 1903423}),
#              (2021634, '4Q57'): defaultdict(int,
#                          {'MT': 220312, '1Qisaa': 1903425}),
#              (220312, 'MT'): defaultdict(int,
#                          {'4Q57': 2021634, '1Qisaa': 1903425}),
#              (2021660, '4Q57'): defaultdict(int,
#                          {'MT': 220335, '1Qisaa': 1903450, '1Q8': 1920739}),
#              (220335, 'MT'): defaultdict(int,
#                          {'4Q57': 2021660, '1Qisaa': 1903450, '1Q8': 1920739}),
#              (2021680, '4Q57'): defaultdict(int,
#                          {'MT': 220354, '1Qisaa': 1903468}),
#              (220354, 'MT'): defaultdict(int,
#                          {'4Q57': 2021680, '1Qisaa': 1903468}),
#              (2021681, '4Q57'): defaultdict(int,
#                          {'MT': 220355, '1Qisaa': 1903469}),
#              (220355, 'MT'): defaultdict(int,
#                          {'4Q57': 2021681, '1Qisaa': 1903469}),
#              (2021767, '4Q57'): defaultdict(int,
#                          {'MT': 220954, '1Qisaa': 1904094}),
#              (220954, 'MT'): defaultdict(int,
#                          {'4Q57': 2021767, '1Qisaa': 1904094}),
#              (2021920, '4Q57'): defaultdict(int,
#                          {'MT': 221968, '1Qisaa': 1905161}),
#              (221968, 'MT'): defaultdict(int,
#                          {'4Q57': 2021920, '1Qisaa': 1905161}),
#              (2021948, '4Q57'): defaultdict(int,
#                          {'MT': 221993, '1Qisaa': 1905189, '1Q8': 1921064}),
#              (221993, 'MT'): defaultdict(int,
#                          {'4Q57': 2021948, '1Qisaa': 1905189, '1Q8': 1921064}),
#              (2022033, '4Q57'): defaultdict(int,
#                          {'MT': 222075, '1Qisaa': 1905274}),
#              (222075, 'MT'): defaultdict(int,
#                          {'4Q57': 2022033, '1Qisaa': 1905274}),
#              (2022092, '4Q57'): defaultdict(int,
#                          {'MT': 222991, '1Qisaa': 1906244}),
#              (222991, 'MT'): defaultdict(int,
#                          {'4Q57': 2022092, '1Qisaa': 1906244}),
#              (2022334, '4Q57'): defaultdict(int,
#                          {'MT': 227444, '1Qisaa': 1911000}),
#              (227444, 'MT'): defaultdict(int,
#                          {'4Q57': 2022334, '1Qisaa': 1911000}),
#              (2022444, '4Q57'): defaultdict(int,
#                          {'MT': 227941, '1Qisaa': 1911524, '1Q8': 1922916}),
#              (227941, 'MT'): defaultdict(int,
#                          {'4Q57': 2022444, '1Qisaa': 1911524, '1Q8': 1922916}),
#              (2022588, '4Q57'): defaultdict(int,
#                          {'MT': 228505,
#                           '4Q58': 2023926,
#                           '1Qisaa': 1912119,
#                           '1Q8': 1923238}),
#              (228505, 'MT'): defaultdict(int,
#                          {'4Q57': 2022588,
#                           '4Q58': 2023926,
#                           '1Qisaa': 1912119,
#                           '1Q8': 1923238}),
#              (2022604, '4Q57'): defaultdict(int,
#                          {'MT': 228520,
#                           '4Q58': 2023942,
#                           '1Qisaa': 1912136,
#                           '1Q8': 1923254}),
#              (228520, 'MT'): defaultdict(int,
#                          {'4Q57': 2022604,
#                           '4Q58': 2023942,
#                           '1Qisaa': 1912136,
#                           '1Q8': 1923254}),
#              (2022977, '4Q57'): defaultdict(int,
#                          {'MT': 230466, '1Qisaa': 1914195, '1Q8': 1924297}),
#              (230466, 'MT'): defaultdict(int,
#                          {'4Q57': 2022977, '1Qisaa': 1914195, '1Q8': 1924297}),
#              (2022978, '4Q57'): defaultdict(int,
#                          {'MT': 230467, '1Qisaa': 1914196, '1Q8': 1924298}),
#              (230467, 'MT'): defaultdict(int,
#                          {'4Q57': 2022978, '1Qisaa': 1914196, '1Q8': 1924298}),
#              (2023065, '4Q57'): defaultdict(int,
#                          {'MT': 230548, '1Qisaa': 1914294, '1Q8': 1924382}),
#              (230548, 'MT'): defaultdict(int,
#                          {'4Q57': 2023065, '1Qisaa': 1914294, '1Q8': 1924382}),
#              (2023229, '4Q57'): defaultdict(int,
#                          {'MT': 230898, '1Qisaa': 1914668}),
#              (230898, 'MT'): defaultdict(int,
#                          {'4Q57': 2023229, '1Qisaa': 1914668}),
#              (2023334, '4Q57'): defaultdict(int,
#                          {'MT': 230994, '1Qisaa': 1914769}),
#              (230994, 'MT'): defaultdict(int,
#                          {'4Q57': 2023334, '1Qisaa': 1914769}),
#              (2023385, '4Q57'): defaultdict(int, {'MT': 231042}),
#              (231042, 'MT'): defaultdict(int, {'4Q57': 2023385}),
#              (2023386, '4Q57'): defaultdict(int, {'MT': 231043}),
#              (231043, 'MT'): defaultdict(int, {'4Q57': 2023386}),
#              (2023449, '4Q57'): defaultdict(int,
#                          {'MT': 231106, '1Qisaa': 1914869}),
#              (231106, 'MT'): defaultdict(int,
#                          {'4Q57': 2023449, '1Qisaa': 1914869}),
#              (2023477, '4Q57'): defaultdict(int,
#                          {'MT': 231133, '1Qisaa': 1914898, '1Q8': 1924761}),
#              (231133, 'MT'): defaultdict(int,
#                          {'4Q57': 2023477, '1Qisaa': 1914898, '1Q8': 1924761}),
#              (2023497, '4Q57'): defaultdict(int,
#                          {'MT': 231152, '1Qisaa': 1914918, '1Q8': 1924782}),
#              (231152, 'MT'): defaultdict(int,
#                          {'4Q57': 2023497, '1Qisaa': 1914918, '1Q8': 1924782}),
#              (2023562, '4Q57'): defaultdict(int,
#                          {'MT': 234903, '1Qisaa': 1918833}),
#              (234903, 'MT'): defaultdict(int,
#                          {'4Q57': 2023562, '1Qisaa': 1918833}),
#              (2023585, '4Q57'): defaultdict(int,
#                          {'MT': 234926, '1Qisaa': 1918857}),
#              (234926, 'MT'): defaultdict(int,
#                          {'4Q57': 2023585, '1Qisaa': 1918857}),
#              (2020350, '4Q57'): defaultdict(int,
#                          {'MT': 215923, '1Qisaa': 1898858}),
#              (215923, 'MT'): defaultdict(int,
#                          {'4Q57': 2020350, '1Qisaa': 1898858}),
#              (2020999, '4Q57'): defaultdict(int,
#                          {'MT': 219509, '1Qisaa': 1902620, '4Q55': 2015925}),
#              (219509, 'MT'): defaultdict(int,
#                          {'4Q57': 2020999,
#                           '1Qisaa': 1902620,
#                           '4Q55': 2015925}),
#              (2021176, '4Q57'): defaultdict(int,
#                          {'MT': 219676, '1Qisaa': 1902778}),
#              (219676, 'MT'): defaultdict(int,
#                          {'4Q57': 2021176, '1Qisaa': 1902778}),
#              (2021194, '4Q57'): defaultdict(int,
#                          {'MT': 219692, '1Qisaa': 1902795}),
#              (219692, 'MT'): defaultdict(int,
#                          {'4Q57': 2021194, '1Qisaa': 1902795}),
#              (2021204, '4Q57'): defaultdict(int,
#                          {'MT': 219702, '1Qisaa': 1902805, '4Q60': 2027660}),
#              (219702, 'MT'): defaultdict(int,
#                          {'4Q57': 2021204,
#                           '1Qisaa': 1902805,
#                           '4Q60': 2027660}),
#              (2021221, '4Q57'): defaultdict(int,
#                          {'MT': 219724, '1Qisaa': 1902822, '4Q60': 2027677}),
#              (219724, 'MT'): defaultdict(int,
#                          {'4Q57': 2021221,
#                           '1Qisaa': 1902822,
#                           '4Q60': 2027677}),
#              (2021223, '4Q57'): defaultdict(int,
#                          {'MT': 219727, '1Qisaa': 1902824}),
#              (219727, 'MT'): defaultdict(int,
#                          {'4Q57': 2021223, '1Qisaa': 1902824}),
#              (2021229, '4Q57'): defaultdict(int,
#                          {'MT': 219736, '1Qisaa': 1902830}),
#              (219736, 'MT'): defaultdict(int,
#                          {'4Q57': 2021229, '1Qisaa': 1902830}),
#              (2021232, '4Q57'): defaultdict(int,
#                          {'MT': 219739, '1Qisaa': 1902833}),
#              (219739, 'MT'): defaultdict(int,
#                          {'4Q57': 2021232, '1Qisaa': 1902833}),
#              (2021269, '4Q57'): defaultdict(int,
#                          {'MT': 219773, '1Qisaa': 1902870}),
#              (219773, 'MT'): defaultdict(int,
#                          {'4Q57': 2021269, '1Qisaa': 1902870}),
#              (2021286, '4Q57'): defaultdict(int,
#                          {'MT': 219789, '1Qisaa': 1902886}),
#              (219789, 'MT'): defaultdict(int,
#                          {'4Q57': 2021286, '1Qisaa': 1902886}),
#              (2021291, '4Q57'): defaultdict(int,
#                          {'MT': 219794, '1Qisaa': 1902891}),
#              (219794, 'MT'): defaultdict(int,
#                          {'4Q57': 2021291, '1Qisaa': 1902891}),
#              (2021633, '4Q57'): defaultdict(int,
#                          {'MT': 220311, '1Qisaa': 1903424}),
#              (220311, 'MT'): defaultdict(int,
#                          {'4Q57': 2021633, '1Qisaa': 1903424}),
#              (2021659, '4Q57'): defaultdict(int,
#                          {'MT': 220334, '1Qisaa': 1903449, '1Q8': 1920738}),
#              (220334, 'MT'): defaultdict(int,
#                          {'4Q57': 2021659, '1Qisaa': 1903449, '1Q8': 1920738}),
#              (2022237, '4Q57'): defaultdict(int,
#                          {'MT': 223225, '1Qisaa': 1906490}),
#              (223225, 'MT'): defaultdict(int,
#                          {'4Q57': 2022237, '1Qisaa': 1906490}),
#              (2022350, '4Q57'): defaultdict(int, {'MT': 227459}),
#              (227459, 'MT'): defaultdict(int, {'4Q57': 2022350}),
#              (2022566, '4Q57'): defaultdict(int,
#                          {'MT': 228484, '1Qisaa': 1912097, '1Q8': 1923216}),
#              (228484, 'MT'): defaultdict(int,
#                          {'4Q57': 2022566, '1Qisaa': 1912097, '1Q8': 1923216}),
#              (2022917, '4Q57'): defaultdict(int,
#                          {'MT': 230141, '1Qisaa': 1913851}),
#              (230141, 'MT'): defaultdict(int,
#                          {'4Q57': 2022917, '1Qisaa': 1913851}),
#              (2022992, '4Q57'): defaultdict(int,
#                          {'MT': 230480, '1Qisaa': 1914211, '1Q8': 1924309}),
#              (230480, 'MT'): defaultdict(int,
#                          {'4Q57': 2022992, '1Qisaa': 1914211, '1Q8': 1924309}),
#              (2023007, '4Q57'): defaultdict(int,
#                          {'MT': 230494, '1Qisaa': 1914226, '1Q8': 1924324}),
#              (230494, 'MT'): defaultdict(int,
#                          {'4Q57': 2023007, '1Qisaa': 1914226, '1Q8': 1924324}),
#              (2023362, '4Q57'): defaultdict(int,
#                          {'MT': 231020, '1Qisaa': 1914797}),
#              (231020, 'MT'): defaultdict(int,
#                          {'4Q57': 2023362, '1Qisaa': 1914797}),
#              (2020594, '4Q57'): defaultdict(int,
#                          {'MT': 216217, '1Qisaa': 1899172}),
#              (216217, 'MT'): defaultdict(int,
#                          {'4Q57': 2020594, '1Qisaa': 1899172}),
#              (2021994, '4Q57'): defaultdict(int,
#                          {'MT': 222037, '1Qisaa': 1905235}),
#              (222037, 'MT'): defaultdict(int,
#                          {'4Q57': 2021994, '1Qisaa': 1905235}),
#              (2021049, '4Q57'): defaultdict(int,
#                          {'MT': 219554, '1Qisaa': 1902669}),
#              (219554, 'MT'): defaultdict(int,
#                          {'4Q57': 2021049, '1Qisaa': 1902669}),
#              (2021128, '4Q57'): defaultdict(int,
#                          {'MT': 219629, '1Qisaa': 1902731}),
#              (219629, 'MT'): defaultdict(int,
#                          {'4Q57': 2021128, '1Qisaa': 1902731}),
#              (2023367, '4Q57'): defaultdict(int,
#                          {'MT': 231025, '1Qisaa': 1914802}),
#              (231025, 'MT'): defaultdict(int,
#                          {'4Q57': 2023367, '1Qisaa': 1914802}),
#              (2023380, '4Q57'): defaultdict(int,
#                          {'MT': 231037, '1Qisaa': 1914814}),
#              (231037, 'MT'): defaultdict(int,
#                          {'4Q57': 2023380, '1Qisaa': 1914814}),
#              (2020949, '4Q57'): defaultdict(int,
#                          {'MT': 219193, '1Qisaa': 1902285}),
#              (219193, 'MT'): defaultdict(int,
#                          {'4Q57': 2020949, '1Qisaa': 1902285}),
#              (2020931, '4Q57'): defaultdict(int,
#                          {'MT': 219176, '1Qisaa': 1902267}),
#              (219176, 'MT'): defaultdict(int,
#                          {'4Q57': 2020931, '1Qisaa': 1902267}),
#              (2021052, '4Q57'): defaultdict(int,
#                          {'MT': 219557, '1Qisaa': 1902672, '4Q55': 2015976}),
#              (219557, 'MT'): defaultdict(int,
#                          {'4Q57': 2021052,
#                           '1Qisaa': 1902672,
#                           '4Q55': 2015976}),
#              (2023262, '4Q57'): defaultdict(int,
#                          {'MT': 230925, '4Q58': 2024939, '1Qisaa': 1914697}),
#              (230925, 'MT'): defaultdict(int,
#                          {'4Q57': 2023262,
#                           '4Q58': 2024939,
#                           '1Qisaa': 1914697}),
#              (2021586, '4Q57'): defaultdict(int,
#                          {'MT': 220265, '1Qisaa': 1903377}),
#              (220265, 'MT'): defaultdict(int,
#                          {'4Q57': 2021586, '1Qisaa': 1903377}),
#              (2021036, '4Q57'): defaultdict(int,
#                          {'MT': 219542, '1Qisaa': 1902656, '4Q55': 2015960}),
#              (219542, 'MT'): defaultdict(int,
#                          {'4Q57': 2021036,
#                           '1Qisaa': 1902656,
#                           '4Q55': 2015960}),
#              (2021588, '4Q57'): defaultdict(int,
#                          {'MT': 220267, '1Qisaa': 1903379}),
#              (220267, 'MT'): defaultdict(int,
#                          {'4Q57': 2021588, '1Qisaa': 1903379}),
#              (2021599, '4Q57'): defaultdict(int,
#                          {'MT': 220277, '1Qisaa': 1903390}),
#              (220277, 'MT'): defaultdict(int,
#                          {'4Q57': 2021599, '1Qisaa': 1903390}),
#              (2021600, '4Q57'): defaultdict(int,
#                          {'MT': 220278, '1Qisaa': 1903391}),
#              (220278, 'MT'): defaultdict(int,
#                          {'4Q57': 2021600, '1Qisaa': 1903391}),
#              (2023017, '4Q57'): defaultdict(int,
#                          {'MT': 230503, '1Qisaa': 1914241, '1Q8': 1924334}),
#              (230503, 'MT'): defaultdict(int,
#                          {'4Q57': 2023017, '1Qisaa': 1914241, '1Q8': 1924334}),
#              (2028211, '4Q61'): defaultdict(int,
#                          {'MT': 226864, '1Qisaa': 1910379}),
#              (226864, 'MT'): defaultdict(int,
#                          {'4Q61': 2028211, '1Qisaa': 1910379}),
#              (2028362, '4Q61'): defaultdict(int,
#                          {'MT': 227010, '1Qisaa': 1910534, '1Q8': 1922427}),
#              (227010, 'MT'): defaultdict(int,
#                          {'4Q61': 2028362, '1Qisaa': 1910534, '1Q8': 1922427}),
#              (2028429, '4Q61'): defaultdict(int,
#                          {'MT': 227255, '1Qisaa': 1910791, '1Q8': 1922606}),
#              (227255, 'MT'): defaultdict(int,
#                          {'4Q61': 2028429, '1Qisaa': 1910791, '1Q8': 1922606}),
#              (2028456, '4Q61'): defaultdict(int,
#                          {'MT': 227279, '1Qisaa': 1910821, '1Q8': 1922633}),
#              (227279, 'MT'): defaultdict(int,
#                          {'4Q61': 2028456, '1Qisaa': 1910821, '1Q8': 1922633}),
#              (2028469, '4Q61'): defaultdict(int,
#                          {'MT': 227292, '1Qisaa': 1910836, '1Q8': 1922646}),
#              (227292, 'MT'): defaultdict(int,
#                          {'4Q61': 2028469, '1Qisaa': 1910836, '1Q8': 1922646}),
#              (2028160, '4Q61'): defaultdict(int,
#                          {'MT': 226816, '1Qisaa': 1910327}),
#              (226816, 'MT'): defaultdict(int,
#                          {'4Q61': 2028160, '1Qisaa': 1910327}),
#              (2028118, '4Q61'): defaultdict(int,
#                          {'MT': 226774, '1Qisaa': 1910284}),
#              (226774, 'MT'): defaultdict(int,
#                          {'4Q61': 2028118, '1Qisaa': 1910284}),
#              (2028231, '4Q61'): defaultdict(int,
#                          {'MT': 226883, '1Qisaa': 1910401}),
#              (226883, 'MT'): defaultdict(int,
#                          {'4Q61': 2028231, '1Qisaa': 1910401}),
#              (2023926, '4Q58'): defaultdict(int,
#                          {'MT': 228505,
#                           '4Q57': 2022588,
#                           '1Qisaa': 1912119,
#                           '1Q8': 1923238}),
#              (2023942, '4Q58'): defaultdict(int,
#                          {'MT': 228520,
#                           '4Q57': 2022604,
#                           '1Qisaa': 1912136,
#                           '1Q8': 1923254}),
#              (2024009, '4Q58'): defaultdict(int,
#                          {'MT': 228584, '1Qisaa': 1912206, '1Q8': 1923321}),
#              (228584, 'MT'): defaultdict(int,
#                          {'4Q58': 2024009, '1Qisaa': 1912206, '1Q8': 1923321}),
#              (2024065, '4Q58'): defaultdict(int,
#                          {'MT': 228671, '1Qisaa': 1912299, '1Q8': 1923412}),
#              (228671, 'MT'): defaultdict(int,
#                          {'4Q58': 2024065, '1Qisaa': 1912299, '1Q8': 1923412}),
#              (2024117, '4Q58'): defaultdict(int,
#                          {'MT': 228965, '1Qisaa': 1912611}),
#              (228965, 'MT'): defaultdict(int,
#                          {'4Q58': 2024117, '1Qisaa': 1912611}),
#              (2024152, '4Q58'): defaultdict(int,
#                          {'MT': 228997, '1Qisaa': 1912647}),
#              (228997, 'MT'): defaultdict(int,
#                          {'4Q58': 2024152, '1Qisaa': 1912647}),
#              (2024211, '4Q58'): defaultdict(int,
#                          {'MT': 229054, '1Qisaa': 1912710}),
#              (229054, 'MT'): defaultdict(int,
#                          {'4Q58': 2024211, '1Qisaa': 1912710}),
#              (2024228, '4Q58'): defaultdict(int,
#                          {'MT': 229071, '1Qisaa': 1912730, '1Q8': 1923559}),
#              (229071, 'MT'): defaultdict(int,
#                          {'4Q58': 2024228, '1Qisaa': 1912730, '1Q8': 1923559}),
#              (2024287, '4Q58'): defaultdict(int,
#                          {'MT': 229128, '1Qisaa': 1912789, '1Q8': 1923618}),
#              (229128, 'MT'): defaultdict(int,
#                          {'4Q58': 2024287, '1Qisaa': 1912789, '1Q8': 1923618}),
#              (2024369, '4Q58'): defaultdict(int,
#                          {'MT': 229205, '1Qisaa': 1912874}),
#              (229205, 'MT'): defaultdict(int,
#                          {'4Q58': 2024369, '1Qisaa': 1912874}),
#              (2024372, '4Q58'): defaultdict(int,
#                          {'MT': 229207, '1Qisaa': 1912876, '1Q8': 1923701}),
#              (229207, 'MT'): defaultdict(int,
#                          {'4Q58': 2024372, '1Qisaa': 1912876, '1Q8': 1923701}),
#              (2024437, '4Q58'): defaultdict(int,
#                          {'MT': 229269, '1Qisaa': 1912942}),
#              (229269, 'MT'): defaultdict(int,
#                          {'4Q58': 2024437, '1Qisaa': 1912942}),
#              (2024498, '4Q58'): defaultdict(int,
#                          {'MT': 229329, '1Qisaa': 1913003}),
#              (229329, 'MT'): defaultdict(int,
#                          {'4Q58': 2024498, '1Qisaa': 1913003}),
#              (2024562, '4Q58'): defaultdict(int,
#                          {'MT': 229394, '1Qisaa': 1913073}),
#              (229394, 'MT'): defaultdict(int,
#                          {'4Q58': 2024562, '1Qisaa': 1913073}),
#              (2024621, '4Q58'): defaultdict(int,
#                          {'MT': 230373, '1Qisaa': 1914093}),
#              (230373, 'MT'): defaultdict(int,
#                          {'4Q58': 2024621, '1Qisaa': 1914093}),
#              (2024669, '4Q58'): defaultdict(int,
#                          {'MT': 230418, '1Qisaa': 1914139}),
#              (230418, 'MT'): defaultdict(int,
#                          {'4Q58': 2024669, '1Qisaa': 1914139}),
#              (2024746, '4Q58'): defaultdict(int,
#                          {'MT': 230740, '1Qisaa': 1914500}),
#              (230740, 'MT'): defaultdict(int,
#                          {'4Q58': 2024746, '1Qisaa': 1914500}),
#              (2024763, '4Q58'): defaultdict(int,
#                          {'MT': 230757, '1Qisaa': 1914517, '1Q8': 1924598}),
#              (230757, 'MT'): defaultdict(int,
#                          {'4Q58': 2024763, '1Qisaa': 1914517, '1Q8': 1924598}),
#              (2024792, '4Q58'): defaultdict(int,
#                          {'MT': 230786, '1Qisaa': 1914546, '1Q8': 1924626}),
#              (230786, 'MT'): defaultdict(int,
#                          {'4Q58': 2024792, '1Qisaa': 1914546, '1Q8': 1924626}),
#              (2024808, '4Q58'): defaultdict(int,
#                          {'MT': 230801, '1Qisaa': 1914563}),
#              (230801, 'MT'): defaultdict(int,
#                          {'4Q58': 2024808, '1Qisaa': 1914563}),
#              (2024811, '4Q58'): defaultdict(int,
#                          {'MT': 230804, '1Qisaa': 1914566}),
#              (230804, 'MT'): defaultdict(int,
#                          {'4Q58': 2024811, '1Qisaa': 1914566}),
#              (2024848, '4Q58'): defaultdict(int,
#                          {'MT': 230839, '1Qisaa': 1914604}),
#              (230839, 'MT'): defaultdict(int,
#                          {'4Q58': 2024848, '1Qisaa': 1914604}),
#              (2024892, '4Q58'): defaultdict(int,
#                          {'MT': 230880, '1Qisaa': 1914649}),
#              (230880, 'MT'): defaultdict(int,
#                          {'4Q58': 2024892, '1Qisaa': 1914649}),
#              (2024906, '4Q58'): defaultdict(int,
#                          {'MT': 230893, '1Qisaa': 1914663}),
#              (230893, 'MT'): defaultdict(int,
#                          {'4Q58': 2024906, '1Qisaa': 1914663}),
#              (2024991, '4Q58'): defaultdict(int,
#                          {'MT': 231700, '1Qisaa': 1915503}),
#              (231700, 'MT'): defaultdict(int,
#                          {'4Q58': 2024991, '1Qisaa': 1915503}),
#              (2025036, '4Q58'): defaultdict(int,
#                          {'MT': 231744, '1Qisaa': 1915551}),
#              (231744, 'MT'): defaultdict(int,
#                          {'4Q58': 2025036, '1Qisaa': 1915551}),
#              (2025055, '4Q58'): defaultdict(int, {'MT': 231761}),
#              (231761, 'MT'): defaultdict(int, {'4Q58': 2025055}),
#              (2025058, '4Q58'): defaultdict(int,
#                          {'MT': 231764, '1Qisaa': 1915574}),
#              (231764, 'MT'): defaultdict(int,
#                          {'4Q58': 2025058, '1Qisaa': 1915574}),
#              (2025072, '4Q58'): defaultdict(int,
#                          {'MT': 231778, '1Qisaa': 1915588}),
#              (231778, 'MT'): defaultdict(int,
#                          {'4Q58': 2025072, '1Qisaa': 1915588}),
#              (2025081, '4Q58'): defaultdict(int,
#                          {'MT': 231786, '1Qisaa': 1915599}),
#              (231786, 'MT'): defaultdict(int,
#                          {'4Q58': 2025081, '1Qisaa': 1915599}),
#              (2025095, '4Q58'): defaultdict(int,
#                          {'MT': 231799, '1Qisaa': 1915613}),
#              (231799, 'MT'): defaultdict(int,
#                          {'4Q58': 2025095, '1Qisaa': 1915613}),
#              (2025097, '4Q58'): defaultdict(int,
#                          {'MT': 231801, '1Qisaa': 1915616}),
#              (231801, 'MT'): defaultdict(int,
#                          {'4Q58': 2025097, '1Qisaa': 1915616}),
#              (2025099, '4Q58'): defaultdict(int,
#                          {'MT': 231803, '1Qisaa': 1915619}),
#              (231803, 'MT'): defaultdict(int,
#                          {'4Q58': 2025099, '1Qisaa': 1915619}),
#              (2025162, '4Q58'): defaultdict(int,
#                          {'MT': 231867, '1Qisaa': 1915686}),
#              (231867, 'MT'): defaultdict(int,
#                          {'4Q58': 2025162, '1Qisaa': 1915686}),
#              (2025197, '4Q58'): defaultdict(int,
#                          {'MT': 231902, '1Qisaa': 1915723}),
#              (231902, 'MT'): defaultdict(int,
#                          {'4Q58': 2025197, '1Qisaa': 1915723}),
#              (2025199, '4Q58'): defaultdict(int,
#                          {'MT': 231904, '1Qisaa': 1915725, '1Q8': 1925324}),
#              (231904, 'MT'): defaultdict(int,
#                          {'4Q58': 2025199, '1Qisaa': 1915725, '1Q8': 1925324}),
#              (2025211, '4Q58'): defaultdict(int,
#                          {'MT': 231917, '1Qisaa': 1915737, '1Q8': 1925338}),
#              (231917, 'MT'): defaultdict(int,
#                          {'4Q58': 2025211, '1Qisaa': 1915737, '1Q8': 1925338}),
#              (2023880, '4Q58'): defaultdict(int,
#                          {'MT': 228231, '1Qisaa': 1911833}),
#              (228231, 'MT'): defaultdict(int,
#                          {'4Q58': 2023880, '1Qisaa': 1911833}),
#              (2023896, '4Q58'): defaultdict(int,
#                          {'MT': 228477, '1Qisaa': 1912089, '1Q8': 1923208}),
#              (228477, 'MT'): defaultdict(int,
#                          {'4Q58': 2023896, '1Qisaa': 1912089, '1Q8': 1923208}),
#              (2024028, '4Q58'): defaultdict(int,
#                          {'MT': 228633, '1Qisaa': 1912260}),
#              (228633, 'MT'): defaultdict(int,
#                          {'4Q58': 2024028, '1Qisaa': 1912260}),
#              (2024144, '4Q58'): defaultdict(int,
#                          {'MT': 228991, '1Qisaa': 1912639}),
#              (228991, 'MT'): defaultdict(int,
#                          {'4Q58': 2024144, '1Qisaa': 1912639}),
#              (2024670, '4Q58'): defaultdict(int,
#                          {'MT': 230419, '1Qisaa': 1914140}),
#              (230419, 'MT'): defaultdict(int,
#                          {'4Q58': 2024670, '1Qisaa': 1914140}),
#              (2024774, '4Q58'): defaultdict(int,
#                          {'MT': 230769, '1Qisaa': 1914528}),
#              (230769, 'MT'): defaultdict(int,
#                          {'4Q58': 2024774, '1Qisaa': 1914528}),
#              (2025065, '4Q58'): defaultdict(int,
#                          {'MT': 231771, '1Qisaa': 1915581}),
#              (231771, 'MT'): defaultdict(int,
#                          {'4Q58': 2025065, '1Qisaa': 1915581}),
#              (2025164, '4Q58'): defaultdict(int,
#                          {'MT': 231868, '1Qisaa': 1915689}),
#              (231868, 'MT'): defaultdict(int,
#                          {'4Q58': 2025164, '1Qisaa': 1915689}),
#              (2024337, '4Q58'): defaultdict(int,
#                          {'MT': 229175, '1Qisaa': 1912840, '1Q8': 1923667}),
#              (229175, 'MT'): defaultdict(int,
#                          {'4Q58': 2024337, '1Qisaa': 1912840, '1Q8': 1923667}),
#              (2024803, '4Q58'): defaultdict(int,
#                          {'MT': 230797, '1Qisaa': 1914558, '1Q8': 1924637}),
#              (230797, 'MT'): defaultdict(int,
#                          {'4Q58': 2024803, '1Qisaa': 1914558, '1Q8': 1924637}),
#              (2024877, '4Q58'): defaultdict(int,
#                          {'MT': 230866, '1Qisaa': 1914633, '1Q8': 1924709}),
#              (230866, 'MT'): defaultdict(int,
#                          {'4Q58': 2024877, '1Qisaa': 1914633, '1Q8': 1924709}),
#              (2024879, '4Q58'): defaultdict(int,
#                          {'MT': 230868, '1Qisaa': 1914635, '1Q8': 1924711}),
#              (230868, 'MT'): defaultdict(int,
#                          {'4Q58': 2024879, '1Qisaa': 1914635, '1Q8': 1924711}),
#              (2023964, '4Q58'): defaultdict(int,
#                          {'MT': 228542, '1Qisaa': 1912160}),
#              (228542, 'MT'): defaultdict(int,
#                          {'4Q58': 2023964, '1Qisaa': 1912160}),
#              (2024214, '4Q58'): defaultdict(int,
#                          {'MT': 229057, '1Qisaa': 1912713, '1Q8': 1923544}),
#              (229057, 'MT'): defaultdict(int,
#                          {'4Q58': 2024214, '1Qisaa': 1912713, '1Q8': 1923544}),
#              (2024268, '4Q58'): defaultdict(int,
#                          {'MT': 229110, '1Q8': 1923599}),
#              (229110, 'MT'): defaultdict(int,
#                          {'4Q58': 2024268, '1Q8': 1923599}),
#              (2025005, '4Q58'): defaultdict(int,
#                          {'MT': 231714, '1Qisaa': 1915518}),
#              (231714, 'MT'): defaultdict(int,
#                          {'4Q58': 2025005, '1Qisaa': 1915518}),
#              (2025050, '4Q58'): defaultdict(int,
#                          {'MT': 231757, '1Qisaa': 1915565}),
#              (231757, 'MT'): defaultdict(int,
#                          {'4Q58': 2025050, '1Qisaa': 1915565}),
#              (2025327, '4Q58'): defaultdict(int,
#                          {'MT': 232048, '1Qisaa': 1915874, '1Q8': 1925470}),
#              (232048, 'MT'): defaultdict(int,
#                          {'4Q58': 2025327, '1Qisaa': 1915874, '1Q8': 1925470}),
#              (2024939, '4Q58'): defaultdict(int,
#                          {'MT': 230925, '4Q57': 2023262, '1Qisaa': 1914697}),
#              (2024192, '4Q58'): defaultdict(int,
#                          {'MT': 229036, '1Qisaa': 1912691}),
#              (229036, 'MT'): defaultdict(int,
#                          {'4Q58': 2024192, '1Qisaa': 1912691}),
#              (2024406, '4Q58'): defaultdict(int,
#                          {'MT': 229239, '1Qisaa': 1912910}),
#              (229239, 'MT'): defaultdict(int,
#                          {'4Q58': 2024406, '1Qisaa': 1912910}),
#              (2024425, '4Q58'): defaultdict(int,
#                          {'MT': 229258, '1Qisaa': 1912929}),
#              (229258, 'MT'): defaultdict(int,
#                          {'4Q58': 2024425, '1Qisaa': 1912929}),
#              (2024097, '4Q58'): defaultdict(int,
#                          {'MT': 228947, '1Qisaa': 1912591}),
#              (228947, 'MT'): defaultdict(int,
#                          {'4Q58': 2024097, '1Qisaa': 1912591}),
#              (2024157, '4Q58'): defaultdict(int,
#                          {'MT': 229002, '1Qisaa': 1912653}),
#              (229002, 'MT'): defaultdict(int,
#                          {'4Q58': 2024157, '1Qisaa': 1912653}),
#              (2024177, '4Q58'): defaultdict(int,
#                          {'MT': 229021, '1Qisaa': 1912674}),
#              (229021, 'MT'): defaultdict(int,
#                          {'4Q58': 2024177, '1Qisaa': 1912674}),
#              (2024215, '4Q58'): defaultdict(int,
#                          {'MT': 229058, '1Qisaa': 1912714, '1Q8': 1923545}),
#              (229058, 'MT'): defaultdict(int,
#                          {'4Q58': 2024215, '1Qisaa': 1912714, '1Q8': 1923545}),
#              (2024284, '4Q58'): defaultdict(int,
#                          {'MT': 229125, '1Qisaa': 1912786}),
#              (229125, 'MT'): defaultdict(int,
#                          {'4Q58': 2024284, '1Qisaa': 1912786}),
#              (2024288, '4Q58'): defaultdict(int,
#                          {'MT': 229129, '1Q8': 1923619}),
#              (229129, 'MT'): defaultdict(int,
#                          {'4Q58': 2024288, '1Q8': 1923619}),
#              (2024320, '4Q58'): defaultdict(int,
#                          {'MT': 229159, '1Qisaa': 1912821, '1Q8': 1923650}),
#              (229159, 'MT'): defaultdict(int,
#                          {'4Q58': 2024320, '1Qisaa': 1912821, '1Q8': 1923650}),
#              (2024340, '4Q58'): defaultdict(int,
#                          {'MT': 229178, '1Qisaa': 1912845, '1Q8': 1923670}),
#              (229178, 'MT'): defaultdict(int,
#                          {'4Q58': 2024340, '1Qisaa': 1912845, '1Q8': 1923670}),
#              (2024727, '4Q58'): defaultdict(int,
#                          {'MT': 230724, '1Qisaa': 1914480}),
#              (230724, 'MT'): defaultdict(int,
#                          {'4Q58': 2024727, '1Qisaa': 1914480}),
#              (2024745, '4Q58'): defaultdict(int,
#                          {'MT': 230739, '1Qisaa': 1914499}),
#              (230739, 'MT'): defaultdict(int,
#                          {'4Q58': 2024745, '1Qisaa': 1914499}),
#              (2024807, '4Q58'): defaultdict(int,
#                          {'MT': 230800, '1Qisaa': 1914562, '1Q8': 1924641}),
#              (230800, 'MT'): defaultdict(int,
#                          {'4Q58': 2024807, '1Qisaa': 1914562, '1Q8': 1924641}),
#              (2024816, '4Q58'): defaultdict(int,
#                          {'MT': 230809, '1Qisaa': 1914572, '1Q8': 1924650}),
#              (230809, 'MT'): defaultdict(int,
#                          {'4Q58': 2024816, '1Qisaa': 1914572, '1Q8': 1924650}),
#              (2025043, '4Q58'): defaultdict(int,
#                          {'MT': 231750, '1Qisaa': 1915558}),
#              (231750, 'MT'): defaultdict(int,
#                          {'4Q58': 2025043, '1Qisaa': 1915558}),
#              (2025054, '4Q58'): defaultdict(int,
#                          {'MT': 231760, '1Qisaa': 1915570}),
#              (231760, 'MT'): defaultdict(int,
#                          {'4Q58': 2025054, '1Qisaa': 1915570}),
#              (2090814, 'Mur3'): defaultdict(int,
#                          {'MT': 212138, '1Qisaa': 1894931}),
#              (212138, 'MT'): defaultdict(int,
#                          {'Mur3': 2090814, '1Qisaa': 1894931}),
#              (2090822, 'Mur3'): defaultdict(int,
#                          {'MT': 212145, '1Qisaa': 1894939}),
#              (212145, 'MT'): defaultdict(int,
#                          {'Mur3': 2090822, '1Qisaa': 1894939}),
#              (2090879, 'Mur3'): defaultdict(int,
#                          {'MT': 212200, '1Qisaa': 1894997}),
#              (212200, 'MT'): defaultdict(int,
#                          {'Mur3': 2090879, '1Qisaa': 1894997}),
#              (1894902, '1Qisaa'): defaultdict(int, {'MT': 212111}),
#              (212111, 'MT'): defaultdict(int, {'1Qisaa': 1894902}),
#              (1894918, '1Qisaa'): defaultdict(int, {'MT': 212125}),
#              (212125, 'MT'): defaultdict(int, {'1Qisaa': 1894918}),
#              (1894928, '1Qisaa'): defaultdict(int, {'MT': 212135}),
#              (212135, 'MT'): defaultdict(int, {'1Qisaa': 1894928}),
#              (1894931, '1Qisaa'): defaultdict(int,
#                          {'MT': 212138, 'Mur3': 2090814}),
#              (1894936, '1Qisaa'): defaultdict(int, {'MT': 212142}),
#              (212142, 'MT'): defaultdict(int, {'1Qisaa': 1894936}),
#              (1894939, '1Qisaa'): defaultdict(int,
#                          {'MT': 212145, 'Mur3': 2090822}),
#              (1894942, '1Qisaa'): defaultdict(int,
#                          {'MT': 212148, '4Q63': 2028797}),
#              (212148, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1894942, '4Q63': 2028797}),
#              (1894944, '1Qisaa'): defaultdict(int, {'MT': 212150}),
#              (212150, 'MT'): defaultdict(int, {'1Qisaa': 1894944}),
#              (1894959, '1Qisaa'): defaultdict(int,
#                          {'MT': 212164, '4Q56': 2016111}),
#              (212164, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1894959, '4Q56': 2016111}),
#              (1894997, '1Qisaa'): defaultdict(int,
#                          {'MT': 212200, 'Mur3': 2090879}),
#              (1895032, '1Qisaa'): defaultdict(int, {'MT': 212231}),
#              (212231, 'MT'): defaultdict(int, {'1Qisaa': 1895032}),
#              (1895038, '1Qisaa'): defaultdict(int, {'MT': 212236}),
#              (212236, 'MT'): defaultdict(int, {'1Qisaa': 1895038}),
#              (1895043, '1Qisaa'): defaultdict(int, {'MT': 212241}),
#              (212241, 'MT'): defaultdict(int, {'1Qisaa': 1895043}),
#              (1895054, '1Qisaa'): defaultdict(int, {'MT': 212252}),
#              (212252, 'MT'): defaultdict(int, {'1Qisaa': 1895054}),
#              (1895079, '1Qisaa'): defaultdict(int, {'MT': 212273}),
#              (212273, 'MT'): defaultdict(int, {'1Qisaa': 1895079}),
#              (1895082, '1Qisaa'): defaultdict(int, {'MT': 212276}),
#              (212276, 'MT'): defaultdict(int, {'1Qisaa': 1895082}),
#              (1895093, '1Qisaa'): defaultdict(int, {'MT': 212286}),
#              (212286, 'MT'): defaultdict(int, {'1Qisaa': 1895093}),
#              (1895095, '1Qisaa'): defaultdict(int, {'MT': 212288}),
#              (212288, 'MT'): defaultdict(int, {'1Qisaa': 1895095}),
#              (1895130, '1Qisaa'): defaultdict(int, {'MT': 212316}),
#              (212316, 'MT'): defaultdict(int, {'1Qisaa': 1895130}),
#              (1895145, '1Qisaa'): defaultdict(int, {'MT': 212330}),
#              (212330, 'MT'): defaultdict(int, {'1Qisaa': 1895145}),
#              (1895211, '1Qisaa'): defaultdict(int, {'MT': 212394}),
#              (212394, 'MT'): defaultdict(int, {'1Qisaa': 1895211}),
#              (1895222, '1Qisaa'): defaultdict(int, {'MT': 212405}),
#              (212405, 'MT'): defaultdict(int, {'1Qisaa': 1895222}),
#              (1895224, '1Qisaa'): defaultdict(int, {'MT': 212407}),
#              (212407, 'MT'): defaultdict(int, {'1Qisaa': 1895224}),
#              (1895226, '1Qisaa'): defaultdict(int, {'MT': 212410}),
#              (212410, 'MT'): defaultdict(int, {'1Qisaa': 1895226}),
#              (1895227, '1Qisaa'): defaultdict(int, {'MT': 212411}),
#              (212411, 'MT'): defaultdict(int, {'1Qisaa': 1895227}),
#              (1895239, '1Qisaa'): defaultdict(int, {'MT': 212421}),
#              (212421, 'MT'): defaultdict(int, {'1Qisaa': 1895239}),
#              (1895241, '1Qisaa'): defaultdict(int, {'MT': 212423}),
#              (212423, 'MT'): defaultdict(int, {'1Qisaa': 1895241}),
#              (1895264, '1Qisaa'): defaultdict(int, {'MT': 212445}),
#              (212445, 'MT'): defaultdict(int, {'1Qisaa': 1895264}),
#              (1895267, '1Qisaa'): defaultdict(int,
#                          {'MT': 212448, '4Q60': 2026769}),
#              (212448, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1895267, '4Q60': 2026769}),
#              (1895304, '1Qisaa'): defaultdict(int, {'MT': 212484}),
#              (212484, 'MT'): defaultdict(int, {'1Qisaa': 1895304}),
#              (1895314, '1Qisaa'): defaultdict(int, {'MT': 212493}),
#              (212493, 'MT'): defaultdict(int, {'1Qisaa': 1895314}),
#              (1895344, '1Qisaa'): defaultdict(int, {'MT': 212521}),
#              (212521, 'MT'): defaultdict(int, {'1Qisaa': 1895344}),
#              (1895346, '1Qisaa'): defaultdict(int, {'MT': 212523}),
#              (212523, 'MT'): defaultdict(int, {'1Qisaa': 1895346}),
#              (1895390, '1Qisaa'): defaultdict(int,
#                          {'MT': 212566, '4Q59': 2025384, '4Q60': 2026895}),
#              (212566, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1895390,
#                           '4Q59': 2025384,
#                           '4Q60': 2026895}),
#              (1895405, '1Qisaa'): defaultdict(int,
#                          {'MT': 212583, '4Q59': 2025403}),
#              (212583, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1895405, '4Q59': 2025403}),
#              (1895414, '1Qisaa'): defaultdict(int,
#                          {'MT': 212592, '4Q59': 2025412}),
#              (212592, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1895414, '4Q59': 2025412}),
#              (1895459, '1Qisaa'): defaultdict(int, {'MT': 212631}),
#              (212631, 'MT'): defaultdict(int, {'1Qisaa': 1895459}),
#              (1895487, '1Qisaa'): defaultdict(int, {'MT': 212658}),
#              (212658, 'MT'): defaultdict(int, {'1Qisaa': 1895487}),
#              (1895500, '1Qisaa'): defaultdict(int, {'MT': 212670}),
# ...
#                          {'1Qisaa': 1898415, '4Q59': 2025818}),
#              (1898432, '1Qisaa'): defaultdict(int,
#                          {'MT': 215516, '4Q59': 2025833}),
#              (215516, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1898432, '4Q59': 2025833}),
#              (1898438, '1Qisaa'): defaultdict(int,
#                          {'MT': 215522, '4Q59': 2025839}),
#              (215522, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1898438, '4Q59': 2025839}),
#              (1898444, '1Qisaa'): defaultdict(int, {'MT': 215528}),
#              (215528, 'MT'): defaultdict(int, {'1Qisaa': 1898444}),
#              (1898468, '1Qisaa'): defaultdict(int, {'MT': 215551}),
#              (215551, 'MT'): defaultdict(int, {'1Qisaa': 1898468}),
#              (1898476, '1Qisaa'): defaultdict(int, {'MT': 215558}),
#              (215558, 'MT'): defaultdict(int, {'1Qisaa': 1898476}),
#              (1898479, '1Qisaa'): defaultdict(int, {'MT': 215561}),
#              (215561, 'MT'): defaultdict(int, {'1Qisaa': 1898479}),
#              (1898491, '1Qisaa'): defaultdict(int, {'MT': 215573}),
#              (215573, 'MT'): defaultdict(int, {'1Qisaa': 1898491}),
#              (1898503, '1Qisaa'): defaultdict(int, {'MT': 215583}),
#              (215583, 'MT'): defaultdict(int, {'1Qisaa': 1898503}),
#              (1898509, '1Qisaa'): defaultdict(int, {'MT': 215589}),
#              (215589, 'MT'): defaultdict(int, {'1Qisaa': 1898509}),
#              (1898546, '1Qisaa'): defaultdict(int, {'MT': 215624}),
#              (215624, 'MT'): defaultdict(int, {'1Qisaa': 1898546}),
#              (1898601, '1Qisaa'): defaultdict(int, {'MT': 215675}),
#              (215675, 'MT'): defaultdict(int, {'1Qisaa': 1898601}),
#              (1898603, '1Qisaa'): defaultdict(int, {'MT': 215677}),
#              (215677, 'MT'): defaultdict(int, {'1Qisaa': 1898603}),
#              (1898619, '1Qisaa'): defaultdict(int, {'MT': 215692}),
#              (215692, 'MT'): defaultdict(int, {'1Qisaa': 1898619}),
#              (1898632, '1Qisaa'): defaultdict(int, {'MT': 215706}),
#              (215706, 'MT'): defaultdict(int, {'1Qisaa': 1898632}),
#              (1898643, '1Qisaa'): defaultdict(int, {'MT': 215717}),
#              (215717, 'MT'): defaultdict(int, {'1Qisaa': 1898643}),
#              (1898650, '1Qisaa'): defaultdict(int, {'MT': 215724}),
#              (215724, 'MT'): defaultdict(int, {'1Qisaa': 1898650}),
#              (1898656, '1Qisaa'): defaultdict(int, {'MT': 215729}),
#              (215729, 'MT'): defaultdict(int, {'1Qisaa': 1898656}),
#              (1898666, '1Qisaa'): defaultdict(int, {'MT': 215739}),
#              (215739, 'MT'): defaultdict(int, {'1Qisaa': 1898666}),
#              (1898688, '1Qisaa'): defaultdict(int, {'MT': 215761}),
#              (215761, 'MT'): defaultdict(int, {'1Qisaa': 1898688}),
#              (1898735, '1Qisaa'): defaultdict(int, {'MT': 215806}),
#              (215806, 'MT'): defaultdict(int, {'1Qisaa': 1898735}),
#              (1898743, '1Qisaa'): defaultdict(int, {'MT': 215814}),
#              (215814, 'MT'): defaultdict(int, {'1Qisaa': 1898743}),
#              (1898745, '1Qisaa'): defaultdict(int, {'MT': 215816}),
#              (215816, 'MT'): defaultdict(int, {'1Qisaa': 1898745}),
#              (1898747, '1Qisaa'): defaultdict(int, {'MT': 215818}),
#              (215818, 'MT'): defaultdict(int, {'1Qisaa': 1898747}),
#              (1898757, '1Qisaa'): defaultdict(int, {'MT': 215827}),
#              (215827, 'MT'): defaultdict(int, {'1Qisaa': 1898757}),
#              (1898759, '1Qisaa'): defaultdict(int, {'MT': 215829}),
#              (215829, 'MT'): defaultdict(int, {'1Qisaa': 1898759}),
#              (1898766, '1Qisaa'): defaultdict(int, {'MT': 215836}),
#              (215836, 'MT'): defaultdict(int, {'1Qisaa': 1898766}),
#              (1898772, '1Qisaa'): defaultdict(int, {'MT': 215841}),
#              (215841, 'MT'): defaultdict(int, {'1Qisaa': 1898772}),
#              (1898806, '1Qisaa'): defaultdict(int, {'MT': 215874}),
#              (215874, 'MT'): defaultdict(int, {'1Qisaa': 1898806}),
#              (1898810, '1Qisaa'): defaultdict(int, {'MT': 215878}),
#              (215878, 'MT'): defaultdict(int, {'1Qisaa': 1898810}),
#              (1898821, '1Qisaa'): defaultdict(int, {'MT': 215889}),
#              (215889, 'MT'): defaultdict(int, {'1Qisaa': 1898821}),
#              (1898832, '1Qisaa'): defaultdict(int, {'MT': 215899}),
#              (215899, 'MT'): defaultdict(int, {'1Qisaa': 1898832}),
#              (1898861, '1Qisaa'): defaultdict(int, {'MT': 215926}),
#              (215926, 'MT'): defaultdict(int, {'1Qisaa': 1898861}),
#              (1898891, '1Qisaa'): defaultdict(int, {'MT': 215954}),
#              (215954, 'MT'): defaultdict(int, {'1Qisaa': 1898891}),
#              (1898912, '1Qisaa'): defaultdict(int, {'MT': 215974}),
#              (215974, 'MT'): defaultdict(int, {'1Qisaa': 1898912}),
#              (1898937, '1Qisaa'): defaultdict(int, {'MT': 215999}),
#              (215999, 'MT'): defaultdict(int, {'1Qisaa': 1898937}),
#              (1898940, '1Qisaa'): defaultdict(int, {'MT': 216002}),
#              (216002, 'MT'): defaultdict(int, {'1Qisaa': 1898940}),
#              (1898973, '1Qisaa'): defaultdict(int, {'MT': 216031}),
#              (216031, 'MT'): defaultdict(int, {'1Qisaa': 1898973}),
#              (1898988, '1Qisaa'): defaultdict(int, {'MT': 216044}),
#              (216044, 'MT'): defaultdict(int, {'1Qisaa': 1898988}),
#              (1899005, '1Qisaa'): defaultdict(int, {'MT': 216060}),
#              (216060, 'MT'): defaultdict(int, {'1Qisaa': 1899005}),
#              (1899015, '1Qisaa'): defaultdict(int, {'MT': 216070}),
#              (216070, 'MT'): defaultdict(int, {'1Qisaa': 1899015}),
#              (1899033, '1Qisaa'): defaultdict(int, {'MT': 216088}),
#              (216088, 'MT'): defaultdict(int, {'1Qisaa': 1899033}),
#              (1899045, '1Qisaa'): defaultdict(int, {'MT': 216099}),
#              (216099, 'MT'): defaultdict(int, {'1Qisaa': 1899045}),
#              (1899060, '1Qisaa'): defaultdict(int, {'MT': 216113}),
#              (216113, 'MT'): defaultdict(int, {'1Qisaa': 1899060}),
#              (1899081, '1Qisaa'): defaultdict(int, {'MT': 216133}),
#              (216133, 'MT'): defaultdict(int, {'1Qisaa': 1899081}),
#              (1899082, '1Qisaa'): defaultdict(int, {'MT': 216134}),
#              (216134, 'MT'): defaultdict(int, {'1Qisaa': 1899082}),
#              (1899093, '1Qisaa'): defaultdict(int, {'MT': 216144}),
#              (216144, 'MT'): defaultdict(int, {'1Qisaa': 1899093}),
#              (1899120, '1Qisaa'): defaultdict(int, {'MT': 216167}),
#              (216167, 'MT'): defaultdict(int, {'1Qisaa': 1899120}),
#              (1899137, '1Qisaa'): defaultdict(int,
#                          {'MT': 216183, '4Q57': 2020559}),
#              (1899147, '1Qisaa'): defaultdict(int, {'MT': 216193}),
#              (216193, 'MT'): defaultdict(int, {'1Qisaa': 1899147}),
#              (1899149, '1Qisaa'): defaultdict(int,
#                          {'MT': 216195, '4Q57': 2020572}),
#              (1899166, '1Qisaa'): defaultdict(int,
#                          {'MT': 216211, '4Q57': 2020588}),
#              (1899171, '1Qisaa'): defaultdict(int,
#                          {'MT': 216216, '4Q57': 2020593}),
#              (1899183, '1Qisaa'): defaultdict(int,
#                          {'MT': 216228, '4Q57': 2020606}),
#              (1899203, '1Qisaa'): defaultdict(int, {'MT': 216250}),
#              (216250, 'MT'): defaultdict(int, {'1Qisaa': 1899203}),
#              (1899208, '1Qisaa'): defaultdict(int, {'MT': 216255}),
#              (216255, 'MT'): defaultdict(int, {'1Qisaa': 1899208}),
#              (1899215, '1Qisaa'): defaultdict(int, {'MT': 216262}),
#              (216262, 'MT'): defaultdict(int, {'1Qisaa': 1899215}),
#              (1899216, '1Qisaa'): defaultdict(int,
#                          {'MT': 216263, '4Q57': 2020641}),
#              (1899263, '1Qisaa'): defaultdict(int, {'MT': 216309}),
#              (216309, 'MT'): defaultdict(int, {'1Qisaa': 1899263}),
#              (1899325, '1Qisaa'): defaultdict(int, {'MT': 216369}),
#              (216369, 'MT'): defaultdict(int, {'1Qisaa': 1899325}),
#              (1899389, '1Qisaa'): defaultdict(int, {'MT': 216429}),
#              (216429, 'MT'): defaultdict(int, {'1Qisaa': 1899389}),
#              (1899395, '1Qisaa'): defaultdict(int, {'MT': 216435}),
#              (216435, 'MT'): defaultdict(int, {'1Qisaa': 1899395}),
#              (1899403, '1Qisaa'): defaultdict(int, {'MT': 216444}),
#              (216444, 'MT'): defaultdict(int, {'1Qisaa': 1899403}),
#              (1899409, '1Qisaa'): defaultdict(int, {'MT': 216449}),
#              (216449, 'MT'): defaultdict(int, {'1Qisaa': 1899409}),
#              (1899413, '1Qisaa'): defaultdict(int, {'MT': 216453}),
#              (216453, 'MT'): defaultdict(int, {'1Qisaa': 1899413}),
#              (1899430, '1Qisaa'): defaultdict(int, {'MT': 216471}),
#              (216471, 'MT'): defaultdict(int, {'1Qisaa': 1899430}),
#              (1899440, '1Qisaa'): defaultdict(int, {'MT': 216479}),
#              (216479, 'MT'): defaultdict(int, {'1Qisaa': 1899440}),
#              (1899445, '1Qisaa'): defaultdict(int, {'MT': 216484}),
#              (216484, 'MT'): defaultdict(int, {'1Qisaa': 1899445}),
#              (1899456, '1Qisaa'): defaultdict(int, {'MT': 216493}),
#              (216493, 'MT'): defaultdict(int, {'1Qisaa': 1899456}),
#              (1899459, '1Qisaa'): defaultdict(int,
#                          {'MT': 216496, '4Q59': 2026143}),
#              (216496, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899459, '4Q59': 2026143}),
#              (1899462, '1Qisaa'): defaultdict(int,
#                          {'MT': 216498, '4Q59': 2026146}),
#              (216498, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899462, '4Q59': 2026146}),
#              (1899474, '1Qisaa'): defaultdict(int,
#                          {'MT': 216509, '4Q55': 2014780, '1Q8': 1919248}),
#              (216509, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899474, '4Q55': 2014780, '1Q8': 1919248}),
#              (1899476, '1Qisaa'): defaultdict(int,
#                          {'MT': 216511, '4Q55': 2014782, '1Q8': 1919250}),
#              (216511, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899476, '4Q55': 2014782, '1Q8': 1919250}),
#              (1899490, '1Qisaa'): defaultdict(int,
#                          {'MT': 216525, '1Q8': 1919265}),
#              (216525, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899490, '1Q8': 1919265}),
#              (1899496, '1Qisaa'): defaultdict(int,
#                          {'MT': 216530, '4Q56': 2016849, '4Q55': 2014802}),
#              (216530, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899496,
#                           '4Q56': 2016849,
#                           '4Q55': 2014802}),
#              (1899503, '1Qisaa'): defaultdict(int,
#                          {'MT': 216538, '4Q55': 2014809}),
#              (216538, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899503, '4Q55': 2014809}),
#              (1899528, '1Qisaa'): defaultdict(int, {'MT': 216562}),
#              (216562, 'MT'): defaultdict(int, {'1Qisaa': 1899528}),
#              (1899534, '1Qisaa'): defaultdict(int,
#                          {'MT': 216567, '4Q56': 2016887}),
#              (216567, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899534, '4Q56': 2016887}),
#              (1899545, '1Qisaa'): defaultdict(int,
#                          {'MT': 216577, '4Q55': 2014851}),
#              (216577, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899545, '4Q55': 2014851}),
#              (1899549, '1Qisaa'): defaultdict(int,
#                          {'MT': 216581, '4Q55': 2014855, '1Q8': 1919324}),
#              (216581, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899549, '4Q55': 2014855, '1Q8': 1919324}),
#              (1899556, '1Qisaa'): defaultdict(int,
#                          {'MT': 216587, '4Q56': 2016909}),
#              (216587, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899556, '4Q56': 2016909}),
#              (1899580, '1Qisaa'): defaultdict(int, {'MT': 216610}),
#              (216610, 'MT'): defaultdict(int, {'1Qisaa': 1899580}),
#              (1899588, '1Qisaa'): defaultdict(int,
#                          {'MT': 216619, '4Q56': 2016941, '4Q55': 2014894}),
#              (216619, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899588,
#                           '4Q56': 2016941,
#                           '4Q55': 2014894}),
#              (1899593, '1Qisaa'): defaultdict(int,
#                          {'MT': 216623, '4Q55': 2014899}),
#              (216623, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899593, '4Q55': 2014899}),
#              (1899597, '1Qisaa'): defaultdict(int,
#                          {'MT': 216627, '4Q55': 2014903}),
#              (216627, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899597, '4Q55': 2014903}),
#              (1899620, '1Qisaa'): defaultdict(int,
#                          {'MT': 216649, '4Q55': 2014928}),
#              (216649, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899620, '4Q55': 2014928}),
#              (1899623, '1Qisaa'): defaultdict(int, {'MT': 216652}),
#              (216652, 'MT'): defaultdict(int, {'1Qisaa': 1899623}),
#              (1899624, '1Qisaa'): defaultdict(int,
#                          {'MT': 216653, '4Q56': 2016977}),
#              (216653, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899624, '4Q56': 2016977}),
#              (1899627, '1Qisaa'): defaultdict(int,
#                          {'MT': 216656, '4Q56': 2016980}),
#              (216656, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899627, '4Q56': 2016980}),
#              (1899649, '1Qisaa'): defaultdict(int, {'MT': 216676}),
#              (216676, 'MT'): defaultdict(int, {'1Qisaa': 1899649}),
#              (1899657, '1Qisaa'): defaultdict(int, {'MT': 216684}),
#              (216684, 'MT'): defaultdict(int, {'1Qisaa': 1899657}),
#              (1899667, '1Qisaa'): defaultdict(int,
#                          {'MT': 216693, '4Q55': 2014975}),
#              (216693, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899667, '4Q55': 2014975}),
#              (1899681, '1Qisaa'): defaultdict(int, {'MT': 216706}),
#              (216706, 'MT'): defaultdict(int, {'1Qisaa': 1899681}),
#              (1899686, '1Qisaa'): defaultdict(int, {'MT': 216711}),
#              (216711, 'MT'): defaultdict(int, {'1Qisaa': 1899686}),
#              (1899694, '1Qisaa'): defaultdict(int,
#                          {'MT': 216719, '4Q56': 2017047}),
#              (216719, 'MT'): defaultdict(int,
#                          {'1Qisaa': 1899694, '4Q56': 2017047}),
#              (1899743, '1Qisaa'): defaultdict(int, {'MT': 216762}),
#              (216762, 'MT'): defaultdict(int, {'1Qisaa': 1899743}),
#              (1899747, '1Qisaa'): defaultdict(int, {'MT': 216766}),
#              (216766, 'MT'): defaultdict(int, {'1Qisaa': 1899747}),
#              (1899762, '1Qisaa'): defaultdict(int, {'MT': 216780}),
#              (216780, 'MT'): defaultdict(int, {'1Qisaa': 1899762}),
#              (1899764, '1Qisaa'): defaultdict(int, {'MT': 216782}),
#              (216782, 'MT'): defaultdict(int, {'1Qisaa': 1899764}),
#              (1899803, '1Qisaa'): defaultdict(int, {'MT': 216819}),
#              (216819, 'MT'): defaultdict(int, {'1Qisaa': 1899803}),
#              (1899804, '1Qisaa'): defaultdict(int, {'MT': 216821}),
#              (216821, 'MT'): defaultdict(int, {'1Qisaa': 1899804}),
#              (1899821, '1Qisaa'): defaultdict(int, {'MT': 216836}),
#              (216836, 'MT'): defaultdict(int, {'1Qisaa': 1899821}),
#              (1899849, '1Qisaa'): defaultdict(int, {'MT': 216859}),
#              (216859, 'MT'): defaultdict(int, {'1Qisaa': 1899849}),
#              (1899883, '1Qisaa'): defaultdict(int, {'MT': 216892}),
#              (216892, 'MT'): defaultdict(int, {'1Qisaa': 1899883}),
#              ...})

# %%
len(hif_match_dict)
# Out:
# 6647

# %%
vowel_letter_pairs = []
feature_counts = collections.defaultdict(int)

for feature, feat_dict in isa_dict[('1Qisaa', 'MT')].items():
    for pair, count in feat_dict.items():
        vowel_letter_pairs += [pair] * count
        feature_counts[feature] += count
    
len(vowel_letter_pairs)
# Out:
# 2789

# %%
pd.value_counts(vowel_letter_pairs)
# Out:
# (1, 1)    1374
# (1, 0)    1078
# (0, 0)     286
# (0, 1)      51
# Name: count, dtype: int64

# %%
feature_counts
# Out:
# defaultdict(int,
#             {'nouns_adjectives_last': 866,
#              'nouns_adjectives_single': 585,
#              'nouns_adjectives_first': 331,
#              'ptca_qal_first': 410,
#              'ptcp_qal_last': 73,
#              'niph_hiph_pe_yod_first': 129,
#              'infa_qal_last': 27,
#              'infc_qal_triliteral_last': 94,
#              'infc_qal_lamed_he_nme': 34,
#              'hiphil_triliteral_with_hireq_last': 240})

# %%
import random
import pprint

# %%
def get_feature_counts_and_vowel_pairs(isa_dict, manuscripts):
    vowel_letter_pairs = []
    feature_counts = collections.defaultdict(int)

    for feature, feat_dict in isa_dict[manuscripts].items():
        for pair, count in feat_dict.items():
            vowel_letter_pairs += [pair] * count
            feature_counts[feature] += count
    return feature_counts, vowel_letter_pairs

def get_spelling_difference_counts(feature_spelling_counts):
    man1_pluses = feature_spelling_counts.get((1, 0), 0) + feature_spelling_counts.get((1, 1), 0)
    man2_pluses = feature_spelling_counts.get((0, 1), 0) + feature_spelling_counts.get((1, 1), 0)
    return man1_pluses, man2_pluses


def sample_spelling(feature_spellings, feature_count, n_samples):
    man1_counts = []
    man2_counts = []
    for i in range(n_samples):
        pairs_sample = random.choices(feature_spellings, k=feature_count)
        man1_fuller = np.sum(pairs_sample.count((1, 0))) + np.sum(pairs_sample.count((1, 1)))
        man2_fuller = np.sum(pairs_sample.count((0, 1)))  + np.sum(pairs_sample.count((1, 1)))
        man1_counts.append(man1_fuller)
        man2_counts.append(man2_fuller)
    return man1_counts, man2_counts
    
    
def calculate_sample_mean(counts):
   
    return np.mean(counts)

def make_distribution_df(counts):

    man1_val_counts = pd.DataFrame(pd.value_counts(counts))
    man1_val_counts['value'] = man1_val_counts.index
    man1_val_counts = man1_val_counts.sort_values(by='value')
    return man1_val_counts

def calculate_feature_man_prob(counts_df, feature_man_mean):
    
    #print(counts_df)
    man_cutoff = counts_df[counts_df.value <= feature_man_mean]
    #print(man_cutoff)
    cutoff_count = man_cutoff['count'].sum()
    total_count = counts_df['count'].sum()
    prob = cutoff_count / total_count
    return prob

# %%
import scipy.stats as st
import seaborn as sns

def calculate_conf_interval(data):
    data = np.array(data)
    mean = data.mean()
    Z = 1.96

    std = np.std(data)

    print('MEAN STD', mean, std)
    left_limit = mean - (Z * (std / np.sqrt(n)))
    right_limit = mean + (Z * (std / np.sqrt(n)))
    print('LIMITS', left_limit, right_limit)
    return left_limit, right_limit

# %%
def run_features_pipeline(isa_dict, manuscripts, feature_counts, vowel_letter_pairs, n_samples):
    
    feature_probs = {}
    
    spelling_counts_all_features = isa_dict[manuscripts]
    
    for feature, feature_count in feature_counts.items():
        
        man1_pluses, man2_pluses = get_spelling_difference_counts(spelling_counts_all_features[feature])
        man1_counts, man2_counts = sample_spelling(vowel_letter_pairs, feature_count, n_samples)

        man1_mean = np.mean(man1_counts)
        man2_mean = np.mean(man2_counts)
        
        #print('mean1:', man1_mean)
        #print('mean2:', man2_mean)
        #print('MAN1 std:', np.std(man1_counts))
        #print('MAN2 std:', np.std(man2_counts))
        #print('MAN1 ci:', calculate_conf_interval(man1_counts))
        #print('MAN2 ci:', calculate_conf_interval(man2_counts))
        
        man1_mean_norm = man1_mean / feature_count
        man2_mean_norm = man2_mean / feature_count
        man1_pluses_norm = man1_pluses / feature_count
        man2_pluses_norm = man2_pluses / feature_count
        #ci1 = calculate_conf_interval(man1_counts)
        #ci2 = calculate_conf_interval(man2_counts)
        
        man1_counts_norm = [count / feature_count for count in man1_counts]
        man2_counts_norm = [count / feature_count for count in man2_counts]

        quantiles1 = np.quantile(man1_counts_norm, [0.025, 0.975])
        quantiles2 = np.quantile(man2_counts_norm, [0.025, 0.975])
        
        feature_probs[feature] = [man1_mean, man2_mean, man1_pluses, man2_pluses, 
                                  man1_mean_norm, man2_mean_norm, man1_pluses_norm,
                                  man2_pluses_norm, quantiles1, quantiles2]
        #print()
        
    return feature_probs

# %%
n_samples = 10000
#manuscripts = ('4Q57', 'MT')

for manuscripts in isa_dict.keys():
    print(manuscripts)
    feature_counts, vowel_letter_pairs = get_feature_counts_and_vowel_pairs(isa_dict, manuscripts)

    probabilities = run_features_pipeline(isa_dict, manuscripts, feature_counts, vowel_letter_pairs, n_samples)
    #pprint.pprint(probabilities)
    print()
    
    #break
# Out:
# ('1Qisaa', 'MT')
#
# ('1Qisaa', 'Mur3')
#
# ('1Qisaa', '4Q63')
#
# ('1Qisaa', '4Q56')
#
# ('1Qisaa', '4Q60')
#
# ('1Qisaa', '4Q59')
#
# ('1Qisaa', '1Q8')
#
# ('1Qisaa', '4Q65')
#
# ('1Qisaa', '4Q57')
#
# ('1Qisaa', '4Q55')
#
# ('1Qisaa', '4Q68')
#
# ('1Qisaa', '4Q64')
#
# ('1Qisaa', '4Q62')
#
# ('1Qisaa', '4Q61')
#
# ('1Qisaa', '4Q58')
#
# ('1Qisaa', '4Q62a')
#
# ('1Qisaa', '4Q67')
#
# ('1Qisaa', '4Q66')
#
# ('1Q8', 'MT')
#
# ('1Q8', '4Q55')
#
# ('1Q8', '4Q56')
#
# ('1Q8', '4Q57')
#
# ('1Q8', '4Q64')
#
# ('1Q8', '4Q61')
#
# ('1Q8', '4Q58')
#
# ('1Q8', '4Q62a')
#
# ('1Q8', '4Q67')
#
# ('4Q55', 'MT')
#
# ('4Q55', '4Q56')
#
# ('4Q55', '4Q60')
#
# ('4Q55', '4Q57')
#
# ('4Q56', 'MT')
#
# ('4Q56', '4Q57')
#
# ('4Q57', 'MT')
#
# ('4Q57', '4Q58')
#
# ('4Q58', 'MT')
#
# ('4Q59', 'MT')
#
# ('4Q59', '4Q60')
#
# ('4Q60', 'MT')
#
# ('4Q61', 'MT')
#
# ('4Q62', 'MT')
#
# ('4Q62a', 'MT')
#
# ('4Q63', 'MT')
#
# ('4Q64', 'MT')
#
# ('4Q65', 'MT')
#
# ('4Q66', 'MT')
#
# ('4Q67', 'MT')
#
# ('4Q68', 'MT')
#
# ('Mur3', 'MT')
#
# ('4Q56', '4Q62')
#
# ('4Q57', '4Q60')
#
# ('1Q8', '4Q66')

# %%
sns.distplot(probabilities['nouns_adjectives_first'][-1], hist=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10420/169262967.py in <module>
# ----> 1 sns.distplot(probabilities['nouns_adjectives_first'][-1], hist=False)
#
# KeyError: 'nouns_adjectives_first'

# %%
calculate_conf_interval(probabilities['nouns_adjectives'][-1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10420/1754877816.py in <module>
# ----> 1 calculate_conf_interval(probabilities['nouns_adjectives'][-1])
#
# KeyError: 'nouns_adjectives'

# %%
data = np.array(probabilities['nouns_adjectives'][-1])

# 1. X - mean of population
mean = data.mean()
print(mean)

# 2. Z-score
Z = 1.96

# 3. standard deviation of the entire population
std = data.std()
print(std)

#left limit
left_limit = mean - (Z * (std / np.sqrt(n)))
right_limit = mean + (Z * (std / np.sqrt(n)))
print(left_limit, right_limit)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10420/857340378.py in <module>
# ----> 1 data = np.array(probabilities['nouns_adjectives'][-1])
#       2
#       3 # 1. X - mean of population
#       4 mean = data.mean()
#       5 print(mean)
#
# KeyError: 'nouns_adjectives'

# %%
import numpy as np
import scipy.stats as st

#define sample data
np.random.seed(0)
data = probabilities['nouns_adjectives'][-1] #np.random.randint(10, 30, 50)

#create 95% confidence interval for population mean weight
st.norm.interval(alpha=0.95, loc=np.mean(data), scale=st.sem(data))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10420/1973153011.py in <module>
#       4 #define sample data
#       5 np.random.seed(0)
# ----> 6 data = probabilities['nouns_adjectives'][-1] #np.random.randint(10, 30, 50)
#       7
#       8 #create 95% confidence interval for population mean weight
#
# KeyError: 'nouns_adjectives'

# %%
sns.distplot(probabilities['nouns_adjectives'][-1], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10420/129209995.py in <module>
# ----> 1 sns.distplot(probabilities['nouns_adjectives'][-1], hist=True, kde=True,
#       2              bins=int(180/5), color = 'darkblue',
#       3              hist_kws={'edgecolor':'black'},
#       4              kde_kws={'linewidth': 4})
#
# KeyError: 'nouns_adjectives'

# %%
def get_feature_counts_per_manuscript(isa_dict, manuscripts):
    vowel_letter_pairs = []
    feature_counts = collections.defaultdict(int)

    man1_values = []
    man2_values = []
    for feature, feat_dict in isa_dict[manuscripts].items():
        
        for pair, count in feat_dict.items():
            vowel_letter_pairs += [pair] * count
            feature_counts[feature] += count
    return feature_counts, vowel_letter_pairs

# %% [markdown]
# ## Calculate average fullness of features of the book of Isaiah

# %%
isa_dict
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('1Qisaa',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 518,
#                                        (1, 0): 255,
#                                        (0, 0): 77,
#                                        (0, 1): 16}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 1): 214,
#                                        (1, 0): 307,
#                                        (0, 1): 10,
#                                        (0, 0): 54}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 1): 90,
#                                        (1, 0): 169,
#                                        (0, 0): 67,
#                                        (0, 1): 5}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(1, 0): 251,
#                                        (1, 1): 99,
#                                        (0, 1): 4,
#                                        (0, 0): 56}),
#                           'ptcp_qal_last': defaultdict(int,
#                                       {(1, 0): 5,
#                                        (1, 1): 62,
#                                        (0, 1): 3,
#                                        (0, 0): 3}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 121,
#                                        (0, 1): 2,
#                                        (1, 0): 4,
#                                        (0, 0): 2}),
#                           'infa_qal_last': defaultdict(int,
#                                       {(1, 1): 12,
#                                        (0, 0): 7,
#                                        (0, 1): 2,
#                                        (1, 0): 6}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 0): 71, (0, 0): 14, (1, 1): 9}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 32, (1, 0): 2}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 217,
#                                        (0, 0): 6,
#                                        (1, 0): 8,
#                                        (0, 1): 9})}),
#              ('1Qisaa',
#               'Mur3'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 2})}),
#              ('1Qisaa',
#               '4Q63'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('1Qisaa',
#               '4Q56'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 0): 13, (1, 1): 13, (0, 0): 2}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 6, (1, 0): 13, (1, 1): 7}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 0): 4, (0, 0): 4, (1, 1): 4}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(0, 0): 1, (1, 0): 16, (1, 1): 3}),
#                           'ptcp_qal_last': defaultdict(int,
#                                       {(1, 1): 1, (1, 0): 1}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 8}),
#                           'infa_qal_last': defaultdict(int, {(1, 0): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(0, 0): 3, (1, 0): 4}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 6, (1, 0): 2})}),
#              ('1Qisaa',
#               '4Q60'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 5, (1, 1): 2}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 0): 4, (1, 1): 1, (0, 1): 1}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 0): 1, (0, 0): 1}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(1, 0): 5, (0, 0): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 0): 2}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 2})}),
#              ('1Qisaa',
#               '4Q59'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 8, (1, 1): 1}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 0): 3, (1, 1): 4, (0, 0): 1}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 0): 2}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(1, 0): 2, (1, 1): 2}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 2}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('1Qisaa',
#               '1Q8'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 71, (0, 0): 7, (1, 1): 41}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 100,
#                                        (1, 0): 74,
#                                        (0, 0): 7,
#                                        (0, 1): 1}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 0): 33, (1, 1): 21, (0, 0): 8}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(1, 1): 35,
#                                        (0, 0): 6,
#                                        (1, 0): 27,
#                                        (0, 1): 2}),
#                           'ptcp_qal_last': defaultdict(int,
#                                       {(1, 1): 14, (1, 0): 1, (0, 1): 1}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 17, (1, 0): 2, (0, 0): 1}),
#                           'infa_qal_last': defaultdict(int,
#                                       {(0, 0): 1, (1, 1): 3}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 0): 9, (1, 1): 5}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 5}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 50,
#                                        (0, 0): 1,
#                                        (1, 0): 2,
#                                        (0, 1): 1})}),
#              ('1Qisaa',
#               '4Q65'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 1): 1, (1, 0): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(0, 0): 1})}),
#              ('1Qisaa',
#               '4Q57'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 28,
#                                        (0, 0): 1,
#                                        (1, 0): 2,
#                                        (0, 1): 2}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 1): 5,
#                                        (0, 1): 2,
#                                        (1, 0): 2,
#                                        (0, 0): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 1): 4, (1, 1): 13}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(1, 1): 20, (0, 0): 1}),
#                           'ptcp_qal_last': defaultdict(int, {(1, 1): 2}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 4}),
#                           'infa_qal_last': defaultdict(int, {(1, 1): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 1): 3}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 5})}),
#              ('1Qisaa',
#               '4Q55'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 2, (1, 1): 5, (1, 0): 4}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 1, (1, 1): 1, (1, 0): 1}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 1): 2,
#                                        (1, 0): 7,
#                                        (1, 1): 6,
#                                        (0, 0): 2}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(1, 1): 6,
#                                        (0, 1): 1,
#                                        (1, 0): 2,
#                                        (0, 0): 1}),
#                           'ptcp_qal_last': defaultdict(int, {(1, 1): 1}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 2}),
#                           'infa_qal_last': defaultdict(int, {(1, 1): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(0, 0): 1, (1, 0): 1, (1, 1): 1}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 3})}),
#              ('1Qisaa',
#               '4Q68'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 0): 2}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 1})}),
#              ('1Qisaa',
#               '4Q64'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 1})}),
#              ('1Qisaa',
#               '4Q62'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 0): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'ptca_qal_first': defaultdict(int, {(1, 0): 3}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('1Qisaa',
#               '4Q61'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 1, (1, 1): 1}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 0): 3}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 2})}),
#              ('1Qisaa',
#               '4Q58'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 0): 8,
#                                        (1, 1): 9,
#                                        (0, 0): 2,
#                                        (0, 1): 1}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 0): 6, (0, 0): 1, (1, 1): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 6, (1, 1): 2}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(1, 0): 6, (0, 0): 1, (1, 1): 1}),
#                           'ptcp_qal_last': defaultdict(int, {(1, 1): 5}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 4}),
#                           'infa_qal_last': defaultdict(int, {(1, 0): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 0): 1}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 3}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 12, (0, 1): 1})}),
#              ('1Qisaa',
#               '4Q62a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 1): 1, (1, 0): 1})}),
#              ('1Qisaa',
#               '4Q67'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 0): 1}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 0): 1})}),
#              ('1Qisaa',
#               '4Q66'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'ptcp_qal_last': defaultdict(int, {(1, 1): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('1Q8',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 68, (1, 1): 40, (0, 1): 11}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 97,
#                                        (0, 1): 18,
#                                        (0, 0): 64,
#                                        (1, 0): 6}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 40, (0, 1): 2, (1, 1): 20}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(1, 1): 13,
#                                        (0, 0): 35,
#                                        (1, 0): 25,
#                                        (0, 1): 1}),
#                           'ptcp_qal_last': defaultdict(int,
#                                       {(1, 1): 16, (0, 0): 1, (0, 1): 3}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 21, (0, 1): 2, (0, 0): 1}),
#                           'infa_qal_last': defaultdict(int,
#                                       {(0, 0): 1, (1, 1): 1, (1, 0): 2}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(0, 0): 9, (1, 1): 5}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 6}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 49,
#                                        (1, 0): 3,
#                                        (0, 0): 1,
#                                        (0, 1): 3})}),
#              ('1Q8',
#               '4Q55'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 2, (1, 1): 1})}),
#              ('1Q8',
#               '4Q56'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 1): 1, (1, 1): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 3}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(0, 1): 1, (1, 0): 4}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 2, (1, 0): 2})}),
#              ('1Q8',
#               '4Q57'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 5, (0, 1): 5}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(0, 1): 3, (1, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('1Q8',
#               '4Q64'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 1})}),
#              ('1Q8',
#               '4Q61'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 0): 2, (1, 0): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 1): 1})}),
#              ('1Q8',
#               '4Q58'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 0): 4, (1, 1): 1, (1, 0): 1}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 2}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 1, (0, 0): 1, (1, 1): 1}),
#                           'ptca_qal_first': defaultdict(int, {(0, 0): 1}),
#                           'ptcp_qal_last': defaultdict(int, {(1, 1): 4}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 2}),
#                           'infa_qal_last': defaultdict(int, {(1, 0): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(0, 1): 1, (1, 1): 5})}),
#              ('1Q8',
#               '4Q62a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('1Q8',
#               '4Q67'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 0): 1})}),
#              ('4Q55',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 3, (1, 1): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 8, (1, 0): 1, (1, 1): 5}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 8,
#                                        (0, 0): 7,
#                                        (0, 1): 2,
#                                        (1, 0): 1}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(1, 1): 2, (1, 0): 5, (0, 0): 3}),
#                           'ptcp_qal_last': defaultdict(int, {(1, 1): 1}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 2}),
#                           'infa_qal_last': defaultdict(int,
#                                       {(1, 0): 1, (1, 1): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(0, 0): 2, (1, 1): 1}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 3})}),
#              ('4Q55',
#               '4Q56'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 1): 1, (0, 0): 1}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'infa_qal_last': defaultdict(int, {(1, 0): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 2})}),
#              ('4Q55',
#               '4Q60'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 1): 1, (1, 0): 1}),
#                           'ptca_qal_first': defaultdict(int, {(1, 0): 1}),
#                           'infa_qal_last': defaultdict(int, {(1, 1): 1})}),
#              ('4Q55',
#               '4Q57'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'ptca_qal_first': defaultdict(int, {(0, 1): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('4Q56',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 1): 2,
#                                        (1, 0): 1,
#                                        (0, 0): 12,
#                                        (1, 1): 13}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 20, (1, 1): 7}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 9, (1, 0): 1, (1, 1): 3}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(0, 0): 16,
#                                        (1, 0): 1,
#                                        (1, 1): 2,
#                                        (0, 1): 1}),
#                           'ptcp_qal_last': defaultdict(int,
#                                       {(1, 1): 1, (0, 1): 1}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 8}),
#                           'infa_qal_last': defaultdict(int,
#                                       {(0, 0): 1, (0, 1): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(0, 0): 7}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 8, (0, 1): 1, (0, 0): 1})}),
#              ('4Q56',
#               '4Q57'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 1): 1})}),
#              ('4Q57',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 22,
#                                        (1, 0): 9,
#                                        (0, 0): 1,
#                                        (0, 1): 2}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 1): 3, (1, 0): 4, (0, 0): 3}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 0): 13, (1, 1): 5}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(1, 0): 16, (1, 1): 3, (0, 0): 2}),
#                           'ptcp_qal_last': defaultdict(int, {(1, 1): 2}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 4}),
#                           'infa_qal_last': defaultdict(int, {(1, 1): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 0): 2, (1, 1): 1}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 5})}),
#              ('4Q57',
#               '4Q58'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 0): 1, (1, 1): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 0): 1})}),
#              ('4Q58',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 1): 6, (1, 1): 10, (0, 0): 5}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 7, (1, 0): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 5,
#                                        (0, 1): 1,
#                                        (1, 0): 1,
#                                        (1, 1): 1}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(0, 0): 5, (0, 1): 2, (1, 1): 1}),
#                           'ptcp_qal_last': defaultdict(int, {(1, 1): 4}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 5}),
#                           'infa_qal_last': defaultdict(int, {(0, 0): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 3}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 14})}),
#              ('4Q59',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 10, (1, 1): 1}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 0): 4, (1, 1): 5}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 2}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(0, 0): 2, (1, 0): 1, (1, 1): 1}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 1, (1, 0): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('4Q59',
#               '4Q60'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 3}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 0): 1})}),
#              ('4Q60',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 6, (1, 1): 2}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 1): 4,
#                                        (0, 0): 1,
#                                        (1, 1): 1,
#                                        (1, 0): 1}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 2}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(0, 0): 4, (0, 1): 2}),
#                           'infa_qal_last': defaultdict(int, {(1, 1): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(0, 0): 2}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 2})}),
#              ('4Q61',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 1, (1, 0): 1}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 0): 2, (0, 1): 1}),
#                           'infc_qal_lamed_he_nme': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 2})}),
#              ('4Q62',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 1): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'ptca_qal_first': defaultdict(int,
#                                       {(0, 1): 1, (0, 0): 2}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('4Q62a',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 1): 1, (0, 0): 1})}),
#              ('4Q63',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('4Q64',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 1})}),
#              ('4Q65',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_first': defaultdict(int,
#                                       {(1, 1): 1, (0, 1): 1}),
#                           'hiphil_triliteral_with_hireq_last': defaultdict(int,
#                                       {(0, 0): 1})}),
#              ('4Q66',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_single': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'ptcp_qal_last': defaultdict(int, {(1, 1): 1}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(1, 0): 1})}),
#              ('4Q67',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 2}),
#                           'infc_qal_triliteral_last': defaultdict(int,
#                                       {(0, 1): 1})}),
#              ('4Q68',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_first': defaultdict(int,
#                                       {(0, 0): 2}),
#                           'nouns_adjectives_last': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'ptca_qal_first': defaultdict(int, {(1, 1): 1})}),
#              ('Mur3',
#               'MT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nouns_adjectives_last': defaultdict(int,
#                                       {(1, 1): 1}),
#                           'nouns_adjectives_single': defaultdict(int,
#                                       {(0, 0): 2})}),
#              ('4Q56',
#               '4Q62'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ptca_qal_first': defaultdict(int,
#                                       {(0, 0): 1}),
#                           'niph_hiph_pe_yod_first': defaultdict(int,
#                                       {(1, 1): 1})}),
#              ('4Q57',
#               '4Q60'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ptca_qal_first': defaultdict(int,
#                                       {(1, 0): 2})}),
#              ('1Q8',
#               '4Q66'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'infc_qal_triliteral_last': defaultdict(int,
#                                       {(0, 1): 1})})})

# %%
n = 0
feature_count_dict = collections.defaultdict(lambda: collections.defaultdict(lambda: collections.defaultdict(int)))
ids = set()


for index, row in dat_dss.iterrows():
    tf_id = row.tf_id, 
    scroll = (row.scroll), 
    has_vl = row.has_vowel_letter
    book, ch, ve = row.book, row.chapter, row.verse
    g_cons = row.g_cons
    lex = row.lex
    prefix = row.prefix
    feature = row.feature
    typ = row.type
    #print(feature)
    feature = feature + '_' + typ
    print(scroll)
    
    if book != 'Isaiah':
        continue

    if (tf_id[0], scroll[0]) in hif_match_dict:

        matching_man_dict = hif_match_dict[(tf_id[0], scroll[0])]
        
        #if scroll[0] == '1Qisaa' and 'MT' not in matching_man_dict:
        #    print(book, ch, ve, lex, g_cons)
        
        for man, corr_id in matching_man_dict.items():

            corr_row = dat[dat.tf_id == corr_id]
        
            mt_full = corr_row.has_vowel_letter.iloc[0]
            corr_scroll = corr_row.scroll.iloc[0]
            corr_vl = corr_row.has_vowel_letter.iloc[0]
            #print(scroll, corr_scroll, has_vl, corr_vl, g_cons, corr_row.g_cons.iloc[0], prefix, book, ch, ve)
            
            if not tf_id[0] in ids:
                feature_count_dict[feature][scroll[0]][has_vl] += 1
                ids.add(tf_id[0])

            if not corr_id in ids:
                feature_count_dict[feature][corr_scroll][corr_vl] += 1
                
                ids.add(corr_id)

            
    
len(ids)
# Out:
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ('SP',)
# ...
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q13',)
# ('2Q13',)
# ('2Q13',)
# ('2Q16',)
# ('2Q16',)
# ('3Q3',)
# ('4Q1',)
# ('4Q1',)
# ('4Q1',)
# ('4Q1',)
# ('4Q2',)
# ('4Q2',)
# ('4Q2',)
# ('4Q5',)
# ('4Q5',)
# ('4Q6',)
# ('4Q9',)
# ('4Q11',)
# ('4Q11',)
# ('4Q13',)
# ('4Q13',)
# ('4Q13',)
# ('4Q14',)
# ('4Q14',)
# ('4Q14',)
# ('4Q14',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q23',)
# ('4Q24',)
# ('4Q26',)
# ('4Q26a',)
# ('4Q27',)
# ('4Q30',)
# ('4Q30',)
# ('4Q31',)
# ('4Q33',)
# ('4Q33',)
# ('4Q35',)
# ('4Q35',)
# ('4Q35',)
# ('4Q41',)
# ('4Q41',)
# ('4Q45',)
# ('4Q45',)
# ('4Q45',)
# ('4Q47',)
# ('4Q48',)
# ('4Q48',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q53',)
# ('4Q53',)
# ('4Q53',)
# ('4Q53',)
# ('4Q53',)
# ('4Q55',)
# ('4Q55',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q57',)
# ('4Q57',)
# ('4Q57',)
# ('4Q57',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q59',)
# ('4Q59',)
# ('4Q59',)
# ('4Q62',)
# ('4Q70',)
# ('4Q70',)
# ('4Q70',)
# ('4Q72',)
# ('4Q72',)
# ('4Q74',)
# ('4Q76',)
# ('4Q76',)
# ('4Q76',)
# ('4Q78',)
# ('4Q78',)
# ('4Q78',)
# ('4Q78',)
# ('4Q82',)
# ('4Q82',)
# ('4Q82',)
# ('4Q82',)
# ('4Q82',)
# ('4Q83',)
# ('4Q83',)
# ('4Q83',)
# ('4Q83',)
# ('4Q84',)
# ('4Q84',)
# ('4Q85',)
# ('4Q86',)
# ('4Q87',)
# ('4Q87',)
# ('4Q87',)
# ('4Q87',)
# ('4Q87',)
# ('4Q88',)
# ('4Q88',)
# ('4Q88',)
# ('4Q88',)
# ('4Q88',)
# ('4Q97',)
# ('4Q98',)
# ('4Q98',)
# ('4Q103',)
# ('4Q111',)
# ('4Q111',)
# ('4Q128',)
# ('4Q129',)
# ('4Q129',)
# ('4Q130',)
# ('4Q130',)
# ('4Q130',)
# ('4Q135',)
# ('4Q138',)
# ('4Q138',)
# ('4Q140',)
# ('4Q140',)
# ('4Q145',)
# ('5Q1',)
# ('5Q1',)
# ('5Q1',)
# ('5Q1',)
# ('5Q2',)
# ('5Q6',)
# ('8Q3',)
# ('8Q3',)
# ('8Q3',)
# ('8Q3',)
# ('8Q3',)
# ('8Q3',)
# ('8Q3',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('Xq1',)
# ('Xq1',)
# ('Xq1',)
# ('Xq1',)
# ('Xq1',)
# ('Xq2',)
# ('Xq2',)
# ('Xq3',)
# ('Xq3',)
# ('Xq3',)
# ('Xq3',)
# ('Mur1',)
# ('Mur4',)
# ('Mur4',)
# ('Mur4',)
# ('Mur4',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('Xhev/se5',)
# ('Xhev/se5',)
# ('Xhev/se5',)
# ('Xhev/se5',)
# ('34Se1',)
# ('Mas1d',)
# ('Mas1d',)
# ('Mas1e',)
# ('Arugleviticus',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('4Q2',)
# ('4Q11',)
# ('4Q13',)
# ('4Q16',)
# ('4Q22',)
# ('4Q22',)
# ('4Q23',)
# ('4Q26b',)
# ('4Q27',)
# ('4Q29',)
# ('4Q30',)
# ('4Q30',)
# ('4Q33',)
# ('4Q38b',)
# ('4Q41',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q52',)
# ('4Q55',)
# ('4Q55',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q57',)
# ('4Q57',)
# ('4Q58',)
# ('4Q60',)
# ('4Q70',)
# ('4Q70',)
# ('4Q70',)
# ('4Q70',)
# ('4Q70',)
# ('4Q72',)
# ('4Q72',)
# ('4Q72',)
# ('4Q77',)
# ('4Q78',)
# ('4Q99',)
# ('4Q111',)
# ('4Q136',)
# ('4Q137',)
# ('4Q154',)
# ('5Q1',)
# ('8Q2',)
# ('8Q3',)
# ('8Q3',)
# ('11Q1',)
# ('11Q1',)
# ('11Q5',)
# ('11Q5',)
# ('Xq1',)
# ('Xq3',)
# ('Mur4',)
# ('Mur4',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Xhev/se2',)
# ('Xhev/se5',)
# ('Xhev/se5',)
# ('34Se1',)
# ('Xjudges',)
# ('1Q6',)
# ('1Q7',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q13',)
# ('2Q15',)
# ('2Q16',)
# ('4Q1',)
# ('4Q1',)
# ('4Q1',)
# ('4Q1',)
# ('4Q1',)
# ('4Q1',)
# ('4Q1',)
# ('4Q2',)
# ('4Q3',)
# ('4Q4',)
# ('4Q7',)
# ('4Q11',)
# ('4Q11',)
# ('4Q11',)
# ('4Q11',)
# ('4Q13',)
# ('4Q13',)
# ('4Q13',)
# ('4Q13',)
# ('4Q13',)
# ('4Q13',)
# ('4Q13',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q24',)
# ('4Q24',)
# ('4Q25',)
# ('4Q25',)
# ('4Q26',)
# ('4Q26a',)
# ('4Q26b',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q28',)
# ('4Q29',)
# ('4Q29',)
# ('4Q29',)
# ('4Q30',)
# ('4Q30',)
# ('4Q30',)
# ('4Q31',)
# ('4Q31',)
# ('4Q33',)
# ('4Q33',)
# ('4Q33',)
# ('4Q33',)
# ('4Q33',)
# ('4Q34',)
# ('4Q35',)
# ('4Q35',)
# ('4Q35',)
# ('4Q37',)
# ('4Q38',)
# ('4Q40',)
# ('4Q40',)
# ('4Q41',)
# ('4Q41',)
# ('4Q41',)
# ('4Q47',)
# ('4Q47',)
# ('4Q47',)
# ('4Q48',)
# ('4Q49',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q52',)
# ('4Q52',)
# ('4Q52',)
# ('4Q53',)
# ('4Q53',)
# ('4Q55',)
# ('4Q55',)
# ('4Q55',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q57',)
# ('4Q57',)
# ('4Q57',)
# ('4Q58',)
# ('4Q60',)
# ('4Q60',)
# ('4Q66',)
# ('4Q67',)
# ('4Q70',)
# ('4Q72',)
# ('4Q72a',)
# ('4Q82',)
# ('4Q82',)
# ('4Q82',)
# ('4Q83',)
# ('4Q83',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q104',)
# ('4Q109',)
# ('4Q109',)
# ('4Q110',)
# ('4Q110',)
# ('4Q111',)
# ('4Q111',)
# ('4Q111',)
# ('4Q112',)
# ('4Q114',)
# ('4Q129',)
# ('4Q129',)
# ('4Q130',)
# ('4Q130',)
# ('4Q133',)
# ('4Q134',)
# ('4Q135',)
# ('4Q135',)
# ('4Q137',)
# ('4Q137',)
# ('4Q137',)
# ('4Q138',)
# ('4Q140',)
# ('4Q140',)
# ('4Q145',)
# ('4Q145',)
# ('4Q155',)
# ('5Q1',)
# ('6Q4',)
# ('8Q3',)
# ('8Q3',)
# ('8Q3',)
# ('8Q3',)
# ('8Q3',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q7',)
# ('Xq1',)
# ('Xq1',)
# ('Xq1',)
# ('Xq1',)
# ('Xq2',)
# ('Xq2',)
# ('Xq2',)
# ('Xq3',)
# ('Xq3',)
# ('Mur1',)
# ('Mur1',)
# ('Mur4',)
# ('Mur4',)
# ('Mur4',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('5/6hev1a',)
# ('5/6hev1b',)
# ('Xhev/se2',)
# ('Xhev/se5',)
# ('Xhev/se5',)
# ('34Se1',)
# ('34Se1',)
# ('Mas1b',)
# ('Mas1b',)
# ('1Q4',)
# ('1Q5',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('4Q1',)
# ('4Q1',)
# ('4Q1',)
# ('4Q2',)
# ('4Q6',)
# ('4Q11',)
# ('4Q11',)
# ('4Q14',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q23',)
# ('4Q23',)
# ('4Q26a',)
# ('4Q27',)
# ('4Q28',)
# ('4Q30',)
# ('4Q30',)
# ('4Q30',)
# ('4Q30',)
# ('4Q33',)
# ('4Q34',)
# ('4Q35',)
# ('4Q41',)
# ('4Q45',)
# ('4Q47',)
# ('4Q47',)
# ('4Q47',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q54',)
# ('4Q54',)
# ('4Q55',)
# ('4Q57',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q61',)
# ('4Q70',)
# ('4Q72',)
# ('4Q72',)
# ('4Q76',)
# ('4Q80',)
# ('4Q82',)
# ('4Q83',)
# ('4Q84',)
# ('4Q85',)
# ('4Q87',)
# ('4Q89',)
# ('4Q95',)
# ('4Q103',)
# ('4Q112',)
# ('4Q113',)
# ('4Q128',)
# ('4Q129',)
# ('4Q129',)
# ('4Q134',)
# ('4Q135',)
# ('4Q135',)
# ('4Q140',)
# ('4Q140',)
# ('4Q142',)
# ('8Q1',)
# ('8Q3',)
# ('8Q3',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('Xq1',)
# ('Xq2',)
# ('Xq2',)
# ('Xq2',)
# ('Xq3',)
# ('Xq3',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('5/6hev1b',)
# ('Mas1b',)
# ('1Q3',)
# ('1Q5',)
# ('1Q5',)
# ('1Q5',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Qisaa',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q8',)
# ('1Q71',)
# ('2Q13',)
# ('2Q13',)
# ('2Q13',)
# ('2Q13',)
# ('2Q16',)
# ('4Q1',)
# ('4Q2',)
# ('4Q2',)
# ('4Q3',)
# ('4Q10',)
# ('4Q11',)
# ('4Q11',)
# ('4Q11',)
# ('4Q13',)
# ('4Q13',)
# ('4Q14',)
# ('4Q14',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q22',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q23',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q24',)
# ('4Q25',)
# ('4Q25',)
# ('4Q26',)
# ('4Q26a',)
# ('4Q26a',)
# ('4Q26c',)
# ('4Q26c',)
# ('4Q26c',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q27',)
# ('4Q28',)
# ('4Q29',)
# ('4Q29',)
# ('4Q30',)
# ('4Q30',)
# ('4Q30',)
# ('4Q31',)
# ('4Q31',)
# ('4Q33',)
# ('4Q34',)
# ('4Q34',)
# ('4Q35',)
# ('4Q35',)
# ('4Q35',)
# ('4Q35',)
# ('4Q37',)
# ('4Q38',)
# ('4Q38a',)
# ('4Q38a',)
# ('4Q41',)
# ('4Q41',)
# ('4Q42',)
# ('4Q44',)
# ('4Q45',)
# ('4Q45',)
# ('4Q45',)
# ('4Q45',)
# ('4Q47',)
# ('4Q47',)
# ('4Q47',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q51',)
# ('4Q52',)
# ('4Q53',)
# ('4Q53',)
# ('4Q53',)
# ('4Q55',)
# ('4Q55',)
# ('4Q55',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q56',)
# ('4Q57',)
# ('4Q57',)
# ('4Q57',)
# ('4Q57',)
# ('4Q57',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q58',)
# ('4Q59',)
# ('4Q60',)
# ('4Q60',)
# ('4Q61',)
# ('4Q61',)
# ('4Q62',)
# ('4Q63',)
# ('4Q65',)
# ('4Q70',)
# ('4Q72',)
# ('4Q72',)
# ('4Q72',)
# ('4Q76',)
# ('4Q79',)
# ('4Q80',)
# ('4Q81',)
# ('4Q82',)
# ('4Q82',)
# ('4Q82',)
# ('4Q82',)
# ('4Q83',)
# ('4Q83',)
# ('4Q83',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q84',)
# ('4Q85',)
# ('4Q85',)
# ('4Q86',)
# ('4Q86',)
# ('4Q87',)
# ('4Q87',)
# ('4Q87',)
# ('4Q87',)
# ('4Q87',)
# ('4Q88',)
# ('4Q90',)
# ('4Q90',)
# ('4Q98',)
# ('4Q98',)
# ('4Q99',)
# ('4Q100',)
# ('4Q103',)
# ('4Q103',)
# ('4Q103',)
# ('4Q107',)
# ('4Q107',)
# ('4Q111',)
# ('4Q111',)
# ('4Q112',)
# ('4Q113',)
# ('4Q113',)
# ('4Q114',)
# ('4Q114',)
# ('4Q114',)
# ('4Q114',)
# ('4Q114',)
# ('4Q129',)
# ('4Q137',)
# ('4Q138',)
# ('4Q140',)
# ('4Q141',)
# ('8Q3',)
# ('8Q4',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q1',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q5',)
# ('11Q7',)
# ('11Q7',)
# ('11Q7',)
# ('11Q8',)
# ('Xq2',)
# ('Xq3',)
# ('Xq3',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('Mur88',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('5/6hev1b',)
# ('Mas1a',)
# ('Mas1b',)
# ('Mas1b',)
# ('Mas1b',)
# ('Mas1b',)
# ('Mas1e',)
# ('Mas1e',)
# ('Mas1e',)
# ('Mas1e',)
# 6646

# %% [markdown]
# ## Calculate average fullness of all features together and separately

# %%
feature_count_dict
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'nouns_adjectives_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 774, 0: 94}),
#                           'MT': defaultdict(int, {1: 540, 0: 335}),
#                           'Mur3': defaultdict(int, {1: 1}),
#                           '4Q56': defaultdict(int, {0: 15, 1: 14}),
#                           '4Q59': defaultdict(int, {0: 4, 1: 5}),
#                           '4Q60': defaultdict(int, {0: 5, 1: 2}),
#                           '1Q8': defaultdict(int, {1: 103, 0: 83}),
#                           '4Q57': defaultdict(int, {1: 31, 0: 3}),
#                           '4Q55': defaultdict(int, {1: 9, 0: 9}),
#                           '4Q68': defaultdict(int, {0: 1}),
#                           '4Q62': defaultdict(int, {0: 1}),
#                           '4Q61': defaultdict(int, {0: 3}),
#                           '4Q58': defaultdict(int, {0: 11, 1: 10}),
#                           '4Q62a': defaultdict(int, {1: 1}),
#                           '4Q67': defaultdict(int, {0: 1})}),
#              'nouns_adjectives_single': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 526, 0: 64}),
#                           'MT': defaultdict(int, {1: 224, 0: 372}),
#                           'Mur3': defaultdict(int, {0: 2}),
#                           '4Q63': defaultdict(int, {0: 1}),
#                           '4Q60': defaultdict(int, {0: 6, 1: 2}),
#                           '4Q59': defaultdict(int, {0: 10, 1: 1}),
#                           '4Q56': defaultdict(int, {0: 20, 1: 7}),
#                           '1Q8': defaultdict(int, {0: 83, 1: 41}),
#                           '4Q57': defaultdict(int, {1: 18}),
#                           '4Q55': defaultdict(int, {0: 8, 1: 6}),
#                           '4Q68': defaultdict(int, {0: 1}),
#                           '4Q64': defaultdict(int, {0: 1}),
#                           '4Q62': defaultdict(int, {1: 1}),
#                           '4Q61': defaultdict(int, {0: 1, 1: 1}),
#                           '4Q58': defaultdict(int, {0: 6, 1: 2}),
#                           '4Q62a': defaultdict(int, {1: 1, 0: 1}),
#                           '4Q66': defaultdict(int, {1: 1})}),
#              'nouns_adjectives_first': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 259, 0: 72}),
#                           'MT': defaultdict(int, {1: 95, 0: 237}),
#                           '4Q59': defaultdict(int, {0: 2}),
#                           '4Q56': defaultdict(int, {0: 8, 1: 4}),
#                           '4Q60': defaultdict(int, {0: 2}),
#                           '4Q65': defaultdict(int, {1: 1, 0: 1}),
#                           '4Q57': defaultdict(int, {1: 7, 0: 3}),
#                           '4Q55': defaultdict(int, {0: 3, 1: 1}),
#                           '4Q68': defaultdict(int, {0: 2}),
#                           '1Q8': defaultdict(int, {0: 42, 1: 21}),
#                           '4Q58': defaultdict(int, {0: 7, 1: 1}),
#                           '4Q67': defaultdict(int, {0: 1}),
#                           '4Q66': defaultdict(int, {0: 1})}),
#              'ptca_qal_first': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 351, 0: 60}),
#                           'MT': defaultdict(int, {0: 312, 1: 104}),
#                           '4Q60': defaultdict(int, {0: 6}),
#                           '4Q56': defaultdict(int, {0: 17, 1: 3}),
#                           '4Q55': defaultdict(int, {1: 7, 0: 3}),
#                           '4Q57': defaultdict(int, {1: 20, 0: 2}),
#                           '1Q8': defaultdict(int, {1: 38, 0: 36}),
#                           '4Q59': defaultdict(int, {0: 2, 1: 2}),
#                           '4Q62': defaultdict(int, {0: 3}),
#                           '4Q58': defaultdict(int, {0: 7, 1: 1}),
#                           '4Q68': defaultdict(int, {1: 1})}),
#              'ptcp_qal_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 68, 0: 6}),
#                           'MT': defaultdict(int, {0: 9, 1: 68}),
#                           '4Q57': defaultdict(int, {1: 2}),
#                           '4Q56': defaultdict(int, {1: 1, 0: 1}),
#                           '4Q55': defaultdict(int, {1: 1}),
#                           '1Q8': defaultdict(int, {1: 16, 0: 4}),
#                           '4Q58': defaultdict(int, {1: 5}),
#                           '4Q66': defaultdict(int, {1: 1})}),
#              'niph_hiph_pe_yod_first': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 126, 0: 4}),
#                           'MT': defaultdict(int, {1: 127, 0: 6}),
#                           '4Q59': defaultdict(int, {1: 2}),
#                           '4Q55': defaultdict(int, {1: 2}),
#                           '4Q56': defaultdict(int, {1: 8}),
#                           '1Q8': defaultdict(int, {1: 21, 0: 3}),
#                           '4Q57': defaultdict(int, {1: 4}),
#                           '4Q62': defaultdict(int, {1: 1}),
#                           '4Q58': defaultdict(int, {1: 5})}),
#              'infa_qal_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 18, 0: 9}),
#                           'MT': defaultdict(int, {1: 16, 0: 13}),
#                           '4Q56': defaultdict(int, {0: 2}),
#                           '4Q55': defaultdict(int, {1: 2}),
#                           '1Q8': defaultdict(int, {0: 1, 1: 3}),
#                           '4Q57': defaultdict(int, {1: 1}),
#                           '4Q58': defaultdict(int, {0: 1}),
#                           '4Q60': defaultdict(int, {1: 1})}),
#              'infc_qal_triliteral_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 80, 0: 14}),
#                           'MT': defaultdict(int, {0: 85, 1: 9}),
#                           '4Q60': defaultdict(int, {0: 2}),
#                           '4Q56': defaultdict(int, {0: 7}),
#                           '4Q55': defaultdict(int, {0: 2, 1: 1}),
#                           '4Q57': defaultdict(int, {1: 3}),
#                           '1Q8': defaultdict(int, {0: 9, 1: 5}),
#                           '4Q58': defaultdict(int, {0: 1}),
#                           '4Q67': defaultdict(int, {0: 1}),
#                           '4Q66': defaultdict(int, {1: 1})}),
#              'infc_qal_lamed_he_nme': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 34}),
#                           'MT': defaultdict(int, {1: 33, 0: 2}),
#                           '4Q55': defaultdict(int, {1: 1}),
#                           '4Q57': defaultdict(int, {1: 1}),
#                           '4Q61': defaultdict(int, {1: 1}),
#                           '4Q58': defaultdict(int, {1: 3}),
#                           '1Q8': defaultdict(int, {1: 6})}),
#              'hiphil_triliteral_with_hireq_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 225, 0: 15}),
#                           'MT': defaultdict(int, {1: 230, 0: 14}),
#                           '4Q63': defaultdict(int, {1: 1}),
#                           '4Q60': defaultdict(int, {1: 2}),
#                           '4Q56': defaultdict(int, {1: 8, 0: 2}),
#                           '4Q59': defaultdict(int, {1: 1}),
#                           '4Q65': defaultdict(int, {0: 1}),
#                           '1Q8': defaultdict(int, {1: 52, 0: 4}),
#                           '4Q55': defaultdict(int, {1: 3}),
#                           '4Q57': defaultdict(int, {1: 5}),
#                           '4Q62': defaultdict(int, {1: 1}),
#                           '4Q61': defaultdict(int, {1: 2}),
#                           '4Q58': defaultdict(int, {1: 14})})})

# %%
# Aggregate manuscripts

all_spelling = []
defective_feature_spelling = collections.defaultdict(int)
full_feature_spelling = collections.defaultdict(int)
feature_spelling_count = collections.defaultdict(int)

for feat, man_dict in feature_count_dict.items():
    for man, fullness_dict in man_dict.items():
        
        full_count = fullness_dict.get(1, 0)
        all_spelling += ([1] * full_count)
        
        defective_count = fullness_dict.get(0, 0)
        all_spelling += ([0] * defective_count)
        
        full_feature_spelling[feat] += full_count
        defective_feature_spelling[feat] += defective_count
        feature_spelling_count[feat] += full_count + defective_count

# %%
# Aggregate features

all_man_spelling = collections.defaultdict(lambda: collections.defaultdict(int))

for feat, man_dict in feature_count_dict.items():
    for man, fullness_dict in man_dict.items():
        
        full_count = fullness_dict.get(1, 0)
        all_man_spelling[man]['full'] += full_count
        
        defective_count = fullness_dict.get(0, 0)
        all_man_spelling[man]['defective'] += defective_count

# %%
all_man_spelling
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'1Qisaa': defaultdict(int, {'full': 2461, 'defective': 338}),
#              'MT': defaultdict(int, {'full': 1446, 'defective': 1385}),
#              'Mur3': defaultdict(int, {'full': 1, 'defective': 2}),
#              '4Q56': defaultdict(int, {'full': 45, 'defective': 72}),
#              '4Q59': defaultdict(int, {'full': 11, 'defective': 18}),
#              '4Q60': defaultdict(int, {'full': 7, 'defective': 21}),
#              '1Q8': defaultdict(int, {'full': 306, 'defective': 265}),
#              '4Q57': defaultdict(int, {'full': 92, 'defective': 8}),
#              '4Q55': defaultdict(int, {'full': 33, 'defective': 25}),
#              '4Q68': defaultdict(int, {'full': 1, 'defective': 4}),
#              '4Q62': defaultdict(int, {'full': 3, 'defective': 4}),
#              '4Q61': defaultdict(int, {'full': 4, 'defective': 4}),
#              '4Q58': defaultdict(int, {'full': 41, 'defective': 33}),
#              '4Q62a': defaultdict(int, {'full': 2, 'defective': 1}),
#              '4Q67': defaultdict(int, {'full': 0, 'defective': 3}),
#              '4Q63': defaultdict(int, {'full': 1, 'defective': 1}),
#              '4Q64': defaultdict(int, {'full': 0, 'defective': 1}),
#              '4Q66': defaultdict(int, {'full': 3, 'defective': 1}),
#              '4Q65': defaultdict(int, {'full': 1, 'defective': 2})})

# %%
feature_spelling_count
# Out:
# defaultdict(int,
#             {'nouns_adjectives_last': 2055,
#              'nouns_adjectives_single': 1407,
#              'nouns_adjectives_first': 770,
#              'ptca_qal_first': 975,
#              'ptcp_qal_last': 182,
#              'niph_hiph_pe_yod_first': 309,
#              'infa_qal_last': 67,
#              'infc_qal_triliteral_last': 220,
#              'infc_qal_lamed_he_nme': 81,
#              'hiphil_triliteral_with_hireq_last': 580})

# %%
full_feature_spelling
# Out:
# defaultdict(int,
#             {'nouns_adjectives_last': 1490,
#              'nouns_adjectives_single': 831,
#              'nouns_adjectives_first': 389,
#              'ptca_qal_first': 527,
#              'ptcp_qal_last': 162,
#              'niph_hiph_pe_yod_first': 296,
#              'infa_qal_last': 41,
#              'infc_qal_triliteral_last': 99,
#              'infc_qal_lamed_he_nme': 79,
#              'hiphil_triliteral_with_hireq_last': 544})

# %%
defective_feature_spelling
# Out:
# defaultdict(int,
#             {'nouns_adjectives_last': 565,
#              'nouns_adjectives_single': 576,
#              'nouns_adjectives_first': 381,
#              'ptca_qal_first': 448,
#              'ptcp_qal_last': 20,
#              'niph_hiph_pe_yod_first': 13,
#              'infa_qal_last': 26,
#              'infc_qal_triliteral_last': 121,
#              'infc_qal_lamed_he_nme': 2,
#              'hiphil_triliteral_with_hireq_last': 36})

# %%
def sample_feature_fullness_spelling(spellings, n_samples):
    full_counts = []

    for i in range(n_samples):
        sample = random.choices(spellings, k=len(spellings))
        full_count = np.sum(sample.count(1))
        full_counts.append(full_count)

    return full_counts

# %%
n_samples = 1000

feature_fullness_dict = {}

for feature, full_count in full_feature_spelling.items():
    def_count = defective_feature_spelling.get(feature, 0)
    feature_spellings = [0]* def_count + [1] * full_count
    full_counts = sample_feature_fullness_spelling(feature_spellings, n_samples)
    full_feature_fractions = [count / len(feature_spellings) for count in full_counts]
    feature_fullness_dict[feature] = full_feature_fractions

# %%
count_dfs = {}

for feature, counts in feature_fullness_dict.items():
    print(feature)
    df = pd.DataFrame(counts, columns=['counts'])
    df['feature'] = feature
    count_dfs[feature] = df
    
feature_df = pd.concat(count_dfs)
# Out:
# nouns_adjectives_last
# nouns_adjectives_single
# nouns_adjectives_first
# ptca_qal_first
# ptcp_qal_last
# niph_hiph_pe_yod_first
# infa_qal_last
# infc_qal_triliteral_last
# infc_qal_lamed_he_nme
# hiphil_triliteral_with_hireq_last

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid",
        font_scale=2,
        rc = {'figure.figsize':(12,8)})


g = sns.boxplot(x="feature", y="counts", data=feature_df)
g.set_xticklabels(g.get_xticklabels(), rotation=90)



plt.savefig('fullness_features.png', bbox_inches='tight')

# %% [markdown]
# # Do the manuscripts

# %%
n_samples = 1000

manuscript_fullness_dict = {}

for man, count_dict in all_man_spelling.items():
    man_spellings = [0]* count_dict.get('defective', 0) + [1] * count_dict.get('full', 0)
    full_counts = sample_feature_fullness_spelling(man_spellings, n_samples)
    full_man_fractions = [count / len(man_spellings) for count in full_counts]
    manuscript_fullness_dict[man] = full_man_fractions

# %%
count_man_dfs = {}

for man, counts in manuscript_fullness_dict.items():
    df = pd.DataFrame(counts, columns=['counts'])
    df['manuscript'] = man
    count_man_dfs[man] = df
    
man_df = pd.concat(count_man_dfs)

# %%
g = sns.boxplot(x="manuscript", y="counts", data=man_df)
g.set_xticklabels(g.get_xticklabels(), rotation=90)


plt.savefig('fullness_manuscripts.png', bbox_inches='tight')

# %%
## All features per manuscript

# %%
feature_count_dict
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'nouns_adjectives_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 774, 0: 94}),
#                           'MT': defaultdict(int, {1: 540, 0: 335}),
#                           'Mur3': defaultdict(int, {1: 1}),
#                           '4Q56': defaultdict(int, {0: 15, 1: 14}),
#                           '4Q59': defaultdict(int, {0: 4, 1: 5}),
#                           '4Q60': defaultdict(int, {0: 5, 1: 2}),
#                           '1Q8': defaultdict(int, {1: 103, 0: 83}),
#                           '4Q57': defaultdict(int, {1: 31, 0: 3}),
#                           '4Q55': defaultdict(int, {1: 9, 0: 9}),
#                           '4Q68': defaultdict(int, {0: 1}),
#                           '4Q62': defaultdict(int, {0: 1}),
#                           '4Q61': defaultdict(int, {0: 3}),
#                           '4Q58': defaultdict(int, {0: 11, 1: 10}),
#                           '4Q62a': defaultdict(int, {1: 1}),
#                           '4Q67': defaultdict(int, {0: 1})}),
#              'nouns_adjectives_single': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 526, 0: 64}),
#                           'MT': defaultdict(int, {1: 224, 0: 372}),
#                           'Mur3': defaultdict(int, {0: 2}),
#                           '4Q63': defaultdict(int, {0: 1}),
#                           '4Q60': defaultdict(int, {0: 6, 1: 2}),
#                           '4Q59': defaultdict(int, {0: 10, 1: 1}),
#                           '4Q56': defaultdict(int, {0: 20, 1: 7}),
#                           '1Q8': defaultdict(int, {0: 83, 1: 41}),
#                           '4Q57': defaultdict(int, {1: 18}),
#                           '4Q55': defaultdict(int, {0: 8, 1: 6}),
#                           '4Q68': defaultdict(int, {0: 1}),
#                           '4Q64': defaultdict(int, {0: 1}),
#                           '4Q62': defaultdict(int, {1: 1}),
#                           '4Q61': defaultdict(int, {0: 1, 1: 1}),
#                           '4Q58': defaultdict(int, {0: 6, 1: 2}),
#                           '4Q62a': defaultdict(int, {1: 1, 0: 1}),
#                           '4Q66': defaultdict(int, {1: 1})}),
#              'nouns_adjectives_first': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 259, 0: 72}),
#                           'MT': defaultdict(int, {1: 95, 0: 237}),
#                           '4Q59': defaultdict(int, {0: 2}),
#                           '4Q56': defaultdict(int, {0: 8, 1: 4}),
#                           '4Q60': defaultdict(int, {0: 2}),
#                           '4Q65': defaultdict(int, {1: 1, 0: 1}),
#                           '4Q57': defaultdict(int, {1: 7, 0: 3}),
#                           '4Q55': defaultdict(int, {0: 3, 1: 1}),
#                           '4Q68': defaultdict(int, {0: 2}),
#                           '1Q8': defaultdict(int, {0: 42, 1: 21}),
#                           '4Q58': defaultdict(int, {0: 7, 1: 1}),
#                           '4Q67': defaultdict(int, {0: 1}),
#                           '4Q66': defaultdict(int, {0: 1})}),
#              'ptca_qal_first': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 351, 0: 60}),
#                           'MT': defaultdict(int, {0: 312, 1: 104}),
#                           '4Q60': defaultdict(int, {0: 6}),
#                           '4Q56': defaultdict(int, {0: 17, 1: 3}),
#                           '4Q55': defaultdict(int, {1: 7, 0: 3}),
#                           '4Q57': defaultdict(int, {1: 20, 0: 2}),
#                           '1Q8': defaultdict(int, {1: 38, 0: 36}),
#                           '4Q59': defaultdict(int, {0: 2, 1: 2}),
#                           '4Q62': defaultdict(int, {0: 3}),
#                           '4Q58': defaultdict(int, {0: 7, 1: 1}),
#                           '4Q68': defaultdict(int, {1: 1})}),
#              'ptcp_qal_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 68, 0: 6}),
#                           'MT': defaultdict(int, {0: 9, 1: 68}),
#                           '4Q57': defaultdict(int, {1: 2}),
#                           '4Q56': defaultdict(int, {1: 1, 0: 1}),
#                           '4Q55': defaultdict(int, {1: 1}),
#                           '1Q8': defaultdict(int, {1: 16, 0: 4}),
#                           '4Q58': defaultdict(int, {1: 5}),
#                           '4Q66': defaultdict(int, {1: 1})}),
#              'niph_hiph_pe_yod_first': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 126, 0: 4}),
#                           'MT': defaultdict(int, {1: 127, 0: 6}),
#                           '4Q59': defaultdict(int, {1: 2}),
#                           '4Q55': defaultdict(int, {1: 2}),
#                           '4Q56': defaultdict(int, {1: 8}),
#                           '1Q8': defaultdict(int, {1: 21, 0: 3}),
#                           '4Q57': defaultdict(int, {1: 4}),
#                           '4Q62': defaultdict(int, {1: 1}),
#                           '4Q58': defaultdict(int, {1: 5})}),
#              'infa_qal_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 18, 0: 9}),
#                           'MT': defaultdict(int, {1: 16, 0: 13}),
#                           '4Q55': defaultdict(int, {1: 2}),
#                           '4Q56': defaultdict(int, {0: 2}),
#                           '1Q8': defaultdict(int, {0: 1, 1: 3}),
#                           '4Q57': defaultdict(int, {1: 1}),
#                           '4Q58': defaultdict(int, {0: 1}),
#                           '4Q60': defaultdict(int, {1: 1})}),
#              'infc_qal_triliteral_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 80, 0: 14}),
#                           'MT': defaultdict(int, {0: 85, 1: 9}),
#                           '4Q60': defaultdict(int, {0: 2}),
#                           '4Q56': defaultdict(int, {0: 7}),
#                           '4Q55': defaultdict(int, {0: 2, 1: 1}),
#                           '4Q57': defaultdict(int, {1: 3}),
#                           '1Q8': defaultdict(int, {0: 9, 1: 5}),
#                           '4Q58': defaultdict(int, {0: 1}),
#                           '4Q67': defaultdict(int, {0: 1}),
#                           '4Q66': defaultdict(int, {1: 1})}),
#              'infc_qal_lamed_he_nme': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 34}),
#                           'MT': defaultdict(int, {1: 33, 0: 2}),
#                           '4Q55': defaultdict(int, {1: 1}),
#                           '4Q57': defaultdict(int, {1: 1}),
#                           '4Q61': defaultdict(int, {1: 1}),
#                           '4Q58': defaultdict(int, {1: 3}),
#                           '1Q8': defaultdict(int, {1: 6})}),
#              'hiphil_triliteral_with_hireq_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'1Qisaa': defaultdict(int, {1: 225, 0: 15}),
#                           'MT': defaultdict(int, {1: 230, 0: 14}),
#                           '4Q63': defaultdict(int, {1: 1}),
#                           '4Q60': defaultdict(int, {1: 2}),
#                           '4Q56': defaultdict(int, {1: 8, 0: 2}),
#                           '4Q59': defaultdict(int, {1: 1}),
#                           '4Q65': defaultdict(int, {0: 1}),
#                           '1Q8': defaultdict(int, {1: 52, 0: 4}),
#                           '4Q55': defaultdict(int, {1: 3}),
#                           '4Q57': defaultdict(int, {1: 5}),
#                           '4Q62': defaultdict(int, {1: 1}),
#                           '4Q61': defaultdict(int, {1: 2}),
#                           '4Q58': defaultdict(int, {1: 14})})})

# %%
def calculate_fractions(man_count_dict, n_samples):
    man_feat_fullness_dict = {}

    for man, count_dict in man_count_dict.items():
        man_spellings = [0]* count_dict.get(0, 0) + [1] * count_dict.get(1, 0)
    
        full_counts = sample_feature_fullness_spelling(man_spellings, n_samples)
        full_man_fractions = [count / len(man_spellings) for count in full_counts]
        man_feat_fullness_dict[man] = full_man_fractions
    return man_feat_fullness_dict

# %%
n_samples = 1000

for feature, man_count_dict in feature_count_dict.items():
    man_feat_fullness_dict = calculate_fractions(man_count_dict, n_samples)
    man_df = make_feature_df(man_feat_fullness_dict)
    
    g = sns.boxplot(x="manuscript", y="counts", data=man_df)
    g.set_xticklabels(g.get_xticklabels(), rotation=90)

    plt.savefig(f'fullness_{feature}_manuscripts.png', bbox_inches='tight')
    plt.clf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23848/2156293304.py in <module>
#       1 n_samples = 1000
#       2
# ----> 3 for feature, man_count_dict in feature_count_dict.items():
#       4     man_feat_fullness_dict = calculate_fractions(man_count_dict, n_samples)
#       5     man_df = make_feature_df(man_feat_fullness_dict)
#
# NameError: name 'feature_count_dict' is not defined

# %% [markdown]
# # ALL DATA OF ONE BOOK

# %%
BOOK = 'Isaiah'
IMAGE_FOLDER = './images_manuscr_comparisons'

# %%
def make_feature_df(man_feat_fullness_dict):
    count_man_dfs = {}

    for man, counts in man_feat_fullness_dict.items():
        df = pd.DataFrame(counts, columns=['counts'])
        df['manuscript'] = man
        count_man_dfs[man] = df
    
    man_df = pd.concat(count_man_dfs)
    return man_df

# %%
def make_image_folder_name(image_folder, book_name):
    return os.path.join(image_folder, book_name)
    

def make_image_folder(folder_name):
    
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)

# %%
isa_df = dat[dat.book2 == BOOK]
isa_df['feature_type'] = isa_df['feature'] + '_' + isa_df['type']
isa_df.shape
# Out:
# C:\Users\geitb\AppData\Local\Temp/ipykernel_23848/3956005299.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isa_df['feature_type'] = isa_df['feature'] + '_' + isa_df['type']
# (7044, 41)

# %%
image_folder_name = make_image_folder_name(IMAGE_FOLDER, BOOK)
make_image_folder(image_folder_name)

# %%
feat_man_count_dict_total = collections.defaultdict(lambda: collections.defaultdict(lambda: collections.defaultdict(int)))

for _, row in isa_df.iterrows():
    scroll = row.scroll
    ft = row.feature_type
    has_vl = row.has_vowel_letter
    feat_man_count_dict_total[ft][scroll][has_vl] += 1

# %%
n_samples = 1000

for feature, man_count_dict in feat_man_count_dict_total.items():
    man_feat_fullness_dict = calculate_fractions(man_count_dict, n_samples)
    man_df = make_feature_df(man_feat_fullness_dict)
    
    g = sns.boxplot(x="manuscript", y="counts", data=man_df)
    g.set_xticklabels(g.get_xticklabels(), rotation=90)

    image_dir = os.path.join(image_folder_name, f'fullness_{feature}_{BOOK}_manuscripts_total.png')
    plt.savefig(image_dir, bbox_inches='tight')
    plt.clf()

# %%
feat_man_count_dict_total
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'nouns_adjectives_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'MT': defaultdict(int, {1: 568, 0: 360}),
#                           '1Qisaa': defaultdict(int, {1: 817, 0: 111}),
#                           '1Q8': defaultdict(int, {1: 107, 0: 86}),
#                           '4Q55': defaultdict(int, {1: 9, 0: 9}),
#                           '4Q56': defaultdict(int, {0: 14, 1: 14}),
#                           '4Q57': defaultdict(int, {1: 35, 0: 3}),
#                           '4Q58': defaultdict(int, {0: 11, 1: 10}),
#                           '4Q59': defaultdict(int, {0: 4, 1: 5}),
#                           '4Q60': defaultdict(int, {0: 5, 1: 2}),
#                           '4Q61': defaultdict(int, {0: 3}),
#                           '4Q62': defaultdict(int, {0: 1}),
#                           '4Q62a': defaultdict(int, {1: 1}),
#                           '4Q67': defaultdict(int, {0: 1}),
#                           '4Q68': defaultdict(int, {0: 1}),
#                           'Mur3': defaultdict(int, {1: 1})}),
#              'nouns_adjectives_single': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'MT': defaultdict(int, {1: 236, 0: 386}),
#                           '1Qisaa': defaultdict(int, {1: 548, 0: 69}),
#                           '1Q8': defaultdict(int, {0: 83, 1: 41}),
#                           '4Q55': defaultdict(int, {0: 9, 1: 6}),
#                           '4Q56': defaultdict(int, {0: 20, 1: 7}),
#                           '4Q57': defaultdict(int, {1: 20}),
#                           '4Q58': defaultdict(int, {0: 6, 1: 2}),
#                           '4Q59': defaultdict(int, {0: 10, 1: 1}),
#                           '4Q60': defaultdict(int, {0: 6, 1: 2}),
#                           '4Q61': defaultdict(int, {0: 1, 1: 1}),
#                           '4Q62': defaultdict(int, {1: 1}),
#                           '4Q62a': defaultdict(int, {1: 1, 0: 1}),
#                           '4Q63': defaultdict(int, {0: 1}),
#                           '4Q64': defaultdict(int, {0: 1}),
#                           '4Q66': defaultdict(int, {1: 1}),
#                           '4Q68': defaultdict(int, {0: 1}),
#                           'Mur3': defaultdict(int, {0: 2})}),
#              'nouns_adjectives_first': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'MT': defaultdict(int, {1: 96, 0: 270}),
#                           '1Qisaa': defaultdict(int, {1: 276, 0: 87}),
#                           '1Q8': defaultdict(int, {0: 47, 1: 20}),
#                           '4Q55': defaultdict(int, {0: 3, 1: 1}),
#                           '4Q56': defaultdict(int, {0: 10, 1: 4}),
#                           '4Q57': defaultdict(int, {1: 7, 0: 3}),
#                           '4Q58': defaultdict(int, {0: 8, 1: 1}),
#                           '4Q59': defaultdict(int, {0: 2}),
#                           '4Q60': defaultdict(int, {0: 2}),
#                           '4Q62': defaultdict(int, {1: 1}),
#                           '4Q65': defaultdict(int, {1: 1, 0: 1}),
#                           '4Q66': defaultdict(int, {0: 1}),
#                           '4Q67': defaultdict(int, {0: 2}),
#                           '4Q68': defaultdict(int, {0: 2})}),
#              'ptca_qal_first': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'MT': defaultdict(int, {0: 329, 1: 111}),
#                           '1Qisaa': defaultdict(int, {1: 394, 0: 65}),
#                           '1Q8': defaultdict(int, {1: 39, 0: 36}),
#                           '4Q55': defaultdict(int, {1: 7, 0: 3}),
#                           '4Q56': defaultdict(int, {0: 17, 1: 4}),
#                           '4Q57': defaultdict(int, {1: 20, 0: 2}),
#                           '4Q58': defaultdict(int, {0: 7, 1: 1}),
#                           '4Q59': defaultdict(int, {0: 2, 1: 2}),
#                           '4Q60': defaultdict(int, {0: 6}),
#                           '4Q62': defaultdict(int, {0: 3}),
#                           '4Q68': defaultdict(int, {1: 1})}),
#              'ptcp_qal_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'MT': defaultdict(int, {0: 12, 1: 67}),
#                           '1Qisaa': defaultdict(int, {1: 76, 0: 7}),
#                           '1Q8': defaultdict(int, {1: 17, 0: 4}),
#                           '4Q55': defaultdict(int, {1: 1}),
#                           '4Q56': defaultdict(int, {1: 1, 0: 1}),
#                           '4Q57': defaultdict(int, {1: 2}),
#                           '4Q58': defaultdict(int, {1: 5}),
#                           '4Q66': defaultdict(int, {1: 1})}),
#              'niph_hiph_pe_yod_first': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'MT': defaultdict(int, {1: 132, 0: 8}),
#                           '1Qisaa': defaultdict(int, {1: 137, 0: 7}),
#                           '1Q8': defaultdict(int, {1: 21, 0: 3}),
#                           '4Q55': defaultdict(int, {1: 2}),
#                           '4Q56': defaultdict(int, {1: 8}),
#                           '4Q57': defaultdict(int, {1: 4}),
#                           '4Q58': defaultdict(int, {1: 5}),
#                           '4Q59': defaultdict(int, {1: 3}),
#                           '4Q62': defaultdict(int, {1: 1})}),
#              'infa_qal_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'MT': defaultdict(int, {1: 20, 0: 16}),
#                           '1Qisaa': defaultdict(int, {1: 21, 0: 9}),
#                           '1Q8': defaultdict(int, {0: 1, 1: 3}),
#                           '4Q55': defaultdict(int, {1: 2}),
#                           '4Q56': defaultdict(int, {0: 2, 1: 1}),
#                           '4Q57': defaultdict(int, {1: 2}),
#                           '4Q58': defaultdict(int, {0: 1}),
#                           '4Q60': defaultdict(int, {1: 1})}),
#              'infc_qal_triliteral_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'MT': defaultdict(int, {0: 87, 1: 9}),
#                           '1Qisaa': defaultdict(int, {1: 85, 0: 15}),
#                           '1Q8': defaultdict(int, {0: 9, 1: 5}),
#                           '4Q55': defaultdict(int, {0: 2, 1: 1}),
#                           '4Q56': defaultdict(int, {0: 7}),
#                           '4Q57': defaultdict(int, {1: 3}),
#                           '4Q58': defaultdict(int, {0: 1}),
#                           '4Q60': defaultdict(int, {0: 2}),
#                           '4Q66': defaultdict(int, {1: 1}),
#                           '4Q67': defaultdict(int, {0: 1})}),
#              'infc_qal_lamed_he_nme': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'MT': defaultdict(int, {1: 33, 0: 3}),
#                           '1Qisaa': defaultdict(int, {1: 36}),
#                           '1Q8': defaultdict(int, {1: 6}),
#                           '4Q55': defaultdict(int, {1: 1}),
#                           '4Q57': defaultdict(int, {1: 1}),
#                           '4Q58': defaultdict(int, {1: 3}),
#                           '4Q61': defaultdict(int, {1: 1})}),
#              'hiphil_triliteral_with_hireq_last': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'MT': defaultdict(int, {1: 242, 0: 15}),
#                           '1Qisaa': defaultdict(int, {1: 225, 0: 15}),
#                           '1Q8': defaultdict(int, {1: 52, 0: 4}),
#                           '4Q55': defaultdict(int, {1: 3}),
#                           '4Q56': defaultdict(int, {1: 8, 0: 2}),
#                           '4Q57': defaultdict(int, {1: 5}),
#                           '4Q58': defaultdict(int, {1: 14}),
#                           '4Q59': defaultdict(int, {1: 1}),
#                           '4Q60': defaultdict(int, {1: 2}),
#                           '4Q61': defaultdict(int, {1: 2}),
#                           '4Q62': defaultdict(int, {1: 1}),
#                           '4Q63': defaultdict(int, {1: 1}),
#                           '4Q65': defaultdict(int, {0: 1})})})

# %% [markdown]
# ## Only features with all data

# %%
# Aggregate manuscripts

all_spelling = []
defective_feature_spelling = collections.defaultdict(int)
full_feature_spelling = collections.defaultdict(int)
feature_spelling_count = collections.defaultdict(int)

for feat, man_dict in feat_man_count_dict_total.items():
    for man, fullness_dict in man_dict.items():
        
        full_count = fullness_dict.get(1, 0)
        all_spelling += ([1] * full_count)
        
        defective_count = fullness_dict.get(0, 0)
        all_spelling += ([0] * defective_count)
        
        full_feature_spelling[feat] += full_count
        defective_feature_spelling[feat] += defective_count
        feature_spelling_count[feat] += full_count + defective_count

# %%
n_samples = 1000

feature_fullness_dict = {}

for feature, full_count in full_feature_spelling.items():
    def_count = defective_feature_spelling.get(feature, 0)
    feature_spellings = [0]* def_count + [1] * full_count
    full_counts = sample_feature_fullness_spelling(feature_spellings, n_samples)
    full_feature_fractions = [count / len(feature_spellings) for count in full_counts]
    feature_fullness_dict[feature] = full_feature_fractions

# %%
feature_df = make_feature_df(feature_fullness_dict)

# %%
feature_df.head()
# Out:
#                            counts             manuscript
# nouns_adjectives_last 0  0.712121  nouns_adjectives_last
#                       1  0.717631  nouns_adjectives_last
#                       2  0.713039  nouns_adjectives_last
#                       3  0.714417  nouns_adjectives_last
#                       4  0.726354  nouns_adjectives_last

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid",
        font_scale=2,
        rc = {'figure.figsize':(12,8)})

g = sns.boxplot(x='manuscript', y='counts', data=feature_df)
g.set_xticklabels(g.get_xticklabels(), rotation=90)

image_dir = os.path.join(image_folder_name, f'fullness_features_{BOOK}_total.png')
plt.savefig(image_dir, bbox_inches='tight')

# %% [markdown]
# ## Only manuscripts with all data

# %%
# Aggregate features

all_man_spelling = collections.defaultdict(lambda: collections.defaultdict(int))

for feat, man_dict in feat_man_count_dict_total.items():
    for man, fullness_dict in man_dict.items():
        
        full_count = fullness_dict.get(1, 0)
        all_man_spelling[man]['full'] += full_count
        
        defective_count = fullness_dict.get(0, 0)
        all_man_spelling[man]['defective'] += defective_count

# %%
n_samples = 1000

manuscript_fullness_dict = {}

for man, count_dict in all_man_spelling.items():
    man_spellings = [0]* count_dict.get('defective', 0) + [1] * count_dict.get('full', 0)
    full_counts = sample_feature_fullness_spelling(man_spellings, n_samples)
    full_man_fractions = [count / len(man_spellings) for count in full_counts]
    manuscript_fullness_dict[man] = full_man_fractions

# %%
man_df = make_feature_df(manuscript_fullness_dict)

# %%
g = sns.boxplot(x="manuscript", y="counts", data=man_df)
g.set_xticklabels(g.get_xticklabels(), rotation=90)

image_dir = os.path.join(image_folder_name, f'fullness_manuscripts_{BOOK}_total.png')
plt.savefig(image_dir, bbox_inches='tight')

# %%
# GET PARALLELS OF WORDS IN SPECIFIC MANUSCRPT

# %%
scroll = '4Q58'
feature = 'ptca_qal_first'

isa_feat_scroll = isa_df[(isa_df.feature_type == feature) & (isa_df.scroll == scroll)]
nodes = isa_feat_scroll.tf_id

# %%
def get_node_info_from_df(node, df):
    row = isa_df[isa_df.tf_id == node]
    lex = row.lex.iloc[0]
    g_cons = row.g_cons.iloc[0]
    has_vl = row.has_vowel_letter.iloc[0]
    return lex, g_cons, has_vl

# %%
n = 0
unequal_with_mt = 0

count_dict = collections.defaultdict(lambda: collections.defaultdict(int))

for node in nodes:
    #print(hif_match_dict[(node, scroll)])
    
    row = isa_df[isa_df.tf_id == node]
    bo, ch, ve = row.book.iloc[0], row.chapter.iloc[0], row.verse.iloc[0]
    lex, g_cons, has_vl = get_node_info_from_df(node, isa_df)
    print(scroll, ch, ve, lex, g_cons, has_vl)
    n += 1
    corr_nodes = hif_match_dict[(node, scroll)]
    count_dict[scroll][has_vl] += 1
  
    for corr_scr, node in corr_nodes.items():
        corr_lex, corr_g_cons, corr_has_vl = get_node_info_from_df(node, isa_df)
        count_dict[corr_scr][corr_has_vl] += 1
        
        print(corr_scr, corr_lex, corr_g_cons, corr_has_vl)
        
        if corr_scr == 'MT' and has_vl != corr_has_vl:
            unequal_with_mt += 1
        
    print()
    
print(n, unequal_with_mt)
# Out:
# 4Q58 45 20 NF>[ NF>JM 0
# MT NF>[ NF>JM 0
# 1Qisaa NF>[ NWF>JM 1
#
# 4Q58 46 10 >MR[ >MR 0
# MT >MR[ >MR 0
# 1Qisaa >MR[ >MR 0
# 1Q8 >MR[ >MR 0
#
# 4Q58 47 8 JCB[ JCBT 0
# MT JCB[ JWCBT 1
# 1Qisaa JCB[ JWCBT 1
#
# 4Q58 48 13 QR>[ QR> 0
# MT QR>[ QR> 0
# 1Qisaa QR>[ QWRH 1
#
# 4Q58 52 7 >MR[ >MR 0
# MT >MR[ >MR 0
# 1Qisaa >MR[ >WMR 1
#
# 4Q58 53 12 PC<[ PC<JM 0
# MT PC<[ PC<JM 0
# 1Qisaa PC<[ PWC<JM 1
#
# 4Q58 57 13 XSH[ XSH 0
# MT XSH[ XWSH 1
# 1Qisaa XSH[ XWSH 1
#
# 4Q58 57 19 BR>[ BWRH 1
# MT BR>[ BWR> 1
# 1Qisaa BR>[ BWRH 1
#
# 8 2

# %%
count_dict['1Q8'][1]
# Out:
# 39

# %%
count_dict['MT'][1]
# Out:
# 14

# %%
q8 = dat[dat.scroll == '1Q8']

# %%
q8.shape
# Out:
# (584, 40)

# %%
q8_first = q8[q8.chapter < 34]
q8_second = q8[q8.chapter >= 34]

# %%
sum(q8_first.has_vowel_letter)/q8_first.shape[0]
# Out:
# 0.64

# %%
sum(q8_second.has_vowel_letter)/q8_second.shape[0]
# Out:
# 0.5224719101123596
