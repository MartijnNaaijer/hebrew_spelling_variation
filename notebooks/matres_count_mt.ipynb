# %%
import pandas as pd

# %%
dat = pd.read_csv('../data/matres_mt.csv', sep='\t')

# %%
dat.head()
# Out:
#    tf_id scroll     book  chapter  verse     lex g_cons   stem pattern  \
# 0      1     MT  Genesis        1      1       B      B      B       C
# 1      2     MT  Genesis        1      1  R>CJT/  R>CJT  R>CJT   CMCMC
# 2      3     MT  Genesis        1      1    BR>[    BR>    BR>     CCM
# 3      4     MT  Genesis        1      1  >LHJM/  >LHJM    >LH     CCC
# 4      5     MT  Genesis        1      1      >T     >T     >T      CC
#
#   pattern_g_cons  ...   gn   ps    sp  prs  nme hloc prefix rec_signs  \
# 0              C  ...  NaN  NaN  prep  NaN  NaN  NaN    NaN         n
# 1          CMCMC  ...    f  NaN  subs  NaN  NaN  NaN      B     nnnnn
# 2            CCM  ...    m   p3  verb  NaN  NaN  NaN    NaN       nnn
# 3          CCCMC  ...    m  NaN  subs  NaN   JM  NaN    NaN     nnnnn
# 4             CC  ...  NaN  NaN  prep  NaN  NaN  NaN    NaN        nn
#
#   cor_signs heb_g_cons
# 0         n          ב
# 1     nnnnn      ראשית
# 2       nnn        ברא
# ...

# %%
dat.shape
# Out:
# (420484, 23)

# %%
dat.columns
# Out:
# Index(['tf_id', 'scroll', 'book', 'chapter', 'verse', 'lex', 'g_cons', 'stem',
#        'pattern', 'pattern_g_cons', 'vs', 'vt', 'nu', 'gn', 'ps', 'sp', 'prs',
#        'nme', 'hloc', 'prefix', 'rec_signs', 'cor_signs', 'heb_g_cons'],
#       dtype='object')

# %%
dat.pattern
# Out:
# 0             C
# 1         CMCMC
# 2           CCM
# 3           CCC
# 4            CC
#           ...
# 420479     CCCM
# 420480      CCC
# 420481       CC
# 420482        C
# 420483       CC
# Name: pattern, Length: 420484, dtype: object

# %%
word_count_matres = sum([1  if 'M' in pattern else 0 for pattern in dat.pattern if isinstance(pattern, str)])
word_count_matres
# Out:
# 104256

# %%
total_matres = sum([pattern.count('M') for pattern in dat.pattern if isinstance(pattern, str)])

# %%
for pattern, g_cons in zip(dat.pattern, dat.g_cons):
    if isinstance(pattern, str) and 'MM' in pattern:
        print(pattern, g_cons)
# Out:
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HBJ>
# CMM HW>
# CMM LW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM MBJ>
# CMM TBJ>
# CCMM JYW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM BW>
# CMM BW>
# CMM HW>
# CMM HJ>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# MCMM HWYJ>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM BW>
# CMM TBW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HBJ>
# CMM HJ>
# CMM HW>
# CMM BW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HJ>
# CMM HW>
# CCMM NBJ>
# CMM HW>
# CMM NBW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CCMM NFJ>
# CMM HW>
# CMM HW>
# CCCMM MSPW>
# CMM BW>
# CCCMM MSPW>
# CMM TBW>
# CMM HW>
# CMM BW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HJ>
# CMM HW>
# CMM HW>
# CMM HBJ>
# CMM HW>
# CCMM >PW>
# CMM HW>
# CMM TBW>
# CCMM >PW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM HW>
# CMM TBW>
# CMM HW>
# CCMM VLW>
# CCMM VLW>
# CMM TBW>
# CCMM VLW>
# CMM HW>
# ...

# %%
double_matres = sum([1 if 'MM' in pattern else 0 for pattern in dat.pattern if isinstance(pattern, str)])

# %%
total_matres - double_matres
# Out:
# 108794
