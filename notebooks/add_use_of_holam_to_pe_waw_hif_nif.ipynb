# %%
import pandas as pd

from tf.app import use
A = use('etcbc/bhsa', hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv1.8.1=#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local release">data:</b> <span title="rv1.8.1=#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#gaba4367b49750089e4e4122415a77cac43bd97bc offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#gf45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/parallels/tf/2021</span>
# ...

# %%
dat = pd.read_csv('../data/niph_hiph_pe_yod.csv', sep='\t')

# %%
dat.head()
# Out:
#    tf_id scroll     book  chapter  verse   lex g_cons  stem pattern  \
# 0    205     MT  Genesis        1     12  JY>[   TWY>   WY>     MCM
# 1    449     MT  Genesis        1     24  JY>[   TWY>   WY>     MCM
# 2   1687     MT  Genesis        4      2  JSP[    TSP    SP      CC
# 3   1769     MT  Genesis        4      7  JVB[  TJVJB  JVJB    MCMC
# 4   1774     MT  Genesis        4      7  JVB[  TJVJB  JVJB    MCMC
#
#   pattern_g_cons  ... column has_prs has_prefix has_hloc has_nme  \
# 0           CMCM  ...      -       0          1        0       0
# 1           CMCM  ...      -       0          0        0       0
# 2            CCC  ...      -       0          1        0       0
# 3          CMCMC  ...      -       0          0        0       0
# 4          CMCMC  ...      -       0          0        0       0
#
#   rec_signs_stem cor_signs_stem   type  vowel_letter has_vowel_letter
# 0            nnn            nnn  first             W                1
# ...

# %%
[(w, T.sectionFromNode(w), F.g_word.v(w)) if scr == 'MT' else '-' for w, scr in zip(dat.tf_id, dat.scroll)]
# Out:
# [(205, ('Genesis', 1, 12), 'T.OWY;63>'),
#  (449, ('Genesis', 1, 24), 'T.OWY;63>'),
#  (1687, ('Genesis', 4, 2), 'T.O74SEP'),
#  (1769, ('Genesis', 4, 7), 'T.;JVIJB03'),
#  (1774, ('Genesis', 4, 7), 'T;JVI80JB'),
#  (1860, ('Genesis', 4, 12), 'TOS;71P'),
#  (2157, ('Genesis', 5, 3), 'J.O71WLED'),
#  (2172, ('Genesis', 5, 4), 'HOWLIJDO74W'),
#  (2179, ('Genesis', 5, 4), 'J.O71WLED'),
#  (2207, ('Genesis', 5, 6), 'J.O73WLED'),
#  (2214, ('Genesis', 5, 7), 'HOWLIJDO74W'),
#  (2224, ('Genesis', 5, 7), 'J.O71WLED'),
#  (2248, ('Genesis', 5, 9), 'J.O73WLED'),
#  (2255, ('Genesis', 5, 10), 'HOWLIJDO74W'),
#  (2266, ('Genesis', 5, 10), 'J.O71WLED'),
#  (2289, ('Genesis', 5, 12), 'J.O73WLED'),
#  (2296, ('Genesis', 5, 13), 'HOWLIJDO74W'),
#  (2306, ('Genesis', 5, 13), 'J.O71WLED'),
#  (2332, ('Genesis', 5, 15), 'J.O73WLED'),
#  (2339, ('Genesis', 5, 16), 'HOWLIJDO74W'),
#  (2349, ('Genesis', 5, 16), 'J.O71WLED'),
#  (2379, ('Genesis', 5, 18), 'J.O73WLED'),
# ...

# %%
has_hireq = [(1 if 'I' in F.g_lex.v(w) else 0) if scr == 'MT' else '-' for w, scr in zip(dat.tf_id, dat.scroll)]

# %%
dat['has_hireq'] = has_hireq
dat.head()
# Out:
#    tf_id scroll     book  chapter  verse   lex g_cons  stem pattern
# 0     90     MT  Genesis        1      6  BDL[  MBDJL  BDJL    CCMC  \
# 1    182     MT  Genesis        1     11  DC>[   TDC>   DC>     CCM
# 2    187     MT  Genesis        1     11  ZR<[  MZRJ<  ZRJ<    CCMC
# 3    210     MT  Genesis        1     12  ZR<[  MZRJ<  ZRJ<    CCMC
# 4    246     MT  Genesis        1     14  BDL[  HBDJL  BDJL    CCMC
#
#   pattern_g_cons  ... has_prs has_prefix has_hloc has_nme rec_signs_stem
# 0          CCCMC  ...       0          0        0       0           nnnn  \
# 1           CCCM  ...       0          0        0       0            nnn
# 2          CCCMC  ...       0          0        0       0           nnnn
# 3          CCCMC  ...       0          0        0       0           nnnn
# 4          CCCMC  ...       0          1        0       0           nnnn
#
#   cor_signs_stem  type vowel_letter  has_vowel_letter has_hireq
# ...

# %%
dat.to_csv('../data/hiphil_triliteral_with_hireq.csv', sep='\t')

# %%
mt_hireq_ipf = dat[(dat.scroll == 'MT') & (dat.vt == 'impf') & (dat.has_hireq == 1)]
pd.crosstab(mt_hireq_ipf.has_prefix, mt_hireq_ipf.has_vowel_letter)
# Out:
#        tf_id scroll          book  chapter  verse    lex   g_cons   stem
# 10      1534     MT       Genesis        3     18   YMX[    TYMJX   YMJX  \
# 16      6038     MT       Genesis       13      9  FM>L[  >FM>JLH  FM>JL
# 18      8306     MT       Genesis       18     28   CXT[    TCXJT   CXJT
# 19      8316     MT       Genesis       18     28   CXT[    >CXJT   CXJT
# 20      8380     MT       Genesis       18     31   CXT[    >CXJT   CXJT
# ...      ...    ...           ...      ...    ...    ...      ...    ...
# 2467  423433     MT  2_Chronicles       32     15  NC>=[     JCJ>    CJ>
# 2468  423444     MT  2_Chronicles       32     15   >MN[   T>MJNW   >MJN
# 2470  423468     MT  2_Chronicles       32     15   NYL[    JYJLW    YJL
# 2472  423512     MT  2_Chronicles       32     17   NYL[     JYJL    YJL
# 2484  425937     MT  2_Chronicles       35     21   CXT[   JCXJTK   CXJT
#
#      pattern pattern_g_cons  ... has_prs has_prefix has_hloc has_nme
# ...

# %%
mt_no_hireq_ipf = dat[(dat.scroll == 'MT') & (dat.vt == 'impf') & (dat.has_hireq == 0)]
pd.crosstab(mt_no_hireq_ipf.has_prefix, mt_no_hireq_ipf.has_vowel_letter)
# Out:
# has_vowel_letter   0  1
# has_prefix
# 0                 62  5
# 1                 22  1
