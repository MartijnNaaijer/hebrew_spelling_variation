# %%
from tf.app import use
A = use('dt-ucph/sp', version = '3.4', hoist=globals())

Fold = F
Told = T
Lold = L
# Out:
# C:\Users\geitb\anaconda3\envs\hebrew_spelling\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#g9d7721efbc6368aa99ec569f07235bd2be47eb1b offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/dt-ucph/sp/tf/3.4 not found
# Could not get rate limit details
# unexpected error from builtins: 'RateLimitOverview' object has no attribute 'core'
# 	connecting to online GitHub repo dt-ucph/sp ... connected
# 	tf/3.4/__checkout__.txt...downloaded
# 	tf/3.4/book.tf...downloaded
# 	tf/3.4/chapter.tf...downloaded
# 	tf/3.4/g_cons.tf...downloaded
# 	tf/3.4/g_cons_raw.tf...downloaded
# 	tf/3.4/g_cons_utf8.tf...downloaded
# 	tf/3.4/g_lex.tf...downloaded
# ...

# %%
A = use('dt-ucph/sp', version = '6.0.3', hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#g9d7721efbc6368aa99ec569f07235bd2be47eb1b offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/app</span>
# <b title="local commit">data:</b> <span title="#f7ef1984d1d9e96bb2f23ca603d96e2f48132a1d offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/tf/6.0.3</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.1.0</a>, <a target="_blank" href="https://github.com/dt-ucph/sp/blob/master/app" title="dt-ucph/sp app">dt-ucph/sp/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
import json

with open('../../data/pattern_data_sp_3.4.json') as f:
    data = json.load(f)

# %%
data
# Out:
# {'405426': 'C',
#  '405427': 'CMCMC',
#  '405428': 'CCM',
#  '405429': 'CCCMC',
#  '405430': 'CC',
#  '405431': 'C',
#  '405432': 'CCCC',
#  '405433': 'C',
#  '405434': 'CC',
#  '405435': 'C',
#  '405436': 'CCC',
#  '405437': 'C',
#  '405438': 'C',
#  '405439': 'CCC',
#  '405440': 'CCCM',
#  '405441': 'CCM',
#  '405442': 'C',
#  '405443': 'CCM',
#  '405444': 'C',
#  '405445': 'CCC',
#  '405446': 'CC',
#  '405447': 'CCM',
#  '405448': 'CCMC',
#  '405449': 'C',
#  '405450': 'CMC',
#  '405451': 'CCCMC',
#  '405452': 'CCCCC',
#  '405453': 'CC',
#  '405454': 'CCM',
#  '405455': 'C',
#  '405456': 'CCC',
#  '405457': 'C',
#  '405458': 'CMCC',
#  '405459': 'CCCMC',
#  '405460': 'CCM',
#  '405461': 'CMC',
#  '405462': 'C',
#  '405463': 'CCM',
#  '405464': 'CMC',
#  '405465': 'C',
#  '405466': 'CCM',
#  '405467': 'CCCMC',
#  '405468': 'CC',
#  '405469': 'C',
#  '405470': 'CMC',
#  '405471': 'CM',
#  '405472': 'CMC',
#  '405473': 'C',
#  '405474': 'CCCC',
#  '405475': 'CCCMC',
# ...

# %%
pattern_string = ''.join(data.values())

new_patterns = {}

for w in F.otype.s('word'):
    g_cons = F.g_cons.v(w).replace('_', '')
    word_pattern = pattern_string[:len(g_cons)]
    pattern_string = pattern_string[len(g_cons):]
    #print(g_cons, word_pattern)
    new_patterns[str(w)] = word_pattern

# %%
new_patterns
# Out:
# {'405426': 'C',
#  '405427': 'CMCMC',
#  '405428': 'CCM',
#  '405429': 'CCCMC',
#  '405430': 'CC',
#  '405431': 'C',
#  '405432': 'CCCC',
#  '405433': 'C',
#  '405434': 'CC',
#  '405435': 'C',
#  '405436': 'CCC',
#  '405437': 'C',
#  '405438': 'C',
#  '405439': 'CCC',
#  '405440': 'CCCM',
#  '405441': 'CCM',
#  '405442': 'C',
#  '405443': 'CCM',
#  '405444': 'C',
#  '405445': 'CCC',
#  '405446': 'CC',
#  '405447': 'CCM',
#  '405448': 'CCMC',
#  '405449': 'C',
#  '405450': 'CMC',
#  '405451': 'CCCMC',
#  '405452': 'CCCCC',
#  '405453': 'CC',
#  '405454': 'CCM',
#  '405455': 'C',
#  '405456': 'CCC',
#  '405457': 'C',
#  '405458': 'CMCC',
#  '405459': 'CCCMC',
#  '405460': 'CCM',
#  '405461': 'CMC',
#  '405462': 'C',
#  '405463': 'CCM',
#  '405464': 'CMC',
#  '405465': 'C',
#  '405466': 'CCM',
#  '405467': 'CCCMC',
#  '405468': 'CC',
#  '405469': 'C',
#  '405470': 'CMC',
#  '405471': 'CM',
#  '405472': 'CMC',
#  '405473': 'C',
#  '405474': 'CCCC',
#  '405475': 'CCCMC',
# ...

# %%
with open('../../data/pattern_data_sp_6.0.3.json', 'w', encoding='utf-8') as f:
    json.dump(new_patterns, f, ensure_ascii=False, indent=4)
