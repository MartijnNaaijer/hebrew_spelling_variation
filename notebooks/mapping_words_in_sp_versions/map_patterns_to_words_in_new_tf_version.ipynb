# %%
from tf.app import use
A = use('dt-ucph/sp', version = '3.3.1', hoist=globals())

Fold = F
Told = T
Lold = L
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv3.3.1=#gd34b301c5874a64cf0e65fae72269152c0297ec5 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/dt-ucph/sp/tf/3.3.1 not found
# Status: latest release online <b>v3.4</b> versus <b>None</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">data:</b> <span title="unknown release or commit">~/text-fabric-data/github/dt-ucph/sp/tf/3.3.1</span>
# ...

# %%
A = use('dt-ucph/sp', version = '3.4', hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv3.3.1=#gd34b301c5874a64cf0e65fae72269152c0297ec5 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/app</span>
# <b title="local release">data:</b> <span title="rv3.3.1=#gd34b301c5874a64cf0e65fae72269152c0297ec5 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/tf/3.4</span>
#    |     0.25s T otype                from ~/text-fabric-data/github/dt-ucph/sp/tf/3.4
#    |     2.27s T oslots               from ~/text-fabric-data/github/dt-ucph/sp/tf/3.4
#    |     0.00s T book                 from ~/text-fabric-data/github/dt-ucph/sp/tf/3.4
#    |     1.59s T sign                 from ~/text-fabric-data/github/dt-ucph/sp/tf/3.4
#    |     0.03s T verse                from ~/text-fabric-data/github/dt-ucph/sp/tf/3.4
#    |     0.00s T chapter              from ~/text-fabric-data/github/dt-ucph/sp/tf/3.4
# ...

# %%
import json

with open('../../data/pattern_data_sp.json') as f:
    data = json.load(f)

# %%
data
# Out:
# {'405425': 'C',
#  '405426': 'CMCMC',
#  '405427': 'CCM',
#  '405428': 'CCCMC',
#  '405429': 'CC',
#  '405430': 'C',
#  '405431': 'CCCC',
#  '405432': 'C',
#  '405433': 'CC',
#  '405434': 'C',
#  '405435': 'CCC',
#  '405436': 'C',
#  '405437': 'C',
#  '405438': 'CCC',
#  '405439': 'CCCM',
#  '405440': 'CCM',
#  '405441': 'C',
#  '405442': 'CCM',
#  '405443': 'C',
#  '405444': 'CCC',
#  '405445': 'CC',
#  '405446': 'CCM',
#  '405447': 'CCMC',
#  '405448': 'C',
#  '405449': 'CMC',
#  '405450': 'CCCMC',
#  '405451': 'CCCCC',
#  '405452': 'CC',
#  '405453': 'CCM',
#  '405454': 'C',
#  '405455': 'CCC',
#  '405456': 'C',
#  '405457': 'CMCC',
#  '405458': 'CCCMC',
#  '405459': 'CCM',
#  '405460': 'CMC',
#  '405461': 'C',
#  '405462': 'CCM',
#  '405463': 'CMC',
#  '405464': 'C',
#  '405465': 'CCM',
#  '405466': 'CCCMC',
#  '405467': 'CC',
#  '405468': 'C',
#  '405469': 'CMC',
#  '405470': 'CM',
#  '405471': 'CMC',
#  '405472': 'C',
#  '405473': 'CCCC',
#  '405474': 'CCCMC',
# ...

# %%
pattern_string = ''.join(data.values())

new_patterns = {}

for w in F.otype.s('word'):
    g_cons = F.g_cons.v(w).replace('_', '')
    word_pattern = pattern_string[:len(g_cons)]
    pattern_string = pattern_string[len(g_cons):]
    #print(g_cons, word_pattern)
    new_patterns[str(w)] = word_pattern

# %%
new_patterns
# Out:
# {'405426': 'C',
#  '405427': 'CMCMC',
#  '405428': 'CCM',
#  '405429': 'CCCMC',
#  '405430': 'CC',
#  '405431': 'C',
#  '405432': 'CCCC',
#  '405433': 'C',
#  '405434': 'CC',
#  '405435': 'C',
#  '405436': 'CCC',
#  '405437': 'C',
#  '405438': 'C',
#  '405439': 'CCC',
#  '405440': 'CCCM',
#  '405441': 'CCM',
#  '405442': 'C',
#  '405443': 'CCM',
#  '405444': 'C',
#  '405445': 'CCC',
#  '405446': 'CC',
#  '405447': 'CCM',
#  '405448': 'CCMC',
#  '405449': 'C',
#  '405450': 'CMC',
#  '405451': 'CCCMC',
#  '405452': 'CCCCC',
#  '405453': 'CC',
#  '405454': 'CCM',
#  '405455': 'C',
#  '405456': 'CCC',
#  '405457': 'C',
#  '405458': 'CMCC',
#  '405459': 'CCCMC',
#  '405460': 'CCM',
#  '405461': 'CMC',
#  '405462': 'C',
#  '405463': 'CCM',
#  '405464': 'CMC',
#  '405465': 'C',
#  '405466': 'CCM',
#  '405467': 'CCCMC',
#  '405468': 'CC',
#  '405469': 'C',
#  '405470': 'CMC',
#  '405471': 'CM',
#  '405472': 'CMC',
#  '405473': 'C',
#  '405474': 'CCCC',
#  '405475': 'CCCMC',
# ...

# %%
with open('../../data/pattern_data_sp_3.4.json', 'w', encoding='utf-8') as f:
    json.dump(new_patterns, f, ensure_ascii=False, indent=4)
