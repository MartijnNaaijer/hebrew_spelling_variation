# %%
import os
import pandas as pd

# %%
folder = 'C:/Users/geitb/Kopenhagen/KopenhagenResearch/scripts_research/hebrew_spelling_variation/data'
file = 'nouns_adjectives.csv'

# %%
os.path.join(folder, file)
# Out:
# 'C:/Users/geitb/Kopenhagen/KopenhagenResearch/scripts_research/hebrew_spelling_variation/data\\nouns_adjectives.csv'

# %%
input_df = pd.read_csv(os.path.join(folder, file), sep='\t')

# %%
input_df.head()
# Out:
#    tf_id scroll     book  chapter  verse     lex g_cons   stem pattern
# 0      2     MT  Genesis        1      1  R>CJT/  R>CJT  R>CJT   CMCMC  \
# 1      2     MT  Genesis        1      1  R>CJT/  R>CJT  R>CJT   CMCMC
# 2      4     MT  Genesis        1      1  >LHJM/  >LHJM    >LH     CCC
# 3     20     MT  Genesis        1      2    XCK/    XCK    XCK     CCC
# 4     23     MT  Genesis        1      2   THWM/   THWM   THWM    CCMC
#
#   pattern_g_cons  ...  has_prs  has_prefix has_hloc has_nme  rec_signs_stem
# 0          CMCMC  ...        0           1        0       0           nnnnn  \
# 1          CMCMC  ...        0           1        0       0           nnnnn
# 2          CCCMC  ...        0           0        0       1             nnn
# 3            CCC  ...        0           1        0       0             nnn
# 4           CCMC  ...        0           0        0       0            nnnn
#
#   cor_signs_stem   type vowel_letter has_vowel_letter neigh_vowel_letter
# ...

# %%
for lex, typ in set(zip(input_df.lex, input_df.type)):
    lex_typ_dat = input_df[(input_df.lex == lex) & (input_df.type == typ)]
    cons_counts = len({pat[1:].count('C') for pat in set(lex_typ_dat.pattern)})
    if cons_counts != 1:
        print(lex, typ, cons_counts)
# Out:
# LBJ>/ last 2

# %%
mt_sp[(mt_sp.lex == 'LBJ>/') & (mt_sp.type == 'last')] # & (mt_sp.g_cons == 'HWDK')]
# Out:
#         tf_id scroll         book  chapter  verse    lex g_cons  stem pattern
# 1708    27900     MT      Genesis       49      9  LBJ>/   LBJ>  LBJ>    CCMC  \
# 6139    85090     MT      Numbers       23     24  LBJ>/   LBJ>  LBJ>    CCMC
# 6148    85343     MT      Numbers       24      9  LBJ>/   LBJ>  LBJ>    CCMC
# 8116   112537     MT  Deuteronomy       33     20  LBJ>/   LBJ>  LBJ>    CCMC
# 13751  213936     MT       Isaiah        5     29  LBJ>/   LBJ>  LBJ>    CCMC
# 14368  221892     MT       Isaiah       30      6  LBJ>/   LBJ>  LBJ>    CCMC
# 19991  293817     MT        Hosea       13      8  LBJ>/   LBJ>  LBJ>    CCMC
# 20025  294158     MT         Joel        1      6  LBJ>/   LBJ>  LBJ>    CCMC
# 20623  301828     MT        Nahum        2     12  LBJ>/   LBJ>  LBJ>    CCMC
# 24043  337192     MT          Job        4     11  LBJ>/   LBJ>  LBJ>    CCMC
# 24690  345810     MT          Job       38     39  LBJ>/   LBJ>  LBJ>    CCMC
# ...

# %%
from tf.app import use
A = use('dt-ucph/sp', version='3.4', hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv3.3.1=#gd34b301c5874a64cf0e65fae72269152c0297ec5 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/app</span>
# <b title="local release">data:</b> <span title="rv3.3.1=#gd34b301c5874a64cf0e65fae72269152c0297ec5 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/tf/3.4</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 12.0.7</a>, <a target="_blank" href="https://github.com/dt-ucph/sp/blob/master/app" title="dt-ucph/sp app">dt-ucph/sp/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
[w for w in F.otype.s('word') if F.g_cons.v(w) == 'LBJH' and F.lex.v(w) == 'LBJ>/']
# Out:
# [433488, 492388, 492643, 519944]
