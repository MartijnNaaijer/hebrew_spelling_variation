# %%
import collections

import pandas as pd

from tf.app import use
A = use('etcbc/bhsa', hoist=globals())
# Out:
# C:\Users\geitb\anaconda3\envs\hebrew_spelling\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local commit">data:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gaba4367b49750089e4e4122415a77cac43bd97bc offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# ...

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\geitb\\Kopenhagen\\KopenhagenResearch\\scripts_research\\hebrew_spelling_variation\\notebooks'

# %%
dat = pd.read_csv('../data/nouns_adjectives.csv', sep='\t')

# %%
dat.head()
# Out:
#    tf_id scroll     book  chapter  verse     lex g_cons   stem pattern  \
# 0      2     MT  Genesis        1      1  R>CJT/  R>CJT  R>CJT   CMCMC
# 1      2     MT  Genesis        1      1  R>CJT/  R>CJT  R>CJT   CMCMC
# 2      4     MT  Genesis        1      1  >LHJM/  >LHJM    >LH     CCC
# 3     20     MT  Genesis        1      2    XCK/    XCK    XCK     CCC
# 4     23     MT  Genesis        1      2   THWM/   THWM   THWM    CCMC
#
#   pattern_g_cons  ...  has_prs  has_prefix has_hloc has_nme  rec_signs_stem  \
# 0          CMCMC  ...        0           1        0       0           nnnnn
# 1          CMCMC  ...        0           1        0       0           nnnnn
# 2          CCCMC  ...        0           0        0       1             nnn
# 3            CCC  ...        0           1        0       0             nnn
# 4           CCMC  ...        0           0        0       0            nnnn
#
#   cor_signs_stem   type vowel_letter has_vowel_letter neigh_vowel_letter
# ...

# %%
dat['lex_type'] = dat['lex'] + '_' + dat['type']
lex_types = set(dat.lex_type)

# %%
lex_types_dict = {}

for lt in lex_types:
    
    lt_df = dat[dat.lex_type == lt]
    letter_count = collections.Counter(lt_df.vowel_letter)
    letter_count2 = collections.Counter({k:v for k, v in letter_count.items() if isinstance(k, str)})
    most = letter_count2.most_common(1)[0][0]
    lex_types_dict[lt] = most

# %%
w_lex_types = {lt for lt, letter in lex_types_dict.items() if (letter == 'W' and 'last' in lt)}
len(w_lex_types)
# Out:
# 364

# %%
lex_set = set()
n = 0

for _, row in dat.iterrows():
    tfid = row.tf_id
    lt = row.lex_type
    lex = row.lex
    #section = T.sectionFromNode(tfid)

    if tfid > 427000:
        continue

    if lt in w_lex_types:
        g_word = F.g_lex.v(tfid)
        try:
            if len(set(g_word).intersection({'O', 'U', 'W'})) == 0:
                print(tfid, g_word)
                lex_set.add(lex)
                n += 1
        except:
            continue

n
# Out:
# 647 JEREQ
# 4096 JEREQ
# 4760 <AR:QIJ
# 6310 HAR:R
# 6875 X:AC;K
# 10817 MIB:XAR
# 11556 MIC:Q@L
# 11564 MIC:Q@L
# 22095 >AC:K.:L
# 24459 VEBAX
# 24469 Y.@H:@R
# 24573 MIC:Q@L
# 24648 Y.@H:@R
# 32591 X:@M@R
# 32592 X:@M@R
# 34188 JEREQ
# 36976 MIB:XAR
# 40179 C:L@C
# 42043 M.IC:X
# 44674 M.IC:X
# 44968 M.IC:X
# 45927 QIN.:M@N
# 45955 MIC:X
# 45962 MIC:X
# 46045 MIC:X
# 46338 M.IC:X
# 48622 M.IC:X
# 48731 M.IC:X
# 49010 M.IC:X
# 50431 M.IC:X
# 51738 M.IC:X
# 51987 M.IC:X
# 54773 G@Z;L
# 56061 M.IC:X
# 56218 M.IC:X
# 56263 M.IC:X
# 56719 M.IC:X
# 57549 MIC:X
# 58109 T.AX:M@S
# 58343 <AK:B.@R
# 60263 YIP.:@R
# 61338 YIP.:@R
# 64356 M.IC:Q@L
# 65130 M.IC:X
# 65177 MIC:X
# 68592 M.IC:Q@L
# 72122 M.IC:X
# 74136 MIC:Q@L
# 74218 MIC:Q@L
# 74299 MIC:Q@L
# 74380 MIC:Q@L
# 74461 MIC:Q@L
# 74542 MIC:Q@L
# 74623 MIC:Q@L
# 74704 MIC:Q@L
# 74785 MIC:Q@L
# 74866 MIC:Q@L
# 74947 MIC:Q@L
# 75028 MIC:Q@L
# 77531 X:@M@R
# 77653 C:L@C:
# 77659 C:L@C:
# 83871 JEREQ
# 84812 HAR:R
# 86629 C.IL.;MIJ
# ...

# %%
lex_set
# Out:
# {'<KBR/',
#  '<MWNJ/',
#  '<QLQL/',
#  '<RQJ/',
#  '>CKWL/',
#  '>CMNJM/',
#  '>CPT/',
#  '>RMWN/',
#  'B>C/',
#  'BSR/',
#  'CLC/',
#  'CLMJ/',
#  'CRJWN/',
#  'GDWL/',
#  'GRC/',
#  'GZL/',
#  'HMS/',
#  'HR/',
#  'J<P/',
#  'JRQ/',
#  'K>B/',
#  'KRKRH/',
#  'M<YWR/',
#  'MBXR/',
#  'MCM</',
#  'MCQL/',
#  'MCSH/',
#  'MCXH/',
#  'MDWN/',
#  'MF>=/',
#  'MFRH/',
#  'MRBH/',
#  'MXCK/',
#  'MXMD/',
#  'N<MNJM/',
#  'NXCT/',
#  'P<L/',
#  'QNMWN/',
#  'SRPD/',
#  'T>R/',
#  'TQ</',
#  'TW>MM/',
#  'TXMS/',
#  'VBX/',
#  'VHR/',
#  'XCKH/',
#  'XMR=/',
#  'YHRJM/',
#  'YJDNJ/',
#  'YPWR/'}

# %%
Issues: 

>CKWL/: Sometimes contraction in plural to shewa, sometimes not.
QNMWN/: qametz in MT Exodus, vowel letter w in SP Exodus
<RQJ/ shewa in MT, w in SP
>CMNJM/ patach in MT, w is 1qisaa
>RMWN/: plural: shewa in MT, w in 1Qisaa
B>C/: in MT contraction in plural, in 1Qisaa
