# %%
from tf.app import use

A = use('etcbc/bhsa', hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local commit">data:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gaba4367b49750089e4e4122415a77cac43bd97bc offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gf45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/parallels/tf/2021</span>
# ...

# %%
{F.prs.v(w) for w in F.otype.s('word')}
# Out:
# {'H',
#  'H=',
#  'HJ',
#  'HM',
#  'HN',
#  'HW',
#  'HWN',
#  'J',
#  'K',
#  'K=',
#  'KM',
#  'KN',
#  'KWN',
#  'M',
#  'MW',
#  'N',
#  'N>',
#  'NJ',
#  'NW',
#  'W',
#  'absent',
#  'n/a'}

# %%
for w in F.otype.s('word'):
    prs = F.prs.v(w)
    if prs in { 'H='}:
        h_person = F.prs_gn.v(w)
        print(w, T.sectionFromNode(w), prs, h_person)
# Out:
# 370635 ('Daniel', 2, 5) H= m
# 370646 ('Daniel', 2, 6) H= m
# 370660 ('Daniel', 2, 6) H= m
# 370723 ('Daniel', 2, 9) H= m
# 370866 ('Daniel', 2, 16) H= m
# 370876 ('Daniel', 2, 17) H= m
# 370928 ('Daniel', 2, 20) H= m
# 370942 ('Daniel', 2, 20) H= m
# 370975 ('Daniel', 2, 22) H= m
# 371020 ('Daniel', 2, 24) H= m
# 371046 ('Daniel', 2, 25) H= m
# 371067 ('Daniel', 2, 26) H= m
# 371078 ('Daniel', 2, 26) H= m
# 371183 ('Daniel', 2, 31) H= m
# 371189 ('Daniel', 2, 31) H= m
# 371193 ('Daniel', 2, 32) H= m
# 371204 ('Daniel', 2, 32) H= m
# 371286 ('Daniel', 2, 36) H= m
# 371521 ('Daniel', 2, 45) H= m
# 371540 ('Daniel', 2, 46) H= m
# 371576 ('Daniel', 2, 48) H= m
# 371578 ('Daniel', 2, 48) H= m
# 371618 ('Daniel', 3, 1) H= m
# 371621 ('Daniel', 3, 1) H= m
# 371624 ('Daniel', 3, 1) H= m
# 371744 ('Daniel', 3, 7) H= m
# 371779 ('Daniel', 3, 8) H= m
# 372050 ('Daniel', 3, 19) H= m
# 372058 ('Daniel', 3, 20) H= m
# 372182 ('Daniel', 3, 25) H= m
# 372269 ('Daniel', 3, 28) H= m
# ...

# %%
for w in F.otype.s('word'):
    if F.lex.v(w) == '>HL/':
        print(w, T.sectionFromNode(w), F.g_cons.v(w), F.prs.v(w))
# Out:
# 2012 ('Genesis', 4, 20) >HL absent
# 4420 ('Genesis', 9, 21) >HLH W
# 4507 ('Genesis', 9, 27) >HLJ absent
# 5645 ('Genesis', 12, 8) >HLH W
# 5912 ('Genesis', 13, 3) >HLH W
# 5952 ('Genesis', 13, 5) >HLJM absent
# 7813 ('Genesis', 18, 1) >HL absent
# 7838 ('Genesis', 18, 2) >HL absent
# 7895 ('Genesis', 18, 6) >HLH absent
# 7967 ('Genesis', 18, 9) >HL absent
# 7988 ('Genesis', 18, 10) >HL absent
# 12407 ('Genesis', 24, 67) >HLH absent
# 12865 ('Genesis', 25, 27) >HLJM absent
# 13458 ('Genesis', 26, 25) >HLW W
# 16828 ('Genesis', 31, 25) >HLW W
# 16979 ('Genesis', 31, 33) >HL absent
# 16983 ('Genesis', 31, 33) >HL absent
# 16987 ('Genesis', 31, 33) >HL absent
# 16997 ('Genesis', 31, 33) >HL absent
# 17002 ('Genesis', 31, 33) >HL absent
# 17025 ('Genesis', 31, 34) >HL absent
# 18432 ('Genesis', 33, 19) >HLW W
# 19429 ('Genesis', 35, 21) >HLH W
# 37737 ('Exodus', 16, 16) >HLW W
# 38604 ('Exodus', 18, 7) >HLH absent
# 42753 ('Exodus', 26, 7) >HL absent
# ...
