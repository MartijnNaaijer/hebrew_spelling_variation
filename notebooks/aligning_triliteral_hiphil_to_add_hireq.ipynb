# %%
import collections

from Bio import pairwise2
from Bio.Seq import Seq
import matplotlib.pyplot as plt
#import networkx as nx
import numpy as np
import pandas as pd

from tf.app import use
A = use('etcbc/bhsa', hoist=globals())
Fmt, Tmt, Lmt = F, T, L

B = use('dt-ucph/sp', version='3.4', hoist=globals())
Fsp, Tsp, Lsp = F, T, L

C = use('etcbc/dss', version='1.9', hoist=globals())
Fdss, Tdss, Ldss = F, T, L

del F, T, L
# Out:
# C:\Users\geitb\anaconda3\envs\hebrew_spelling\Lib\site-packages\Bio\pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(
# C:\Users\geitb\anaconda3\envs\hebrew_spelling\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local commit">data:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gaba4367b49750089e4e4122415a77cac43bd97bc offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gf45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/parallels/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/ner</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.6</a>, <a target="_blank" href="https://github.com/etcbc/bhsa/blob/master/app" title="etcbc/bhsa app">etcbc/bhsa/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://etcbc.github.io/bhsa/" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">etcbc - bhsa 2021</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="etcbc - bhsa feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>39</td>
#     <td>10938.21</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>929</td>
#     <td>459.19</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>lex</th>
#     <td>9230</td>
#     <td>46.22</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>23213</td>
#     <td>18.38</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>half_verse</th>
#     <td>45179</td>
#     <td>9.44</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>63717</td>
#     <td>6.70</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence_atom</th>
#     <td>64514</td>
#     <td>6.61</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>88131</td>
#     <td>4.84</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause_atom</th>
#     <td>90704</td>
#     <td>4.70</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>253203</td>
#     <td>1.68</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase_atom</th>
#     <td>267532</td>
#     <td>1.59</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>113850</td>
#     <td>1.42</td>
#     <td>38</td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>426590</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>Parallel Passages</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://nbviewer.jupyter.org/github/etcbc/parallels/blob/master/programs/parallels.ipynb" title="~/text-fabric-data/github/etcbc/parallels/tf/2021/crossref.tf">crossref</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 🆗 links between similar passages</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in Latin (Genesis; Numeri; Reges1; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book@ll" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book@am.tf">book@ll</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in amharic (ኣማርኛ)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ chapter number (1; 2; 3; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/code" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/code.tf">code</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ identifier of a clause atom relationship (0; 74; 367; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/det" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/det.tf">det</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ determinedness of phrase(atom) (det; und; NA.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/domain" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ text type of clause (? (Unknown); N (narrative); D (discursive); Q (Quotation).)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/freq_lex" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/freq_lex.tf">freq_lex</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ frequency of lexemes</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/function" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/function.tf">function</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ syntactic function of phrase (Cmpl; Objc; Pred; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word consonantal-transliterated (B R>CJT BR> >LHJM ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_cons_utf8.tf">g_cons_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word consonantal-Hebrew (ב ראשׁית ברא אלהים)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_lex.tf">g_lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme pointed-transliterated (B.:- R;>CIJT B.@R@> >:ELOH ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_lex_utf8.tf">g_lex_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme pointed-Hebrew (בְּ רֵאשִׁית בָּרָא אֱלֹה)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_word.tf">g_word</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word pointed-transliterated (B.:- R;>CI73JT B.@R@74> >:ELOHI92JM)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_word_utf8.tf">g_word_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word pointed-Hebrew (בְּ רֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/gloss" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> 🆗 english translation of lexeme (beginning create god(s))</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/gn" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/gn.tf">gn</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ grammatical gender (m; f; NA; unknown.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.gith
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#g9d7721efbc6368aa99ec569f07235bd2be47eb1b offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/dt-ucph/sp/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/dt-ucph/sp/tf/3.4 not found
# Backend provider github not supported.
# Cannot reach online data on github
# Try installing text-fabric one of the following:
# pip install text-fabric[github]
# pip install text-fabric[all]
# The requested data is not available offline
# There were problems with loading data.
# The TF API has not been loaded!
# The app "dt-ucph/sp" will not work!
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/app</span>
# <b title="local commit">data:</b> <span title="#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/tf/1.9</span>
# <b title="local commit">data:</b> <span title="#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under C:/Users/geitb/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/parallels/tf/1.9</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.6</a>, <a target="_blank" href="https://github.com/etcbc/dss/blob/master/app" title="etcbc/dss app">etcbc/dss/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/about.md" title="provenance of Dead Sea Scrolls">etcbc - dss 1.9</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="etcbc - dss feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>scroll</th>
#     <td>1001</td>
#     <td>1428.81</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>lex</th>
#     <td>10450</td>
#     <td>129.14</td>
#     <td>94</td>
# </tr>
#
# <tr>
#     <th>fragment</th>
#     <td>11182</td>
#     <td>127.91</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>line</th>
#     <td>52895</td>
#     <td>27.04</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>125</td>
#     <td>12.85</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>cluster</th>
#     <td>101099</td>
#     <td>6.68</td>
#     <td>47</td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>315</td>
#     <td>5.10</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>500995</td>
#     <td>2.81</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th><i>sign</i></th>
#     <td>1430241</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b><github>etcbc/dss/parallels/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://github.com/etcbc/dss/tree/master/parallels/tf" title="~/text-fabric-data/github/etcbc/dss/parallels/tf/1.9/sim.tf">sim</a>
# </div>
# <div class="fmono">int</div>
#
# <span> similarity between lines, as a percentage of the common material wrt the combined material</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>Dead Sea Scrolls</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> space behind the word, if any</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/alt.tf">alt</a>
# </div>
# <div class="fmono">int</div>
#
# <span> alternative reading</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/biblical.tf">biblical</a>
# </div>
# <div class="fmono">int</div>
#
# <span> whether we are in biblical material or not</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> acronym of the book in which the word occurs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/book_etcbc.tf">book_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/chapter.tf">chapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> label of the chapter in which the word occurs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/cl.tf">cl</a>
# </div>
# <div class="fmono">str</div>
#
# <span> class (morphology tag)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/cl2.tf">cl2</a>
# </div>
# <div class="fmono">str</div>
#
# <span> class (for part 2) (morphology tag)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/cor.tf">cor</a>
# </div>
# <div class="fmono">int</div>
#
# <span> correction made by an ancient or modern editor</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/fragment.tf">fragment</a>
# </div>
# <div class="fmono">str</div>
#
# <span> label of a fragment of a scroll</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/full.tf">full</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (Unicode) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/fulle.tf">fulle</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (ETCBC transliteration) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/fullo.tf">fullo</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (original source) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/g_nme_etcbc.tf">g_nme_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/g_prs_etcbc.tf">g_prs_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/glex.tf">glex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> representation (Unicode) of a lexeme leaving out non-letters</span>
#
# </div>
#
# <div class="frow">
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %%
file = '../data/hiphil_triliteral.csv'

dat = pd.read_csv(file, sep='\t')
has_hireq = [(1 if 'I' in Fmt.g_lex.v(w) else 0) if scr == 'MT' else '-' for w, scr in zip(dat.tf_id, dat.scroll)]

# %%
PENTATEUCH_BOOKS = ['Genesis', 'Exodus', 'Leviticus', 'Numbers', 'Deuteronomy']
ALL_BOOK_NAMES = [Tmt.sectionFromNode(bo)[0] for bo in Fmt.otype.s('book')]

# %%
class Book:
    def __init__(self, manuscript, book_name, F, T, L):
        self.manuscript = manuscript
        self.book_name = book_name
        self.F = F
        self.T = T
        self.L = L
        if self.manuscript in {'MT', 'SP'}:
            self.verse_g_cons, self.word2char = self.prepare_book_data()
        else:
            self.verse_g_cons, self.word2char = self.prepare_dss_book_data()
        self.verse_text_dict = self.make_verse_text()
        
    def prepare_book_data(self):
        verse_g_cons = collections.defaultdict(list)
        word2char = collections.defaultdict(list)
    
        for book_node in eval(self.F + ".otype.s('book')"):
            book_name = eval(self.T + '.sectionFromNode(book_node)[0]')
            if book_name != self.book_name:
                continue
            words = eval(self.L + ".d(book_node, 'word')")
            for w in words:
                bo, ch, ve = eval(self.T + '.sectionFromNode(w)')
                g_cons = eval(self.F + '.g_cons.v(w)')
                trailer = eval(self.F + '.trailer.v(w)')
                if trailer:
                    trailer = ' '
                verse_g_cons[(bo, ch, ve)].append(g_cons + trailer)
                for char in g_cons:
                    word2char[(bo, ch, ve)].append(w)
        return verse_g_cons, word2char
    
    def prepare_dss_book_data(self):
        verse_g_cons = collections.defaultdict(list)
        word2char = collections.defaultdict(list)
        
        for scr in eval(self.F + ".otype.s('scroll')"):
            if eval(self.T + '.scrollName(scr)') == self.manuscript:
                words = eval(self.L + ".d(scr, 'word')")
                for w in words:
                    bo = eval(self.F + '.book_etcbc.v(w)')
                    if bo != self.book_name:
                        continue            
                    ch = eval(self.F + '.chapter.v(w)')
                    ve = eval(self.F + '.verse.v(w)')
                
                    g_cons = eval(self.F + '.g_cons.v(w)')
                    after = eval(self.F + '.after.v(w)')

                    if after is None:
                        after = ''
                    if g_cons:
                        verse_g_cons[(bo, int(ch), int(ve))].append(g_cons + after)
                        for char in g_cons:
                            word2char[(bo, int(ch), int(ve))].append(w)
        return verse_g_cons, word2char
    
    def make_verse_text(self):
        return {section : ''.join(g_conss).strip() for (section, g_conss) in self.verse_g_cons.items()}

# %%
class AllBooks:
    def __init__(self):
        self.data = {}

# %%
def align_verses(str_1, str_2):
        
    seq1 = Seq(str_1)
    seq2 = Seq(str_2)
    
    alignments = pairwise2.align.globalxx(seq1, seq2)
    
    seq1_al = (alignments[0][0]).strip(' ')
    seq2_al = (alignments[0][1]).strip(' ')
        
    return seq1_al, seq2_al

# %%
def make_alignments(verse_text1, verse_text2):
    alignments_dict = {}

    for section, text1 in verse_text1.items():
        try:
            text2 = verse_text2[section]
            alignment1, alignment2 = align_verses(text1, text2)
            alignments_dict[section] = (alignment1, alignment2)
        except:
            continue
    return alignments_dict

# %%
def collect_matching_words(alignments_dict, word2char1, word2char2):
    man1_man2_dict = collections.defaultdict(list)

    for section, (al1, al2) in alignments_dict.items():
        man1_idx = 0
        man2_idx = 0
    
        word_chars1 = word2char1[section]
        word_chars2 = word2char2[section]
        for char1, char2 in zip(al1, al2):
            if char1 not in {' ', '-'}:
                man1_word = word_chars1[man1_idx]
                man1_idx += 1
            
            if char2 not in {' ', '-'}:
                man2_word = word_chars2[man2_idx]
                man2_idx += 1
            
            if char1 not in {' ', '-'} and char2 not in {' ', '-'}:
                man1_man2_dict[man1_word].append(man2_word)
                
    return man1_man2_dict

# %%
def most_frequent(List):
    return max(set(List), key = List.count)

# %% [markdown]
# # Prepare MT and SP texts

# %% [markdown]
# Produce dictionary mt_sp_matches which has mt words nodes as keys and matching word numbers from SP as values.

# %%
# prepare mt and sp books
MANUSCRIPTS = ['MT', 'SP']
all_books = AllBooks()
for book_name in ALL_BOOK_NAMES:
    book = Book('MT', book_name, 'Fmt', 'Tmt', 'Lmt')
    all_books.data[('MT', book_name)] = book
    
    if book_name in PENTATEUCH_BOOKS:
        book = Book('SP', book_name, 'Fsp', 'Tsp', 'Lsp')
        all_books.data[('SP', book_name)] = book

# %% [markdown]
# # Match words

# %%
#dat = pd.read_csv('../data/hiphil_triliteral.csv', sep='\t')
dat_dss = dat[~dat.scroll.isin(['MT', 'SP'])]
scroll_book_combinations = list(set(zip(dat_dss.scroll, dat_dss.book)))
dat_dss.shape
# Out:
# (756, 36)

# %%
dat.head()
# Out:
#    tf_id scroll     book  chapter  verse   lex g_cons  stem pattern  \
# 0     49     MT  Genesis        1      4  BDL[   JBDL   BDL     CCC
# 1     90     MT  Genesis        1      6  BDL[  MBDJL  BDJL    CCMC
# 2    102     MT  Genesis        1      7  BDL[   JBDL   BDL     CCC
# 3    182     MT  Genesis        1     11  DC>[   TDC>   DC>     CCM
# 4    187     MT  Genesis        1     11  ZR<[  MZRJ<  ZRJ<    CCMC
#
#   pattern_g_cons  ... column has_prs has_prefix has_hloc has_nme  \
# 0           CCCC  ...      -       0          1        0       0
# 1          CCCMC  ...      -       0          0        0       0
# 2           CCCC  ...      -       0          1        0       0
# 3           CCCM  ...      -       0          0        0       0
# 4          CCCMC  ...      -       0          0        0       0
#
#   rec_signs_stem cor_signs_stem  type  vowel_letter has_vowel_letter
# 0            nnn            nnn  last           NaN                0
# 1           nnnn           nnnn  last             J                1
# 2            nnn            nnn  last           NaN                0
# 3            nnn            nnn  last           NaN                0
# 4           nnnn           nnnn  last             J                1
#
# [5 rows x 36 columns]

# %%
for manuscript, book_name in scroll_book_combinations:
    book = Book(manuscript, book_name, 'Fdss', 'Tdss', 'Ldss')
    all_books.data[(manuscript, book_name)] = book

# %%
def make_matching_word_dict(book_name, all_books):

    all_match_dicts = {}

    matching_book = book_name
    matching_manuscripts = [scr for scr, bo in all_books.data.keys() if bo == matching_book]

    for man1 in matching_manuscripts:
        for man2 in matching_manuscripts:
            if man1 != man2:
            
                man1_verse_texts = all_books.data[(man1, matching_book)].verse_text_dict
                man2_verse_texts = all_books.data[(man2, matching_book)].verse_text_dict

                alignments_dict = make_alignments(man1_verse_texts, man2_verse_texts)
    
                man1_word2char = all_books.data[(man1, matching_book)].word2char
                man2_word2char = all_books.data[(man2, matching_book)].word2char
 
                matching_words_dict = collect_matching_words(alignments_dict, man1_word2char, man2_word2char)

                matches = {}
                for man1_word, man2_list in matching_words_dict.items():
                    man2_word = most_frequent(man2_list)
                    matches[man1_word] = man2_word
                all_match_dicts[((man1, matching_book), (man2, matching_book))] = matches
                
    return all_match_dicts, matching_manuscripts

# %%
def read_dataset(file):

    return pd.read_csv(file, sep='\t')

# %%
class MaterData:
    def __init__(self, man1, man2, section, lex, mater_val1, mater_val2, tf_id1, tf_id2, g_cons1, g_cons2):
        self.man1 = man1
        self.man2 = man2
        self.section = section
        self.lex = lex
        self.mater_val1 = mater_val1
        self.mater_val2 = mater_val2
        self.tf_id1 = tf_id1
        self.tf_id2 = tf_id2
        self.g_cons1 = g_cons1
        self.g_cons2 = g_cons2

# %%
def collect_matching_cases(matching_manuscripts, matching_book, dat):

    all_mater_datasets = {}

    for man in matching_manuscripts:
        mater_data = dat[(dat.book == matching_book) & (dat.scroll == man)]
        all_mater_datasets[(man, matching_book)] = mater_data
        
    return all_mater_datasets

# %%
def collect_mater_data(matching_manuscripts, all_match_dicts, all_mater_datasets, matching_book):

    manuscript_mater_match = collections.defaultdict(list)
    manuscripts = set()

    for idx, man in enumerate(matching_manuscripts):
        for idx2, man2 in enumerate(matching_manuscripts):
            if idx < idx2:
            
                matching_ids = all_match_dicts[((man, matching_book), (man2, matching_book))]
                man_data = all_mater_datasets[(man, matching_book)]
                man2_data = all_mater_datasets[(man2, matching_book)]
                for _, row in man_data.iterrows():
                
                    tf_id = row.tf_id
                    lex, typ, has_vl = row.lex, row.type, row.has_vowel_letter
                    g_cons1 = row.g_cons
                    section = (row.book, row.chapter, row.verse)
                    if man == 'SP':
                        tf_id = tf_id - 100000

                    matching_tf_id = matching_ids.get(tf_id, None)
                
                    if not matching_tf_id:
                        continue
                    
                    if man2 == 'SP':
                        matching_tf_id = matching_tf_id + 100000
                
                    man2_row = man2_data[(man2_data.tf_id == matching_tf_id) & (man2_data.lex == lex) & (man2_data.type == typ)]
                    
                    if not man2_row.shape[0]:
                        continue
                    has_vl2 = man2_row.has_vowel_letter.iloc[0]
                    g_cons2 = man2_row.g_cons.iloc[0]
                 
                    mater_data = MaterData(man, man2, section, lex, has_vl, has_vl2, tf_id, matching_tf_id, g_cons1, g_cons2)
                
                    manuscript_mater_match[man].append(mater_data)
                    manuscripts.add(man)
                    manuscripts.add(man2)
                    
    return manuscript_mater_match, manuscripts

# %%
def register_similarities_with_mt(manuscripts, mt_ids, manuscript_mater_match):

    mater_value_dict = {0: -1,
                    1: 1}

    mater_match_array = np.zeros((len(manuscripts), len(mt_ids)))

    for dat_object in manuscript_mater_match['MT']:
        print(dat_object.g_cons1, dat_object.g_cons2)
        
        other_man = dat_object.man2
        mt_tfid = dat_object.tf_id1
        other_man_tfid = dat_object.tf_id2
    
        mt_mater = dat_object.mater_val1
        other_man_mater = dat_object.mater_val2
    
        mt_idx = man2idx['MT']
        other_man_idx = man2idx[other_man]
    
        mt_mater_value = mater_value_dict[mt_mater]
        other_man_mater_value = mater_value_dict[other_man_mater]
    
        mt_tf_id = mt_tf2idx[mt_tfid]
    
        mater_match_array[mt_idx, mt_tf_id] = mt_mater_value
        mater_match_array[other_man_idx, mt_tf_id] = other_man_mater_value
        
    return mater_match_array

# %%
def get_parallels(manuscript_mater_match, hif_match_dict):
    for scroll in manuscript_mater_match.keys():
        for dat_object in manuscript_mater_match[scroll]:
            man1 = dat_object.man1
            man2 = dat_object.man2
            if man1 == 'MT' or man2 == 'MT':
            
                hif_match_dict[dat_object.tf_id2] = dat_object.tf_id1
                hif_match_dict[dat_object.tf_id1] = dat_object.tf_id2
        
    return hif_match_dict

# %%
def count_parallel_cases(mater_match_array):

    mater_arr = np.zeros((2, mater_match_array.shape[1]))

    for col_idx in range(mater_match_array.shape[1]):
        col = mater_match_array[:, col_idx]
        col_counts = collections.Counter(col)
        with_vowel_count = col_counts.get(1, 0)
        without_vowel_count = col_counts.get(-1, 0)
        mater_arr[0, col_idx] = with_vowel_count
        mater_arr[1, col_idx] = without_vowel_count
        
    return mater_arr

# %%
#file_name = '../data/hiphil_triliteral.csv'
all_bib_books = [Tmt.sectionFromNode(bo)[0] for bo in Fmt.otype.s('book')]
#dat = read_dataset(file_name)

hif_match_dict = {}

for book in all_bib_books:

    print(book)
    all_match_dicts, matching_manuscripts = make_matching_word_dict(book, all_books)
    all_mater_datasets = collect_matching_cases(matching_manuscripts, book, dat)
    manuscript_mater_match, manuscripts = collect_mater_data(matching_manuscripts, all_match_dicts, all_mater_datasets, book)
    
    hif_match_dict = get_parallels(manuscript_mater_match, hif_match_dict)
    print(len(hif_match_dict))
# Out:
# Genesis
# 27
# Exodus
# 74
# Leviticus
# 176
# Numbers
# 196
# Deuteronomy
# 270
# Joshua
# 278
# Judges
# 282
# 1_Samuel
# 304
# 2_Samuel
# 336
# 1_Kings
# 336
# 2_Kings
# 336
# Isaiah
# 969
# Jeremiah
# 987
# Ezekiel
# 987
# Hosea
# 989
# Joel
# 991
# Amos
# 1003
# Obadiah
# 1013
# Jonah
# 1039
# Micah
# 1057
# Nahum
# 1061
# Habakkuk
# 1063
# Zephaniah
# 1067
# Haggai
# 1067
# Zechariah
# 1069
# Malachi
# 1073
# Psalms
# 1236
# Job
# 1242
# Proverbs
# 1250
# Ruth
# 1254
# Song_of_songs
# 1258
# Ecclesiastes
# 1258
# Lamentations
# 1266
# Esther
# 1266
# Daniel
# 1283
# Ezra
# 1283
# Nehemiah
# 1283
# 1_Chronicles
# 1283
# 2_Chronicles
# 1283

# %%
dat = pd.read_csv('../data/hiphil_triliteral.csv', sep='\t')
has_hireq = [(1 if 'I' in Fmt.g_lex.v(w) else 0) if scr == 'MT' else '-' for w, scr in zip(dat.tf_id, dat.scroll)]

dat_mt = dat[dat.scroll == 'MT']
has_hireq_mt = [val for val in has_hireq if val != '-']
dat_mt['has_hireq'] = has_hireq_mt
# Out:
# C:\Users\geitb\AppData\Local\Temp\ipykernel_30560\972278135.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat_mt['has_hireq'] = has_hireq_mt

# %%
matching_mt_ids = [hif_match_dict.get(dss_id, '-') for dss_id in dat_dss.tf_id]

# %%
has_hireq_dss = []

for matching_mt_id in matching_mt_ids:
    if matching_mt_id != '-':
        has_hireq_dss.append(dat_mt[dat_mt.tf_id == matching_mt_id].has_hireq.iloc[0])
    else:
        has_hireq_dss.append('-')
        
dat_dss['has_hireq'] = has_hireq_dss 
dat_dss['mt_match'] = matching_mt_ids

# %% [markdown]
# # SAVE HIREQ DATA

# %%
dat_total_hireq = pd.concat([dat_mt, dat_dss])
dat_total_hireq.to_csv('../data/hiphil_triliteral_with_hireq.csv', sep='\t', index=False)

# %%
dat_dss_hir = dat_dss[dat_dss.has_hireq != '-']
dat_dss_hir
# Out:
#         tf_id  scroll         book  chapter  verse   lex  g_cons  stem
# 2491  1890850     1Q3    Leviticus       22      3  QDC[  JQDJCW  QDJC  \
# 2492  1893020     1Q5  Deuteronomy       29     20  BDL[  HBDJLW  BDJL
# 2493  1893145     1Q5  Deuteronomy       31      3  CMD[   JCMJD  CMJD
# 2494  1893499     1Q5  Deuteronomy       32     26  CBT[   >CBJT  CBJT
# 2495  1894883  1Qisaa       Isaiah        1      2  >ZN[  H>ZJNJ  >ZJN
# ...       ...     ...          ...      ...    ...   ...     ...   ...
# 3136  2104434   Mas1b    Leviticus       11      7  PRS[   MPRJS  PRJS
# 3137  2106782   Mas1e       Psalms       81     15  KN<[   >KNJ<  KNJ<
# 3138  2106808   Mas1e       Psalms       81     17  FB<[  >FBJ<K  FBJ<
# 3139  2106840   Mas1e       Psalms       82      3  YDQ[  HYDJQW  YDJQ
# 3140  2106849   Mas1e       Psalms       82      4  NYL[   HYJLW   YJL
#
#      pattern pattern_g_cons  ... has_prefix has_hloc has_nme rec_signs_stem
# 2491     NaN            NaN  ...          0        0       0           nnnn  \
# 2492     NaN            NaN  ...          1        0       0           nnnn
# 2493     NaN            NaN  ...          0        0       0           nnnn
# 2494     NaN            NaN  ...          0        0       0           rnnn
# 2495     NaN            NaN  ...          1        0       0           nnnn
# ...      ...            ...  ...        ...      ...     ...            ...
# 3136     NaN            NaN  ...          0        0       0           nnnn
# 3137     NaN            NaN  ...          0        0       0           nnnn
# 3138     NaN            NaN  ...          0        0       0           nnnn
# 3139     NaN            NaN  ...          0        0       0           nnnn
# 3140     NaN            NaN  ...          0        0       0            nnn
#
#      cor_signs_stem  type vowel_letter has_vowel_letter  has_hireq mt_match
# 2491           nnnn  last            J                1          1    65403
# 2492           nnnn  last            J                1          1   109959
# 2493           nnnn  last            J                1          1   110713
# 2494           nnnn  last            J                1          1   111792
# 2495           nnnn  last            J                1          1   212094
# ...             ...   ...          ...              ...        ...      ...
# 3136           nnnn  last            J                1          1    57952
# 3137           nnnn  last            J                1          1   324738
# 3138           nnnn  last            J                1          1   324762
# 3139           nnnn  last            J                1          1   324791
# 3140            nnn  last            J                1          1   324799
#
# [602 rows x 37 columns]

# %%
pd.crosstab(dat_dss_hir.has_vowel_letter, dat_dss_hir.has_hireq)
# Out:
# has_hireq          0    1
# has_vowel_letter
# 0                 19   53
# 1                  3  527

# %%
pd.crosstab(dat_mt.has_vowel_letter, dat_mt.has_hireq)
# Out:
# has_hireq           0     1
# has_vowel_letter
# 0                 122   184
# 1                   9  2176

# %%
mt_tsere = dat_mt[dat_mt.has_hireq == 0]
mt_hireq = dat_mt[dat_mt.has_hireq == 1]

dss_tsere = dat_dss[dat_dss.has_hireq == 0]
dss_hireq = dat_dss[dat_dss.has_hireq == 1]

# %%
pd.crosstab(mt_hireq.vt, mt_hireq.has_vowel_letter)
# Out:
# has_vowel_letter   0    1
# vt
# impf              93  763
# impv               3  115
# infc              24  328
# perf              21  659
# ptca              43  311

# %%
pd.crosstab(dss_hireq.vt, dss_hireq.has_vowel_letter)
# Out:
# has_vowel_letter   0    1
# vt
# impf              31  223
# impv               2   50
# infc               8   48
# perf               5  124
# ptca               7   82

# %%
pd.crosstab(mt_tsere.vt, mt_tsere.has_vowel_letter)
# Out:
# has_vowel_letter   0  1
# vt
# impf              84  6
# impv               2  0
# infc               6  1
# perf               4  2
# ptca              26  0

# %%
pd.crosstab(dss_tsere.vt, dss_tsere.has_vowel_letter)
# Out:
# has_vowel_letter   0  1
# vt
# impf              16  2
# impv               0  1
# ptca               3  0

# %%
dss_mt_match_dict = {dss_id:mt_id for dss_id, mt_id in zip(dat_dss.tf_id, dat_dss.mt_match) if mt_id != '-'}

# %%
mt_dss_match_dict = collections.defaultdict(list)
for dss_id, mt_id in dss_mt_match_dict.items():
    mt_dss_match_dict[mt_id].append(dss_id)

# %%
mt_hireq.pattern.isnull().sum()
# Out:
# 0

# %%
# Explore parallel hireq cases

# %%
mt_nodes = list(mt_hireq.tf_id)

for mt_node in mt_nodes:
    dss_nodes = mt_dss_match_dict.get(mt_node, [])
    dss_df = dss_hireq[dss_hireq.tf_id.isin(dss_nodes)]
    if dss_df.shape[0] > 0:
        mt_row = mt_hireq[mt_hireq.tf_id == mt_node]
        mt_mater = mt_row.has_vowel_letter.iloc[0]
        mt_vt, bo, ch, ve, lex, g_cons = mt_row.vt.iloc[0], mt_row.book.iloc[0], mt_row.chapter.iloc[0], mt_row.verse.iloc[0], mt_row.lex.iloc[0], mt_row.g_cons.iloc[0]
        dss_mater_count = collections.Counter(dss_df.has_vowel_letter)
        scrolls = list(dss_df.scroll)
        #if mt_mater == 1:
        #    continue
        print(scrolls, bo, ch, ve, lex, g_cons)
        print(mt_mater, mt_vt)
        print(dss_mater_count)
        print()
# Out:
# ['4Q2'] Genesis 1 11 ZR<[ MZRJ<
# 1 ptca
# Counter({1: 1})
#
# ['4Q2', '4Q10'] Genesis 1 14 BDL[ HBDJL
# 1 infc
# Counter({1: 2})
#
# ['4Q1'] Genesis 39 23 YLX[ MYLJX
# 1 ptca
# Counter({1: 1})
#
# ['4Q3'] Genesis 41 9 ZKR[ MZKJR
# 1 ptca
# Counter({1: 1})
#
# ['4Q13'] Exodus 2 3 YPN[ HYPJNW
# 1 infc
# Counter({1: 1})
#
# ['4Q13'] Exodus 2 9 HLK[ HJLJKJ
# 1 impv
# Counter({0: 1})
#
# ['4Q14'] Exodus 8 5 KRT[ HKRJT
# 1 infc
# Counter({1: 1})
#
# ['4Q11'] Exodus 16 24 B>C[ HB>JC
# 1 perf
# Counter({1: 1})
#
# ['4Q22'] Exodus 18 9 NYL[ HYJLW
# 1 perf
# Counter({1: 1})
#
# ['4Q22'] Exodus 18 10 NYL[ HYJL
# 1 perf
# Counter({1: 1})
#
# ['4Q14'] Exodus 18 10 NYL[ HYJL
# 1 perf
# Counter({1: 1})
#
# ['4Q22'] Exodus 21 6 NGC[ HGJCW
# 1 perf
# Counter({1: 1})
#
# ['4Q22'] Exodus 21 6 NGC[ HGJCW
# 1 perf
# Counter({1: 1})
#
# ['4Q22'] Exodus 21 27 NPL[ JPJL
# 1 impf
# Counter({1: 1})
#
# ['4Q11'] Exodus 23 7 YDQ[ >YDJQ
# 1 impf
# Counter({1: 1})
#
# ['4Q11'] Exodus 23 13 ZKR[ TZKJRW
# 1 impf
# Counter({1: 1})
#
# ['4Q25'] Leviticus 1 3 QRB[ JQRJBNW
# 1 impf
# Counter({1: 1})
#
# ['4Q24'] Leviticus 1 13 QRB[ HQRJB
# 1 perf
# Counter({1: 1})
#
# ['4Q24'] Leviticus 1 17 BDL[ JBDJL
# 1 impf
# Counter({1: 1})
#
# ['4Q24'] Leviticus 2 11 QRB[ TQRJBW
# 1 impf
# Counter({1: 1})
#
# ['4Q24'] Leviticus 2 13 QRB[ TQRJB
# 1 impf
# Counter({1: 1})
#
# ['4Q24'] Leviticus 2 14 QRB[ TQRJB
# 1 impf
# Counter({1: 1})
#
# ['4Q26a'] Leviticus 3 3 QRB[ HQRJB
# 1 perf
# Counter({1: 1})
#
# ['4Q26a'] Leviticus 3 7 QRB[ HQRJB
# 1 perf
# Counter({1: 1})
#
# ['4Q24'] Leviticus 3 9 QRB[ HQRJB
# 1 perf
# Counter({1: 1})
#
# ['4Q25'] Leviticus 3 16 QVR[ HQVJRM
# 1 perf
# Counter({1: 1})
#
# ['Mas1a'] Leviticus 4 3 QRB[ HQRJB
# 1 perf
# Counter({1: 1})
#
# ['Mas1b'] Leviticus 9 10 QVR[ HQVJR
# 1 perf
# Counter({1: 1})
#
# ['Mas1b'] Leviticus 10 19 QRB[ HQRJBW
# 1 perf
# Counter({1: 1})
#
# ['Mas1b'] Leviticus 11 4 PRS[ MPRJSJ
# 1 ptca
# Counter({1: 1})
#
# ['Mas1b'] Leviticus 11 7 PRS[ MPRJS
# 1 ptca
# Counter({1: 1})
#
# ['4Q23'] Leviticus 14 22 NFG[ TFJG
# 1 impf
# Counter({1: 1})
#
# ['4Q23'] Leviticus 14 32 NFG[ TFJG
# 1 impf
# Counter({1: 1})
#
# ['4Q26', '11Q1'] Leviticus 17 4 QRB[ HQRJB
# 1 infc
# Counter({1: 2})
#
# ['11Q1'] Leviticus 20 4 <LM[ J<LJMW
# 1 impf
# Counter({0: 1})
#
# ['11Q1'] Leviticus 21 6 QRB[ MQRJBM
# 1 ptca
# Counter({1: 1})
#
# ['11Q1'] Leviticus 21 8 QRB[ MQRJB
# 1 ptca
# Counter({1: 1})
#
# ['1Q3', '4Q24'] Leviticus 22 3 QDC[ JQDJCW
# 1 impf
# Counter({1: 2})
#
# ['4Q24'] Leviticus 22 16 NF>[ HFJ>W
# 1 perf
# Counter({1: 1})
#
# ['4Q24'] Leviticus 22 18 QRB[ JQRJB
# 1 impf
# Counter({1: 1})
#
# ['4Q24'] Leviticus 22 18 QRB[ JQRJBW
# 1 impf
# Counter({1: 1})
#
# ['4Q24'] Leviticus 22 20 QRB[ TQRJBW
# 1 impf
# Counter({1: 1})
#
# ['4Q24'] Leviticus 22 21 QRB[ JQRJB
# 1 impf
# Counter({1: 1})
#
# ['4Q24', '11Q1'] Leviticus 22 22 QRB[ TQRJBW
# 1 impf
# Counter({1: 1, 0: 1})
#
# ['11Q1'] Leviticus 22 24 QRB[ TQRJBW
# 1 impf
# Counter({1: 1})
#
# ['11Q1'] Leviticus 22 25 QRB[ TQRJBW
# 1 impf
# Counter({1: 1})
#
# ['4Q26c'] Leviticus 26 5 NFG[ HFJG
# 1 perf
# Counter({1: 1})
#
# ['4Q26c'] Leviticus 26 5 NFG[ JFJG
# 1 impf
# Counter({1: 1})
#
# ['4Q26c'] Leviticus 26 6 XRD[ MXRJD
# 1 ptca
# Counter({1: 1})
#
# ['11Q1'] Leviticus 26 22 M<V[ HM<JVH
# 1 perf
# Counter({1: 1})
#
# ['4Q23'] Leviticus 27 10 XLP[ JXLJPNW
# 1 impf
# Counter({1: 1})
#
# ['4Q23'] Leviticus 27 11 <MD[ H<MJD
# 1 perf
# Counter({1: 1})
#
# ['11Q1'] Leviticus 27 14 QDC[ JQDC
# 0 impf
# Counter({1: 1})
#
# ['4Q23', '11Q1'] Leviticus 27 14 <RK[ H<RJKW
# 1 perf
# Counter({1: 2})
#
# ['11Q1'] Leviticus 27 14 <RK[ J<RJK
# 1 impf
# Counter({1: 1})
#
# ['4Q23', '11Q1'] Leviticus 27 15 QDC[ MQDJC
# 1 ptca
# Counter({1: 2})
#
# ['4Q23', '11Q1'] Leviticus 27 16 QDC[ JQDJC
# 1 impf
# Counter({1: 2})
#
# ['11Q1'] Leviticus 27 17 QDC[ JQDJC
# 1 impf
# Counter({1: 1})
#
# ['11Q1'] Leviticus 27 18 QDC[ JQDJC
# 1 impf
# Counter({1: 1})
#
# ['11Q1'] Leviticus 27 19 QDC[ MQDJC
# 1 ptca
# Counter({1: 1})
#
# ['4Q27'] Numbers 11 32 M<V[ MM<JV
# 1 ptca
# Counter({1: 1})
#
# ['4Q27'] Numbers 16 5 QRB[ HQRJB
# 1 perf
# Counter({1: 1})
#
# ['4Q27'] Numbers 16 9 QRB[ HQRJB
# 1 infc
# Counter({1: 1})
#
# ['4Q27'] Numbers 32 5 <BR[ T<BRNW
# 0 impf
# Counter({1: 1})
#
# ['4Q27'] Numbers 35 22 CLK[ HCLJK
# 1 perf
# Counter({1: 1})
#
# ['4Q35'] Deuteronomy 1 17 NKR[ TKJRW
# 1 impf
# Counter({1: 1})
#
# ['4Q35'] Deuteronomy 1 17 QRB[ TQRBWN
# 0 impf
# Counter({1: 1})
#
# ['4Q35'] Deuteronomy 1 45 >ZN[ H>ZJN
# 1 perf
# Counter({1: 1})
#
# ['4Q35'] Deuteronomy 2 28 CBR=[ TCBRNJ
# 0 impf
# Counter({1: 1})
#
# ['4Q31'] Deuteronomy 2 30 <BR[ H<BRNW
# 0 infc
# Counter({0: 1})
#
# ['4Q31'] Deuteronomy 3 28 NXL[ JNXJL
# 1 impf
# Counter({0: 1})
#
# ['4Q33'] Deuteronomy 4 25 K<S[ HK<JSW
# 1 infc
# Counter({1: 1})
#
# ['4Q37', '4Q41', '4Q137', '8Q3', 'Xq3'] Deuteronomy 5 5 NGD[ HGJD
# 1 infc
# Counter({1: 4, 0: 1})
#
# ['4Q41', 'Xq3'] Deuteronomy 5 16 >RK[ J>RJKN
# 1 impf
# Counter({1: 2})
#
# ['4Q129', '4Q140', 'Xq2'] Deuteronomy 6 2 >RK[ J>RKN
# 0 impf
# Counter({0: 2, 1: 1})
#
# ['4Q45'] Deuteronomy 7 2 XRM[ TXRJM
# 1 impf
# Counter({1: 1})
#
# ['4Q45'] Deuteronomy 7 24 CMD[ HCMDK
# 0 infc
# Counter({1: 1})
#
# ['4Q30'] Deuteronomy 8 2 HLK[ HLJKK
# 1 perf
# Counter({1: 1})
#
# ['4Q38', '4Q138', '8Q4'] Deuteronomy 11 9 >RK[ T>RJKW
# 1 impf
# Counter({1: 2, 0: 1})
#
# ['4Q30'] Deuteronomy 17 20 >RK[ J>RJK
# 1 impf
# Counter({1: 1})
#
# ['4Q38a'] Deuteronomy 20 12 CLM[ TCLJM
# 1 impf
# Counter({1: 1})
#
# ['4Q38a'] Deuteronomy 21 16 NXL[ HNXJLW
# 1 infc
# Counter({1: 1})
#
# ['4Q28'] Deuteronomy 24 4 XV>[ TXVJ>
# 1 impf
# Counter({0: 1})
#
# ['4Q34'] Deuteronomy 25 15 >RK[ J>RJKW
# 1 impf
# Counter({1: 1})
#
# ['4Q42', '4Q45'] Deuteronomy 28 15 NFG[ HFJGWK
# 1 perf
# Counter({1: 2})
#
# ['4Q34'] Deuteronomy 28 29 YLX[ TYLJX
# 1 impf
# Counter({1: 1})
#
# ['4Q30'] Deuteronomy 28 48 CMD[ HCMJDW
# 1 infc
# Counter({1: 1})
#
# ['1Q5'] Deuteronomy 29 20 BDL[ HBDJLW
# 1 perf
# Counter({1: 1})
#
# ['1Q5'] Deuteronomy 31 3 CMD[ JCMJD
# 1 impf
# Counter({1: 1})
#
# ['4Q29'] Deuteronomy 31 29 CXT[ TCXTWN
# 0 impf
# Counter({0: 1})
#
# ['4Q29'] Deuteronomy 31 29 K<S[ HK<JSW
# 1 infc
# Counter({0: 1})
#
# ['4Q45'] Deuteronomy 32 8 PRD[ HPRJDW
# 1 infc
# Counter({1: 1})
#
# ['4Q141'] Deuteronomy 32 16 K<S[ JK<JSHW
# 1 impf
# Counter({1: 1})
#
# ['1Q5'] Deuteronomy 32 26 CBT[ >CBJTH
# 1 impf
# Counter({1: 1})
#
# ['4Q44'] Deuteronomy 32 39 NYL[ MYJL
# 1 ptca
# Counter({1: 1})
#
# ['4Q47'] Joshua 7 12 CMD[ TCMJDW
# 1 impf
# Counter({1: 1})
#
# ['4Q47'] Joshua 10 4 CLM[ HCLJMH
# 1 perf
# Counter({1: 1})
#
# ['4Q47'] Joshua 10 11 CLK[ HCLJK
# 1 perf
# Counter({1: 1})
#
# ['4Q51'] 1_Samuel 2 16 QVR[ JQVJRWN
# 1 impf
# Counter({0: 1})
#
# ['4Q51'] 1_Samuel 2 24 <BR[ M<BRJM
# 0 ptca
# Counter({0: 1})
#
# ['4Q52'] 1_Samuel 23 9 XRC=[ MXRJC
# 1 ptca
# Counter({1: 1})
#
# ['4Q51'] 1_Samuel 27 11 NGD[ JGDW
# 0 impf
# Counter({1: 1})
#
# ['4Q51'] 2_Samuel 4 10 NGD[ MGJD
# 1 ptca
# Counter({1: 1})
#
# ['4Q51'] 2_Samuel 12 18 NGD[ HGJD
# 1 infc
# Counter({1: 1})
#
# ['4Q53'] 2_Samuel 14 11 CMD[ JCMJDW
# 1 impf
# Counter({1: 1})
#
# ['4Q51'] 2_Samuel 14 19 FM>L[ HFMJL
# 1 infc
# Counter({0: 1})
#
# ['4Q53'] 2_Samuel 15 2 CKM[ HCKJM
# 1 perf
# Counter({1: 1})
#
# ['4Q53'] 2_Samuel 15 14 NDX[ HDJX
# 1 perf
# Counter({1: 1})
#
# ['4Q51'] 2_Samuel 22 34 <MD[ J<MDNJ
# 0 impf
# Counter({0: 1})
#
# ['1Qisaa', '4Q63'] Isaiah 1 2 >ZN[ H>ZJNJ
# 1 impv
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 1 4 CXT[ MCXJTJM
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 1 10 >ZN[ H>ZJNW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa', '4Q60'] Isaiah 1 15 <LM[ ><LJM
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 1 18 LBN[ JLBJNW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 2 6 FPQ[ JFPJQW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 2 20 CLK[ JCLJK
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 3 9 NGD[ HGJDW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 4 1 XZQ[ HXZJQW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 5 6 MVR[ HMVJR
# 1 infc
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 5 8 NG<[ MGJ<J
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 5 8 QRB[ JQRJBW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 5 11 DLQ[ JDLJQM
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 5 12 NBV[ JBJVW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 5 14 RXB[ HRXJBH
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa', '4Q56'] Isaiah 5 23 YDQ[ MYDJQJ
# 1 ptca
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 5 29 PLV[ JPLJV
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 5 29 NYL[ MYJL
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 7 6 BQ<[ NBQ<NH
# 0 impf
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 7 6 MLK[ NMLJK
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '4Q60'] Isaiah 8 8 NG<[ JGJ<
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 8 9 >ZN[ H>ZJNW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 8 12 <RY[ T<RJYW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '4Q59'] Isaiah 8 13 QDC[ TQDJCW
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa', '4Q65'] Isaiah 8 13 <RY[ M<RYKM
# 0 ptca
# Counter({0: 2})
#
# ['1Qisaa'] Isaiah 8 17 STR[ MSTJR
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 8 22 NBV[ JBJV
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 8 23 KBD[ HKBJD
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 9 9 XLP[ NXLJP
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 10 7 CMD[ HCMJD
# 1 infc
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 10 7 KRT[ HKRJT
# 1 infc
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 10 30 QCB[ HQCJBJ
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 11 9 CXT[ JCXJTW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 11 15 XRM=[ HXRJM
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 11 15 DRK[ HDRJK
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 12 4 ZKR[ HZKJRW
# 1 impv
# Counter({1: 2})
#
# ['1Qisaa', '4Q55', '4Q56'] Isaiah 13 9 CMD[ JCMJD
# 1 impf
# Counter({1: 3})
#
# ['1Qisaa', '4Q56'] Isaiah 13 11 CPL[ >CPJL
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa', '4Q55', '4Q56'] Isaiah 13 13 RGZ[ >RGJZ
# 1 impf
# Counter({1: 3})
#
# ['1Qisaa'] Isaiah 13 20 RBY[ JRBYW
# 0 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 14 16 CGX[ JCGJXW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 14 16 RGZ[ MRGJZ
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 14 16 R<C[ MR<JC
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 15 8 NQP[ HQJPH
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 17 2 XRD[ MXRJD
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 17 11 PRX[ TPRJXJ
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 18 4 NBV[ >BJVH
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 19 6 ZNX=[ H>ZNJXW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8', '4Q56'] Isaiah 19 8 CLK[ MCLJKJ
# 1 ptca
# Counter({1: 3})
#
# ['1Qisaa', '1Q8'] Isaiah 19 12 NGD[ JGJDW
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 19 17 ZKR[ JZKJR
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 19 20 NYL[ HYJLM
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 21 6 NGD[ JGJD
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 21 7 QCB[ HQCJB
# 1 perf
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 23 8 <VR[ M<VJRH
# 1 ptca
# Counter({0: 1})
#
# ['1Qisaa', '4Q55', '4Q57'] Isaiah 23 11 RGZ[ HRGJZ
# 1 perf
# Counter({1: 3})
#
# ['1Qisaa'] Isaiah 23 11 CMD[ CMD
# 0 infc
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 25 5 KN<[ TKNJ<
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '4Q57'] Isaiah 25 11 CPL[ HCPJL
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '4Q57'] Isaiah 25 12 CPL[ HCPJL
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '4Q57'] Isaiah 25 12 NG<[ HGJ<
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 26 5 CPL[ JCPJLH
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 26 5 NG<[ JGJ<NH
# 1 impf
# Counter({1: 1})
#
# ['4Q56'] Isaiah 26 13 ZKR[ NZKJR
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 26 17 QRB[ TQRJB
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 26 19 NPL[ TPJL
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 28 16 >MN[ M>MJN
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 28 23 >ZN[ H>ZJNW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 28 23 QCB[ HQCJBW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 28 29 PL>[ HPLJ>
# 1 perf
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 28 29 GDL[ HGDJL
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 29 14 PL>[ HPLJ>
# 1 infc
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 29 15 <MQ[ M<MJQJM
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 29 15 STR[ STR
# 0 infc
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 29 21 XV>[ MXVJ>J
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 29 23 QDC[ HQDJCW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 29 23 <RY[ J<RJYW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 30 4 NG<[ JGJ<W
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 30 11 CBT[ HCBJTW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 30 21 FM>L[ TFM>JLW
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 30 30 CM<[ HCMJ<
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 30 33 <MQ[ H<MJQ
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 30 33 RXB[ HRXB
# 0 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 31 5 NYL[ HYJL
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 31 6 <MQ[ H<MJQW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 32 6 XSR[ JXSJR
# 1 impf
# Counter({1: 1})
# ['1Qisaa'] Isaiah 34 1 QCB[ HQCJBW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 34 2 XRM[ HXRJMM
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 34 14 RG<[ HRGJ<H
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 34 17 NPL[ HPJL
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 35 10 NFG[ JFJGW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 3 ZKR[ MZKJR
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 10 CXT[ HCXJTH
# 1 infc
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 14 NC>=[ JC>
# 0 impf
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 36 14 NYL[ HYJL
# 1 infc
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 15 NYL[ JYJLNW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 18 NYL[ JYJLNW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 18 NYL[ HYJLW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 19 NYL[ HYJLW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 20 NYL[ HYJLW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 20 NYL[ JYJL
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 22 ZKR[ MZKJR
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 37 11 XRM[ HXRJMM
# 1 infc
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 37 12 NYL[ HYJLW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 37 12 CXT[ HCXJTW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 37 18 XRB[ HXRJBW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 37 25 XRB[ >XRB
# 0 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 38 6 NYL[ >YJLK
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 38 11 NBV[ >BJV
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 38 12 CLM[ TCLJMNJ
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 38 13 CLM[ TCLJMNJ
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 40 31 XLP[ JXLJPW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 1 XRC[ HXRJCW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 1 XLP[ JXLJPW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 41 7 XLQ=[ MXLJQ
# 1 ptca
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 41 13 XZQ[ MXZJQ
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 20 FKL[ JFKJLW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 21 NGC[ HGJCW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 22 NGC[ JGJCW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 22 NGD[ JGJDW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 22 NGD[ HGJDW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 22 CM<[ HCMJ<NW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 23 NGD[ HGJDW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 26 NGD[ HGJD
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 26 NGD[ MGJD
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 41 26 CM<[ MCMJ<
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 42 2 CM<[ JCMJ<
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '4Q62'] Isaiah 42 9 NGD[ MGJD
# 1 ptca
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 42 9 CM<[ >CMJ<
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 42 12 NGD[ JGJDW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 42 13 YRX[ JYRJX
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 42 14 XRC[ >XRJC
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 42 15 XRB[ >XRJB
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '4Q61'] Isaiah 42 16 DRK[ >DRJKM
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 42 18 NBV[ HBJVW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 42 21 GDL[ JGDJL
# 1 impf
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 42 21 >DR[ J>DJR
# 1 impf
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 42 22 NYL[ MYJL
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa', '4Q61'] Isaiah 42 23 >ZN[ J>ZJN
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 42 23 QCB[ JQCB
# 0 impf
# Counter({0: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 43 9 NGD[ JGJD
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 43 9 CM<[ JCMJ<NW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 43 10 >MN[ T>MJNW
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 43 13 NYL[ MYJL
# 1 ptca
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 44 7 NGD[ JGJDH
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 44 7 NGD[ JGJDW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 44 15 NFQ[ JFJQ
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 44 18 FKL[ HFKJL
# 1 infc
# Counter({0: 1})
#
# ['4Q56'] Isaiah 44 20 NYL[ JYJL
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8', '4Q56'] Isaiah 44 26 CLM[ JCLJM
# 1 impf
# Counter({1: 2, 0: 1})
#
# ['1Qisaa', '1Q8', '4Q56'] Isaiah 44 28 CLM[ JCLM
# 0 impf
# Counter({1: 2, 0: 1})
#
# ['1Qisaa'] Isaiah 45 8 YMX[ TYMJX
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 45 19 NGD[ MGJD
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 45 21 NGD[ HGJDW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 45 21 NGC[ HGJCW
# 1 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 45 21 CM<[ HCMJ<
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 45 21 NGD[ HGJDH
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 46 5 MCL=[ TMCLWNJ
# 0 impf
# Counter({0: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 46 10 NGD[ MGJD
# 1 ptca
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 47 14 NYL[ JYJLW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 48 1 ZKR[ JZKJRW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 48 3 CM<[ >CMJ<M
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 48 6 NGD[ TGJDW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 48 9 >RK[ >>RJK
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '4Q58'] Isaiah 48 9 KRT[ HKRJTK
# 1 infc
# Counter({1: 2})
#
# ['1Qisaa', '4Q58'] Isaiah 48 14 NGD[ HGJD
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '4Q58'] Isaiah 48 15 YLX[ HYLJX
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8', '4Q58'] Isaiah 48 17 DRK[ MDRJKK
# 1 ptca
# Counter({1: 2, 0: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 48 20 NGD[ HGJDW
# 1 impv
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 48 20 CM<[ HCMJ<W
# 1 impv
# Counter({1: 2})
#
# ['1Qisaa', '4Q58'] Isaiah 48 21 HLK[ HWLJKM
# 1 perf
# Counter({1: 2})
#
# ['1Q8', '4Q58'] Isaiah 48 21 NZL[ HZJL
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 49 1 QCB[ HQCJBW
# 1 impv
# Counter({1: 2})
#
# ['1Qisaa', '1Q8', '4Q58'] Isaiah 49 1 ZKR[ HZKJR
# 1 perf
# Counter({1: 3})
#
# ['1Qisaa', '1Q8'] Isaiah 49 2 XB>[ HXBJ>NJ
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8', '4Q58'] Isaiah 49 2 STR[ HSTJRNJ
# 1 perf
# Counter({1: 3})
#
# ['1Qisaa'] Isaiah 49 8 NXL[ HNXJL
# 1 infc
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 49 17 XRB[ MXRBJK
# 0 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 50 2 NYL[ HYJL
# 1 infc
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 50 2 XRB[ >XRJB
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 50 3 LBC[ >LBJC
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 50 8 YDQ[ MYDJQJ
# 1 ptca
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 50 9 RC<[ JRCJ<NJ
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8', '4Q56'] Isaiah 51 1 NBV[ HBJVW
# 1 impv
# Counter({1: 3})
#
# ['1Qisaa', '1Q8'] Isaiah 51 2 NBV[ HBJVW
# 1 impv
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 51 4 QCB[ HQCJBW
# 1 impv
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 51 4 >ZN[ H>ZJNW
# 1 impv
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 51 4 RG<[ >RGJ<
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 51 6 NBV[ HBJVW
# 1 impv
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 51 11 NFG[ JFJGWN
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 51 13 CXT[ HCXJT
# 1 infc
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 51 18 XZQ[ MXZJQ
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 52 7 CM<[ MCMJ<
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa', '1Q8', '4Q57'] Isaiah 52 13 FKL[ JFKJL
# 1 impf
# Counter({1: 3})
#
# ['1Qisaa', '1Q8'] Isaiah 53 1 >MN[ H>MJN
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 53 6 PG<[ HPGJ<
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '4Q58'] Isaiah 53 10 >RK[ J>RJK
# 1 impf
# Counter({0: 1, 1: 1})
#
# ['1Qisaa', '4Q58'] Isaiah 53 11 YDQ[ JYDJQ
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 53 12 PG<[ JPGJ<
# 1 impf
# Counter({0: 1, 1: 1})
#
# ['1Qisaa', '1Q8', '4Q58'] Isaiah 54 2 RXB[ HRXJBJ
# 1 impv
# Counter({1: 3})
#
# ['1Qisaa', '1Q8', '4Q58'] Isaiah 54 2 >RK[ H>RJKJ
# 1 impv
# Counter({1: 3})
#
# ['1Q8'] Isaiah 54 4 XPR[ TXPJRJ
# 1 impf
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 54 11 RBY[ MRBJY
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 55 10 YMX[ HYMJXH
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 55 11 YLX[ HYLJX
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 56 2 XZQ[ JXZJQ
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 56 3 BDL[ JBDJLNJ
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 56 4 XZQ[ MXZJQJM
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 56 6 XZQ[ MXZJQJM
# 1 ptca
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 57 4 RXB[ TRXJBW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 57 4 >RK[ T>RJKW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '4Q58'] Isaiah 57 12 NGD[ >GJD
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa', '4Q58'] Isaiah 57 13 NYL[ JYJLK
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 58 4 CM<[ HCMJ<
# 1 infc
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 58 10 FB<[ TFBJ<
# 1 impf
# Counter({1: 1, 0: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 58 11 FB<[ HFBJ<
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 58 11 XLY[ JXLJY
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 59 2 BDL[ MBDLJM
# 0 ptca
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 59 2 STR[ HSTJRW
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 59 9 NFG[ TFJGNW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 59 16 PG<[ MPGJ<
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 61 9 NKR[ JKJRWM
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 61 10 LBC[ HLBJCNJ
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 61 11 YMX[ TYMJX
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 61 11 YMX[ JYMJX
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 62 6 ZKR[ MZKRJM
# 0 ptca
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 62 11 CM<[ HCMJ<
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 63 5 NBV[ >BJV
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 63 7 ZKR[ >ZKJR
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 63 12 HLK[ MWLJK
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 63 13 HLK[ MWLJKM
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 63 16 NKR[ JKJRNW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 63 17 QCX[ TQCJX
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 64 3 >ZN[ H>ZJNW
# 1 perf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 64 6 XZQ[ HXZJQ
# 1 infc
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 65 3 K<S[ MK<JSJM
# 1 ptca
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 65 8 CXT[ TCXJTHW
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 65 8 CXT[ HCXJT
# 1 infc
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 65 25 CXT[ JCXJTW
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 66 2 NBV[ >BJV
# 1 impf
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 66 3 ZKR[ MZKJR
# 1 ptca
# Counter({1: 2})
#
# ['1Qisaa', '1Q8'] Isaiah 66 7 MLV[ HMLJVH
# 1 perf
# Counter({1: 2})
#
# ['1Qisaa'] Isaiah 66 9 CBR[ >CBJR
# 1 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 66 19 NGD[ HGJDW
# 1 perf
# Counter({1: 2})
#
# ['4Q72'] Jeremiah 8 21 XZQ[ HXZQTNJ
# 0 perf
# Counter({0: 1})
#
# ['4Q70'] Jeremiah 9 14 >KL[ M>KJLM
# 1 ptca
# Counter({1: 1})
#
# ['4Q72'] Jeremiah 31 21 NYB[ HYJBJ
# 1 impv
# Counter({1: 1})
#
# ['4Q72'] Jeremiah 33 18 QVR[ MQVJR
# 1 ptca
# Counter({1: 1})
#
# ['2Q13'] Jeremiah 46 27 XRD[ MXRJD
# 1 ptca
# Counter({1: 1})
#
# ['2Q13'] Jeremiah 48 26 CKR[ HCKJRHW
# 1 impv
# Counter({1: 1})
#
# ['2Q13'] Jeremiah 48 26 GDL[ HGDJL
# 1 perf
# Counter({1: 1})
#
# ['2Q13'] Jeremiah 48 35 QVR[ MQVJR
# 1 ptca
# Counter({1: 1})
#
# ['4Q79'] Hosea 2 5 PCV[ >PCJVNH
# 1 impf
# Counter({0: 1})
#
# ['Mur88'] Joel 4 6 RXQ[ HRXJQM
# 1 infc
# Counter({1: 1})
#
# ['Mur88'] Amos 1 9 SGR[ HSGJRM
# 1 infc
# Counter({1: 1})
#
# ['4Q82'] Amos 4 7 MVR[ >MVJR
# 1 impf
# Counter({1: 1})
#
# ['Mur88'] Amos 8 3 CLK[ HCLJK
# 1 perf
# Counter({1: 1})
#
# ['4Q82'] Amos 8 5 CBR=[ NCBJRH
# 1 impf
# Counter({0: 1})
#
# ['Mur88'] Amos 8 5 QVN[ HQVJN
# 1 infc
# Counter({1: 1})
#
# ['Mur88'] Obadiah 1 3 NC>=[ HCJ>K
# 1 perf
# Counter({1: 1})
#
# ['Mur88'] Obadiah 1 5 C>R[ JC>JRW
# 1 impf
# Counter({1: 1})
#
# ['Mur88'] Obadiah 1 7 NC>=[ HCJ>WK
# 1 perf
# Counter({1: 1})
#
# ['Mur88'] Obadiah 1 14 KRT[ HKRJT
# 1 infc
# Counter({1: 1})
#
# ['Mur88'] Jonah 1 7 NPL[ NPJLH
# 1 impf
# Counter({1: 1})
#
# ['4Q81', 'Mur88'] Jonah 1 10 NGD[ HGJD
# 1 perf
# Counter({1: 2})
#
# ['4Q82', 'Mur88'] Jonah 2 5 NBV[ HBJV
# 1 infc
# Counter({1: 2})
#
# ['4Q82', 'Mur88'] Jonah 4 6 NYL[ HYJL
# 1 infc
# Counter({0: 1, 1: 1})
#
# ['Mur88'] Micah 1 16 RXB[ HRXBJ
# 0 impv
# Counter({0: 1})
#
# ['Mur88'] Micah 2 6 NVP[ TVPW
# 0 impf
# Counter({0: 1})
#
# ['Mur88'] Micah 2 6 NVP[ JVPW
# 0 impf
# Counter({0: 1})
#
# ['Mur88'] Micah 2 8 PCV[ TPCVWN
# 0 impf
# Counter({0: 1})
#
# ['Mur88'] Micah 2 11 NVP[ >VP
# 0 impf
# Counter({0: 1})
#
# ['Mur88'] Micah 3 8 NGD[ HGJD
# 1 infc
# Counter({1: 1})
#
# ['Mur88'] Micah 5 7 NYL[ MYJL
# 1 ptca
# Counter({1: 1})
#
# ['Mur88'] Micah 7 5 >MN[ T>MJNW
# 1 impf
# Counter({1: 1})
#
# ['Mur88'] Nahum 1 14 KRT[ >KRJT
# 1 impf
# Counter({1: 1})
#
# ['Mur88'] Nahum 3 14 XZQ[ HXZJQJ
# 1 impv
# Counter({1: 1})
#
# ['Mur88'] Habakkuk 1 3 NBV[ TBJV
# 1 impf
# Counter({1: 1})
#
# ['Mur88'] Zephaniah 3 13 XRD[ MXRJD
# 1 ptca
# Counter({1: 1})
#
# ['Mur88'] Zephaniah 3 17 XRC[ JXRJC
# 1 impf
# Counter({1: 1})
#
# ['4Q80'] Zechariah 1 4 QCB[ HQCJBW
# 1 perf
# Counter({1: 1})
#
# ['4Q76'] Malachi 3 3 NGC[ MGJCJ
# 1 ptca
# Counter({1: 1})
#
# ['4Q83'] Psalms 5 10 XLQ=[ JXLJQWN
# 1 impf
# Counter({1: 1})
#
# ['11Q7'] Psalms 12 5 GBR[ NGBJR
# 1 impf
# Counter({1: 1})
#
# ['11Q7'] Psalms 13 2 STR[ TSTJR
# 1 impf
# Counter({1: 1})
#
# ['11Q7'] Psalms 14 1 T<B[ HT<JBW
# 1 perf
# Counter({1: 1})
#
# ['11Q8', '5/6hev1b'] Psalms 18 28 CPL[ TCPJL
# 1 impf
# Counter({1: 2})
#
# ['5/6hev1b'] Psalms 18 34 <MD[ J<MJDNJ
# 1 impf
# Counter({1: 1})
#
# ['5/6hev1b'] Psalms 18 40 KR<[ TKRJ<
# 1 impf
# Counter({1: 1})
#
# ['5/6hev1b'] Psalms 18 41 YMT[ >YMJTM
# 1 impf
# Counter({1: 1})
#
# ['5/6hev1b'] Psalms 22 8 L<G[ JL<GW
# 0 impf
# Counter({0: 1})
#
# ['5/6hev1b'] Psalms 22 8 PVR[ JPVJRW
# 1 impf
# Counter({1: 1})
#
# ['5/6hev1b'] Psalms 22 9 NYL[ JYJLHW
# 1 impf
# Counter({1: 1})
#
# ['4Q88', '5/6hev1b'] Psalms 22 17 NQP[ HQJPWNJ
# 1 perf
# Counter({1: 2})
#
# ['5/6hev1b'] Psalms 22 18 NBV[ JBJVW
# 1 impf
# Counter({1: 1})
#
# ['5/6hev1b'] Psalms 22 19 NPL[ JPJLW
# 1 impf
# Counter({1: 1})
#
# ['5/6hev1b'] Psalms 23 2 RBY[ JRBJYNJ
# 1 impf
# Counter({1: 1})
#
# ['4Q98'] Psalms 33 14 CGX[ HCGJX
# 1 perf
# Counter({1: 1})
#
# ['4Q98'] Psalms 35 10 NYL[ MYJL
# 1 ptca
# Counter({1: 1})
#
# ['4Q83'] Psalms 38 17 GDL[ HGDJLW
# 1 perf
# Counter({1: 1})
#
# ['4Q85'] Psalms 50 19 YMD[ TYMJD
# 1 impf
# Counter({1: 1})
#
# ['4Q85'] Psalms 50 22 NYL[ MYJL
# 1 ptca
# Counter({1: 1})
#
# ['4Q83'] Psalms 71 9 CLK[ TCLJKNJ
# 1 impf
# Counter({1: 1})
#
# ['Mas1e'] Psalms 81 15 KN<[ >KNJ<
# 1 impf
# Counter({1: 1})
#
# ['Mas1e'] Psalms 81 17 FB<[ >FBJ<K
# 1 impf
# Counter({1: 1})
#
# ['Mas1e'] Psalms 82 3 YDQ[ HYDJQW
# 1 impv
# Counter({1: 1})
#
# ['Mas1e'] Psalms 82 4 NYL[ HYJLW
# 1 impv
# Counter({1: 1})
#
# ['4Q84'] Psalms 91 8 NBV[ TBJV
# 1 impf
# Counter({1: 1})
# ['4Q84'] Psalms 94 9 NBV[ JBJV
# 1 impf
# Counter({1: 1})
#
# ['4Q84'] Psalms 94 13 CQV[ HCQJV
# 1 infc
# Counter({1: 1})
#
# ['4Q84'] Psalms 102 20 CQP[ HCQJP
# 1 perf
# Counter({1: 1})
#
# ['4Q84'] Psalms 102 27 XLP[ TXLJPM
# 1 impf
# Counter({1: 1})
#
# ['4Q84'] Psalms 103 5 FB<[ MFBJ<
# 1 ptca
# Counter({1: 1})
#
# ['4Q84'] Psalms 103 12 RXQ[ HRXJQ
# 1 perf
# Counter({1: 1})
#
# ['4Q87'] Psalms 105 40 FB<[ JFBJ<M
# 1 impf
# Counter({1: 1})
#
# ['4Q87'] Psalms 109 13 KRT[ HKRJT
# 1 infc
# Counter({1: 1})
#
# ['4Q90', '11Q5'] Psalms 119 15 NBV[ >BJVH
# 1 impf
# Counter({1: 2})
#
# ['4Q90', '11Q5'] Psalms 119 18 NBV[ >BJVH
# 1 impf
# Counter({1: 2})
#
# ['4Q87'] Psalms 125 5 HLK[ JWLJKM
# 1 impf
# Counter({1: 1})
#
# ['4Q87', '11Q5'] Psalms 126 2 GDL[ HGDJL
# 1 perf
# Counter({1: 2})
#
# ['4Q87'] Psalms 126 3 GDL[ HGDJL
# 1 perf
# Counter({1: 1})
#
# ['11Q5'] Psalms 132 15 FB<[ >FBJ<
# 1 impf
# Counter({1: 1})
#
# ['11Q5'] Psalms 132 17 YMX[ >YMJX
# 1 impf
# Counter({1: 1})
#
# ['11Q5'] Psalms 132 18 LBC[ >LBJC
# 1 impf
# Counter({1: 1})
#
# ['11Q5'] Psalms 135 17 >ZN[ J>ZJNW
# 1 impf
# Counter({1: 1})
#
# ['11Q5'] Psalms 136 14 <BR[ H<BJR
# 1 perf
# Counter({0: 1})
#
# ['11Q5'] Psalms 136 16 HLK[ MWLJK
# 1 ptca
# Counter({1: 1})
#
# ['11Q5'] Psalms 138 3 RHB[ TRHBNJ
# 0 impf
# Counter({1: 1})
#
# ['11Q5'] Psalms 142 5 NKR[ MKJR
# 1 ptca
# Counter({1: 1})
#
# ['11Q5'] Psalms 142 8 KTR[ JKTRW
# 0 impf
# Counter({1: 1})
#
# ['11Q5'] Psalms 145 4 NGD[ JGJDW
# 1 impf
# Counter({1: 1})
#
# ['11Q5'] Psalms 145 16 FB<[ MFBJ<
# 1 ptca
# Counter({1: 1})
#
# ['11Q5'] Psalms 145 20 CMD[ JCMJD
# 1 impf
# Counter({1: 1})
#
# ['4Q86'] Psalms 147 14 FB<[ JFBJ<K
# 1 impf
# Counter({1: 1})
#
# ['4Q86'] Psalms 147 17 CLK[ MCLJK
# 1 ptca
# Counter({1: 1})
#
# ['4Q100'] Job 8 15 XZQ[ JXZJQ
# 1 impf
# Counter({0: 1})
#
# ['4Q99'] Job 36 33 NGD[ JGJD
# 1 impf
# Counter({1: 1})
#
# ['4Q103'] Proverbs 14 35 FKL[ MFKJL
# 1 ptca
# Counter({1: 1})
#
# ['4Q103'] Proverbs 15 2 NB<[ JBJ<
# 1 impf
# Counter({1: 1})
#
# ['4Q103'] Proverbs 15 24 FKL[ MFKJL
# 1 ptca
# Counter({1: 1})
#
# ['2Q16'] Ruth 2 15 KLM[ TKLJMWH
# 1 impf
# Counter({1: 1})
#
# ['4Q107'] Song_of_songs 2 12 NG<[ HGJ<
# 1 perf
# Counter({1: 1})
#
# ['4Q107'] Song_of_songs 4 2 T>M[ MT>JMWT
# 1 ptca
# Counter({0: 1})
#
# ['4Q111'] Lamentations 1 9 GDL[ HGDJL
# 1 perf
# Counter({1: 1})
#
# ['4Q111'] Lamentations 1 14 KCL[ HKCJL
# 1 perf
# Counter({1: 1})
#
# ['1Q71'] Daniel 2 2 NGD[ HGJD
# 1 infc
# Counter({1: 1})
#
# ['4Q112', '4Q113'] Daniel 8 4 GDL[ HGDJL
# 1 perf
# Counter({1: 1, 0: 1})
#
# ['4Q113'] Daniel 8 7 NG<[ MGJ<
# 1 ptca
# Counter({1: 1})
#
# ['4Q114'] Daniel 11 1 XZQ[ MXZJQ
# 1 ptca
# Counter({0: 1})
#
# ['4Q114'] Daniel 11 2 NGD[ >GJD
# 1 impf
# Counter({1: 1})
#
# ['4Q114'] Daniel 11 2 <CR[ J<CJR
# 1 impf
# Counter({1: 1})
#
# ['4Q114'] Daniel 11 14 <MD[ H<MJD
# 1 infc
# Counter({1: 1})
#
# ['4Q114'] Daniel 11 17 CXT[ HCXJTH
# 1 infc
# Counter({1: 1})

# %%
# Explore tsere cases

# %%
mt_nodes = list(mt_tsere.tf_id)

for mt_node in mt_nodes:
    dss_nodes = mt_dss_match_dict.get(mt_node, [])
    dss_df = dss_tsere[dss_tsere.tf_id.isin(dss_nodes)]
    if dss_df.shape[0] > 0:
        mt_row = mt_tsere[mt_tsere.tf_id == mt_node]
        mt_mater = mt_row.has_vowel_letter.iloc[0]
        mt_vt, bo, ch, ve = mt_row.vt.iloc[0], mt_row.book.iloc[0], mt_row.chapter.iloc[0], mt_row.verse.iloc[0]
        dss_mater_count = collections.Counter(dss_df.has_vowel_letter)
        scrolls = list(dss_df.scroll)
        #if mt_mater == 0:
        #    continue
        print(scrolls, bo, ch, ve)
        print(mt_mater, mt_vt)
        print(dss_mater_count)
        print()
# Out:
# ['4Q2'] Genesis 1 11
# 0 impf
# Counter({0: 1})
#
# ['4Q9'] Genesis 41 34
# 0 impf
# Counter({0: 1})
#
# ['2Q5'] Leviticus 11 26
# 0 ptca
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 27 5
# 0 impf
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 27 6
# 0 impf
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 32 9
# 0 impv
# Counter({1: 1})
#
# ['1Qisaa'] Isaiah 36 15
# 0 impf
# Counter({0: 1})
#
# ['1Qisaa'] Isaiah 42 6
# 0 impf
# Counter({1: 1})
#
# ['1Qisaa', '1Q8'] Isaiah 51 10
# 0 ptca
# Counter({0: 2})
#
# ['Mur88'] Obadiah 1 14
# 0 impf
# Counter({0: 1})
#
# ['Mur88'] Micah 3 4
# 0 impf
# Counter({0: 1})
#
# ['4Q85'] Psalms 27 14
# 0 impf
# Counter({0: 1})
#
# ['4Q83'] Psalms 69 18
# 0 impf
# Counter({0: 1})
#
# ['11Q5'] Psalms 119 19
# 0 impf
# Counter({0: 1})
#
# ['1Q10', '4Q89', '11Q5'] Psalms 119 43
# 0 impf
# Counter({0: 3})
#
# ['11Q5'] Psalms 119 133
# 0 impf
# Counter({0: 1})
#
# ['11Q5'] Psalms 143 7
# 0 impf
# Counter({0: 1})
#
# ['4Q99'] Job 37 5
# 0 impf
# Counter({0: 1})
#
# ['4Q103'] Proverbs 15 25
# 0 impf
# Counter({0: 1})
