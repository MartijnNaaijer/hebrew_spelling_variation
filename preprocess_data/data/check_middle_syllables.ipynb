# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is FCC3-CE53
#
#  Directory of C:\Users\geitb\Kopenhagen\KopenhagenResearch\scripts_research\hebrew_spelling_variation\preprocess_data\data
#
# 09-02-2023  13:47    <DIR>          .
# 15-01-2023  15:03    <DIR>          ..
# 09-02-2023  13:47    <DIR>          .ipynb_checkpoints
# 09-02-2023  10:17            31.308 check_middle_syllables.ipynb
# 09-02-2023  09:56         5.130.794 matres_dss.csv
# 09-02-2023  09:56        31.154.695 matres_mt.csv
# 09-02-2023  10:00        31.666.189 mt_dss_with_middle_syllables.csv
#                4 File(s)     67.982.986 bytes
#                3 Dir(s)  594.897.592.320 bytes free

# %%
dat = pd.read_csv('mt_dss_with_middle_syllables.csv', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26532/3648146535.py in <module>
# ----> 1 dat = pd.read_csv('mt_dss_with_middle_syllables.csv', sep='\t')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     678     kwds.update(kwds_defaults)
#     679
# --> 680     return _read(filepath_or_buffer, kwds)
#     681
#     682
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     931
#     932         self.handles: IOHandles | None = None
# --> 933         self._engine = self._make_engine(f, self.engine)
#     934
#     935     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1215             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217             self.handles = get_handle(  # type: ignore[call-overload]
#    1218                 f,
#    1219                 mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     787         if ioargs.encoding and "b" not in ioargs.mode:
#     788             # Encoding
# --> 789             handle = open(
#     790                 handle,
#     791                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mt_dss_with_middle_syllables.csv'

# %%
dat.head()
# Out:
#    tf_id scroll     book  chapter  verse     lex g_cons   stem pattern  \
# 0      2     MT  Genesis        1      1  R>CJT/  R>CJT  R>CJT   CMCMC
# 1      2     MT  Genesis        1      1  R>CJT/  R>CJT  R>CJT   CMCMC
# 2      4     MT  Genesis        1      1  >LHJM/  >LHJM    >LH     CCC
# 3      4     MT  Genesis        1      1  >LHJM/  >LHJM    >LH     CCC
# 4      7     MT  Genesis        1      1   CMJM/   CMJM    CMJ     CCC
#
#   pattern_g_cons  ... other_vowel_ending final_h line column  \
# 0          CMCMC  ...                NaN     noH    -      -
# 1          CMCMC  ...                NaN     noH    -      -
# 2          CCCMC  ...                NaN     noH    -      -
# 3          CCCMC  ...                NaN     noH    -      -
# 4           CCCC  ...                NaN     noH    -      -
#
#   has_pronominal_suffix has_prefix has_hloc has_nme   type vowel_letter
# 0                     0          1        0       0   last            J
# 1                     0          1        0       0  first            >
# 2                     0          0        0       1   last          NaN
# 3                     0          0        0       1  first          NaN
# 4                     0          1        0       1   last          NaN
#
# [5 rows x 33 columns]

# %%
dat.type.value_counts()
# Out:
# last      107586
# first     107586
# single     73167
# second       647
# third          4
# Name: type, dtype: int64

# %%
dat.query("type=='third'")
# Out:
#           tf_id  scroll         book  chapter  verse      lex   g_cons   stem  \
# 53201    111708      MT  Deuteronomy       32     20  THPKWT/    THPKT  THPKT
# 201360  1893410     1Q5  Deuteronomy       32     20  THPKWT/    THPKT   THPK
# 268298  2055670  4Q103a     Proverbs       10     31  THPKWT/   THPKWT   THPK
# 272830  2069684   4Q141  Deuteronomy       32     20  THPKWT/  THPWKWT  THPWK
#
#        pattern pattern_g_cons  ... other_vowel_ending final_h line  column  \
# 53201    CCCCC          CCCCC  ...                NaN     noH    -       -
# 201360    CCCC           CCCC  ...                NaN     noH    3  f16_19
# 268298    CCCC           CCCC  ...                NaN     noH    2      f2
# 272830   CCCMC          CCCMC  ...                NaN     noH   16     f1i
#
#        has_pronominal_suffix has_prefix has_hloc has_nme   type vowel_letter
# 53201                      0          0        0       0  third          NaN
# 201360                     0          0        0       1  third          NaN
# 268298                     0          0        0       1  third          NaN
# 272830                     0          0        0       1  third            W
#
# [4 rows x 33 columns]

# %%
second = dat.query("type=='second'")

# %%
sec_lexemes = set(second.lex)

# %%
for lex in sec_lexemes:
    lex_df = second.query("lex==@lex")
    print(lex)
    print(set(lex_df.stem))
    print()
# Out:
# KRJTWT/
# {'KRJTWT', 'KRTT', 'KRJTT'}
#
# TLNWT/
# {'TLNT', 'TLWNT'}
#
# CRRWT/
# {'CRJRWT', 'CRRWT'}
#
# >R>LJ/
# {'>RJ>L', '>R>L'}
#
# NVWPTJ/
# {'NVPT', 'NVWPT'}
#
# >RMWN/
# {'>RMWN', '>RWMN', '>RMN'}
#
# YW>R/
# {'YW>RT', 'YWR>'}
#
# YMTT/
# {'YMTT', 'YMJTT', 'YMJTWT'}
#
# MSLWL/
# {'MSWLL', 'MSLWL'}
#
# XYYRH/
# {'XYWYR', 'XYYR'}
#
# JCJMWN/
# {'JCJMWN', 'JCMWN', 'JCMN', 'JCJMN', 'JCWMWN'}
#
# CLJCJT/
# {'CLJCT', 'CLCJT', 'CLJCJT', 'CLCT'}
#
# MDBR/
# {'MDJBR', 'MDBR', 'MBDBR'}
#
# R>CWN/
# {'R>CN', 'RJ>CN', 'R>CWN', 'RJ>CWN', 'R>JCWN'}
#
# M<ZN/
# {'M<ZN', 'M<WZN'}
#
# XMJCJT/
# {'XMJCT', 'XMCJT', 'XMCT', 'XMJCJT'}
#
# >J<ZRJ/
# {'>XJ<ZR', '>J<ZR'}
#
# HRJST/
# {'HRST', 'HRWST'}

# %%
dat.query("g_cons=='R>JCWN'")
# Out:
#           tf_id scroll       book  chapter  verse     lex  g_cons    stem  \
# 158724   339800     MT        Job       15      7  R>CWN/  R>JCWN  R>JCWN
# 158725   339800     MT        Job       15      7  R>CWN/  R>JCWN  R>JCWN
# 158726   339800     MT        Job       15      7  R>CWN/  R>JCWN  R>JCWN
# 200534  1890978    1Q3  Leviticus       23      7  R>CWN/  R>JCWN  R>JCWN
# 200535  1890978    1Q3  Leviticus       23      7  R>CWN/  R>JCWN  R>JCWN
# 254186  2022647   4Q57     Isaiah       48     12  R>CWN/  R>JCWN  R>JCWN
# 254187  2022647   4Q57     Isaiah       48     12  R>CWN/  R>JCWN  R>JCWN
# 254188  2022647   4Q57     Isaiah       48     12  R>CWN/  R>JCWN  R>JCWN
#
#        pattern pattern_g_cons  ... other_vowel_ending final_h line column  \
# 158724  CMCCMC         CMCCMC  ...                NaN     noH    -      -
# 158725  CMCCMC         CMCCMC  ...                NaN     noH    -      -
# 158726  CMCCMC         CMCCMC  ...                NaN     noH    -      -
# 200534  CMMCMC         CMMCMC  ...                NaN     noH    4     f7
# 200535  CMMCMC         CMMCMC  ...                NaN     noH    4     f7
# 254186  CCMCMC         CCMCMC  ...                NaN     noH    1    f29
# 254187  CCMCMC         CCMCMC  ...                NaN     noH    1    f29
# 254188  CCMCMC         CCMCMC  ...                NaN     noH    1    f29
#
#        has_pronominal_suffix has_prefix has_hloc has_nme    type vowel_letter
# 158724                     0          1        0       0  second          NaN
# 158725                     0          1        0       0   first            >
# 158726                     0          1        0       0    last            W
# 200534                     0          1        0       0   first           >J
# 200535                     0          1        0       0    last            W
# 254186                     0          0        0       0    last            W
# 254187                     0          0        0       0  second            J
# 254188                     0          0        0       0   first          NaN
#
# [8 rows x 33 columns]

# %%
# CASES TO BE REMOVED WITH REASON:
YW>R/ {'YW>RT', 'YWR>'} mix of consonants
R>CWN/ {'R>CN', 'RJ>CN', 'R>CWN', 'RJ>CWN', 'R>JCWN'} On several places wrong parsing, e.g. MT tfid 339800, should be CMMCMC
>J<ZRJ/ {'>XJ<ZR', '>J<ZR'} strange extra X in word

# %%
# OTHER REMARKS
MDBR/ {'MDJBR', 'MDBR', 'MBDBR'} a bit strange, but maybe keep it.
